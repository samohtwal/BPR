# %% [markdown]
# <a href="https://colab.research.google.com/github/samohtwal/BPR/blob/20221027/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import torch
import copy
from itertools import islice
from google.colab import files
import os
import matplotlib.pyplot as plt

# %%
global data_user_column_name
data_user_column_name = 'user_id'

global data_item_column_name
data_item_column_name = 'item_id'

global data_group_by_user_id_dictionary_key
data_group_by_user_id_dictionary_key = 'data_group_by_user_id'

global data_group_by_item_id_dictionary_key
data_group_by_item_id_dictionary_key = 'data_group_by_item_id'

global user_latent_factor_matrix_dictionary_key
user_latent_factor_matrix_dictionary_key = 'user_latent_factor_matrix'

global item_latent_factor_matrix_dictionary_key
item_latent_factor_matrix_dictionary_key = 'item_latent_factor_matrix'

global working_file_path
working_file_path = '/content/working/'

global user_latent_factor_matrix_file_name_base
user_latent_factor_matrix_file_name_base = 'user_latent_factor_matrix'

global item_latent_factor_matrix_file_name_base
item_latent_factor_matrix_file_name_base = 'item_latent_factor_matrix'

global root_mean_square_error_file_name_base
root_mean_square_error_file_name_base = 'root_mean_square_error'

global precision_file_name_base
precision_file_name_base = 'precision'

global csv_file_extension
csv_file_extension = '.csv'

global training_data_url
training_data_url = 'https://raw.githubusercontent.com/samohtwal/Bayesian-Personalized-Ranking/main/data/train.csv'

global validation_data_url
validation_data_url = 'https://raw.githubusercontent.com/samohtwal/Bayesian-Personalized-Ranking/main/data/vali.csv'

# %%
class DataHelper:

    def load_data_dictionary(self, data_url):

        column_names = [data_user_column_name, data_item_column_name]
        raw_data = pd.read_csv(data_url, names = column_names, header=0)

        data_group_by_user_id = raw_data.groupby(data_user_column_name)[data_item_column_name].apply(list).reset_index(name=data_item_column_name).sort_values(by=[data_user_column_name])
        data_group_by_item_id = raw_data.groupby(data_item_column_name)[data_user_column_name].apply(list).reset_index(name=data_user_column_name).sort_values(by=[data_item_column_name])

        data_dictionary = {
            data_group_by_user_id_dictionary_key: data_group_by_user_id, 
            data_group_by_item_id_dictionary_key: data_group_by_item_id
        }

        return data_dictionary

    def save_latent_factor_matrix_dictionarys(self, bayseian_personalized_ranking_models):

        for index, bayseian_personalized_ranking_model in enumerate(bayseian_personalized_ranking_models):

            latent_factor_matrix_dictionary = bayseian_personalized_ranking_model.latent_factor_matrix_dictionary

            user_latent_factor_matrix = latent_factor_matrix_dictionary[user_latent_factor_matrix_dictionary_key]
            item_latent_factor_matrix = latent_factor_matrix_dictionary[item_latent_factor_matrix_dictionary_key]
        
            if os.path.exists(working_file_path) == False:
                os.mkdir(working_file_path)

            user_latent_factor_matrix_file_name = user_latent_factor_matrix_file_name_base + '_' + str(index) + csv_file_extension
            item_latent_factor_matrix_file_name = item_latent_factor_matrix_file_name_base + '_' + str(index) + csv_file_extension

            pd.DataFrame(user_latent_factor_matrix).to_csv(working_file_path + user_latent_factor_matrix_file_name, index=False, header=False)
            pd.DataFrame(item_latent_factor_matrix).to_csv(working_file_path + item_latent_factor_matrix_file_name, index=False, header=False)

        return None

    def load_latent_factor_matrix_dictionarys(self, n_latent_factor_matrix_dictionary):

        latent_factor_matrix_dictionarys = []
        for index in range(n_latent_factor_matrix_dictionary):

            user_latent_factor_matrix_file_name = user_latent_factor_matrix_file_name_base + '_' + str(index) + csv_file_extension
            item_latent_factor_matrix_file_name = item_latent_factor_matrix_file_name_base + '_' + str(index) + csv_file_extension

            user_latent_factor_matrix = pd.read_csv(working_file_path + user_latent_factor_matrix_file_name, header=None).values
            item_latent_factor_matrix = pd.read_csv(working_file_path + item_latent_factor_matrix_file_name, header=None).values

            latent_factor_matrix_dictionary = {
                user_latent_factor_matrix_dictionary_key: user_latent_factor_matrix, 
                item_latent_factor_matrix_dictionary_key: item_latent_factor_matrix
            }

            latent_factor_matrix_dictionarys.append(latent_factor_matrix_dictionary)

        return latent_factor_matrix_dictionarys 

    def save_root_mean_square_errors(self, bayseian_personalized_ranking_models):

        for index, bayseian_personalized_ranking_model in enumerate(bayseian_personalized_ranking_models):

            root_mean_square_errors = bayseian_personalized_ranking_model.root_mean_square_errors   

            if os.path.exists(working_file_path) == False:
                os.mkdir(working_file_path)
            
            root_mean_square_error_file_name = root_mean_square_error_file_name_base + '_' + str(index) + csv_file_extension
            pd.DataFrame(root_mean_square_errors).to_csv(working_file_path + root_mean_square_error_file_name, index=False, header=False)

        return None

    def load_root_mean_square_errors(self, n_root_mean_square_error):

        root_mean_square_errors = []
        for index in range(n_root_mean_square_error):

            root_mean_square_error_file_name = root_mean_square_error_file_name_base + '_' + str(index) + csv_file_extension
            root_mean_square_error = pd.read_csv(working_file_path + root_mean_square_error_file_name, header=None).values
            root_mean_square_errors.append(root_mean_square_error)

        return root_mean_square_errors

    def save_precisions(self, precisions):
        
        if os.path.exists(working_file_path) == False:
            os.mkdir(working_file_path)
            
        precision_file_name = precision_file_name_base + csv_file_extension
        pd.DataFrame(precisions).to_csv(working_file_path + precision_file_name, index=False, header=False)

        return None

# %%
class BayseianPersonalizedRankingModel:

    def __init__(self, random_seed, n_latent_factor, n_batch, learning_rate, regularization_constant):
        
        self.random_seed = random_seed
        self.n_latent_factor = n_latent_factor
        self.n_batch = n_batch
        self.learning_rate = learning_rate
        self.regularization_constant = regularization_constant
        
        self.training_data_dictionary = {}
        self.latent_factor_matrix_dictionary = {}
        self.root_mean_square_errors = []
        self.root_mean_square_error = 0
    
    def fit(self):

        training_data_dictionary = self.training_data_dictionary

        training_data_group_by_user_id = training_data_dictionary[data_group_by_user_id_dictionary_key]
        training_data_group_by_item_id = training_data_dictionary[data_group_by_item_id_dictionary_key]

        n_user = len(training_data_group_by_user_id[data_user_column_name])
        n_item = len(training_data_group_by_item_id[data_item_column_name])

        rstate = np.random.RandomState(self.random_seed)

        user_latent_factor_matrix = rstate.normal(size = (n_user, self.n_latent_factor))
        item_latent_factor_matrix = rstate.normal(size = (n_item, self.n_latent_factor))

        user_item_rating_matrix = self._create_user_item_rating_matrix(training_data_group_by_user_id, training_data_group_by_item_id)

        user_latent_factor_matrixes = []
        item_latent_factor_matrixes = []
        root_mean_square_errors = []

        is_converge = True
        index = 0
        while is_converge:
            
            sample_latent_factor_matrix_row_indexes = self._create_sample_latent_factor_matrix_row_indexes(training_data_group_by_user_id, training_data_group_by_item_id)
            sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes = sample_latent_factor_matrix_row_indexes
            user_latent_factor_matrix, item_latent_factor_matrix = self._update_sample_latent_factor_matrix_rows(user_latent_factor_matrix, item_latent_factor_matrix, sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes)
            
            sum_of_square_error = np.sum((user_item_rating_matrix - self._predict(user_latent_factor_matrix, item_latent_factor_matrix))**2)
            root_mean_square_error = np.sqrt((sum_of_square_error / n_user * n_item))

            user_latent_factor_matrixes.append(user_latent_factor_matrix)
            item_latent_factor_matrixes.append(item_latent_factor_matrix)
            root_mean_square_errors.append(root_mean_square_error)
            
            print('debug - iteration:', index+1, end='\n')
            print('debug - root_mean_square_error:', root_mean_square_error, end='\n')
            print('', end='\n')
            
            if (root_mean_square_errors[index] > root_mean_square_errors[index-1] 
                and root_mean_square_errors[index-1] > root_mean_square_errors[index-2]
                and root_mean_square_errors[index-2] > root_mean_square_errors[index-3]):
                is_converge = False
            # if index == 10:
            #     is_converge = False

            index = index + 1

        latent_factor_matrix_dictionary = {
            user_latent_factor_matrix_dictionary_key: user_latent_factor_matrixes[index-3], 
            item_latent_factor_matrix_dictionary_key: item_latent_factor_matrixes[index-3]
        }

        root_mean_square_error = root_mean_square_errors[index-3]

        self.latent_factor_matrix_dictionary = latent_factor_matrix_dictionary
        self.root_mean_square_errors = root_mean_square_errors
        self.root_mean_square_error = root_mean_square_errors[index-3]

        return None
    
    def _create_user_item_rating_matrix(self, training_data_group_by_user_id, training_data_group_by_item_id):

        n_user = len(training_data_group_by_user_id[data_user_column_name])
        n_item = len(training_data_group_by_item_id[data_item_column_name])

        user_ids = training_data_group_by_user_id[data_user_column_name].tolist()
        item_ids = training_data_group_by_item_id[data_item_column_name].tolist()

        user_item_rating_matrix = np.zeros((n_user, n_item), dtype = np.int64)
        for user_id_index, user_id in enumerate(user_ids):
            item_id_indexes = np.where(np.isin(training_data_group_by_user_id.iloc[user_id_index][data_item_column_name],item_ids))[0]
            for item_id_index in item_id_indexes:
                user_item_rating_matrix[user_id_index, item_id_index] = 1

        return user_item_rating_matrix

    def _create_sample_latent_factor_matrix_row_indexes(self, training_data_group_by_user_id, training_data_group_by_item_id):

        n_user = len(training_data_group_by_user_id[data_user_column_name])
        n_item = len(training_data_group_by_item_id[data_item_column_name])

        item_ids = training_data_group_by_item_id[data_item_column_name].tolist()

        sample_user_id_indexes = np.random.choice(n_user, size = self.n_batch, replace = False)
        sample_positive_item_id_indexes = np.zeros(self.n_batch, dtype = np.int64)
        sample_negative_item_id_indexes = np.zeros(self.n_batch, dtype = np.int64)

        for index, sampled_user_id_index in enumerate(sample_user_id_indexes):
            possible_positive_item_ids = training_data_group_by_user_id.iloc[sampled_user_id_index][data_item_column_name]
            possible_negative_item_ids = list(set(item_ids).difference(possible_positive_item_ids))
            sample_positive_item_id = np.random.choice(possible_positive_item_ids)
            sample_negative_item_id = np.random.choice(possible_negative_item_ids)
            sample_positive_item_id_indexes[index] = item_ids.index(sample_positive_item_id)
            sample_negative_item_id_indexes[index] = item_ids.index(sample_negative_item_id)

        return sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes

    def _update_sample_latent_factor_matrix_rows(self, user_latent_factor_matrix, item_latent_factor_matrix, sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes):

        sample_user_latent_factor_matrix_tuple = user_latent_factor_matrix[sample_user_id_indexes]
        sample_item_latent_factor_matrix_positive_item_tuple = item_latent_factor_matrix[sample_positive_item_id_indexes]
        sample_item_latent_factor_matrix_negative_item_tuple = item_latent_factor_matrix[sample_negative_item_id_indexes]

        r_uij = np.sum(sample_user_latent_factor_matrix_tuple * (sample_item_latent_factor_matrix_positive_item_tuple - sample_item_latent_factor_matrix_negative_item_tuple), axis = 1)
        sigmoid = np.exp(-r_uij) / (1.0 + np.exp(-r_uij))
        sigmoid_tiled = np.tile(sigmoid, (self.n_latent_factor, 1)).T

        gradient_user = sigmoid_tiled * (sample_item_latent_factor_matrix_negative_item_tuple - sample_item_latent_factor_matrix_positive_item_tuple) + self.regularization_constant * sample_user_latent_factor_matrix_tuple
        gradient_positive_item = sigmoid_tiled * -sample_user_latent_factor_matrix_tuple + self.regularization_constant * sample_item_latent_factor_matrix_positive_item_tuple
        gradient_negative_item = sigmoid_tiled * sample_user_latent_factor_matrix_tuple + self.regularization_constant * sample_item_latent_factor_matrix_negative_item_tuple

        user_latent_factor_matrix[sample_user_id_indexes] -= self.learning_rate * gradient_user
        item_latent_factor_matrix[sample_positive_item_id_indexes] -= self.learning_rate * gradient_positive_item
        item_latent_factor_matrix[sample_negative_item_id_indexes] -= self.learning_rate * gradient_negative_item

        return user_latent_factor_matrix, item_latent_factor_matrix
    
    def recommend(self, n_best_recommendation):

        testing_data_dictionary = self.testing_data_dictionary
        training_data_dictionary = self.training_data_dictionary
        latent_factor_matrix_dictionary = self.latent_factor_matrix_dictionary

        testing_data_group_by_user_id = testing_data_dictionary[data_group_by_user_id_dictionary_key]

        n_user = len(testing_data_group_by_user_id[data_user_column_name])
        user_ids = user_ids = testing_data_group_by_user_id[data_user_column_name].tolist()

        recommendation_user_ids = []
        recommendation_item_ids = []
        for user_id in user_ids:
            best_recommendition_item_ids = self.recommend_user(user_id, n_best_recommendation)
            print('debug - len(best_recommendition_item_ids):', len(best_recommendition_item_ids), end='\n')
            print('', end='\n')
            for item_id in best_recommendition_item_ids:
                recommendation_user_ids.append(user_id)
                recommendation_item_ids.append(item_id)

        data = {'user_id': recommendation_user_ids, 'item_id': recommendation_item_ids}
        recommendation_data = pd.DataFrame.from_dict(data)

        recommendation_data_group_by_user_id = recommendation_data.groupby(data_user_column_name)[data_item_column_name].apply(list).reset_index(name=data_item_column_name).sort_values(by=[data_user_column_name])
        recommendation_data_group_by_item_id = recommendation_data.groupby(data_item_column_name)[data_user_column_name].apply(list).reset_index(name=data_user_column_name).sort_values(by=[data_item_column_name])

        recommendation_data_dictionary = {
            data_group_by_user_id_dictionary_key: recommendation_data_group_by_user_id, 
            data_group_by_item_id_dictionary_key: recommendation_data_group_by_item_id
        }

        return recommendation_data_dictionary

    def recommend_user(self, user_id, n_best_recommendation):

        training_data_dictionary = self.training_data_dictionary
        latent_factor_matrix_dictionary = self.latent_factor_matrix_dictionary

        training_data_group_by_user_id = training_data_dictionary[data_group_by_user_id_dictionary_key]
        training_data_group_by_item_id = training_data_dictionary[data_group_by_item_id_dictionary_key]

        user_latent_factor_matrix = latent_factor_matrix_dictionary[user_latent_factor_matrix_dictionary_key]
        item_latent_factor_matrix = latent_factor_matrix_dictionary[item_latent_factor_matrix_dictionary_key]

        user_ids = training_data_group_by_user_id[data_user_column_name].tolist()
        item_ids = training_data_group_by_item_id[data_item_column_name].tolist()

        n_item = len(training_data_group_by_item_id[data_item_column_name])

        user_index = user_ids.index(user_id)

        scores = self._predict_user(user_latent_factor_matrix, item_latent_factor_matrix, user_index)

        item_score_dictionary = {item_ids[i]: scores[i] for i in range(len(item_ids))}

        # positive_item_ids = training_data_group_by_user_id.iloc[user_index][data_item_column_name]
        # item_score_dictionary = dict((key, value) for key, value in item_score_dictionary.items() if key not in positive_item_ids)

        item_score_dictionary = dict(sorted(item_score_dictionary.items(), key=lambda item: item[1], reverse=True))
        best_recommendition_item_dictionary = dict(islice(item_score_dictionary.items(), n_best_recommendation))
        best_recommendition_item_ids = list(best_recommendition_item_dictionary.keys())

        return best_recommendition_item_ids

    def _predict(self, user_latent_factor_matrix, item_latent_factor_matrix):
        return user_latent_factor_matrix.dot(item_latent_factor_matrix.T)

    def _predict_user(self, user_latent_factor_matrix, item_latent_factor_matrix, user_index):
        return user_latent_factor_matrix[user_index].dot(item_latent_factor_matrix.T)

# %%
class ModelAnalyzerHelper:

    def plot_error_chart(self, bayseian_personalized_ranking_models):

        for index, bayseian_personalized_ranking_model in enumerate(bayseian_personalized_ranking_models):
            x = range(len(bayseian_personalized_ranking_model.root_mean_square_errors))
            y = bayseian_personalized_ranking_model.root_mean_square_errors
            label = label='Learning Rate = ' + str(bayseian_personalized_ranking_model.learning_rate) + ' Batch Size = ' + str(bayseian_personalized_ranking_model.n_batch)
            plt.plot(x, y, label=label)

        plt.xlabel("Iteration")
        plt.ylabel("Root Mean Square Error")
        plt.title("Root Mean Square Error / Iteration")
        plt.legend()
        plt.show()

        return None
    
    def evaluate(self, testing_data_dictionary, recommendation_data_dictionary):

        testing_data_group_by_user_id = testing_data_dictionary[data_group_by_user_id_dictionary_key]
        testing_user_ids = testing_data_group_by_user_id[data_user_column_name].tolist()

        testing_data_group_by_item_id = testing_data_dictionary[data_group_by_item_id_dictionary_key]
        testing_item_ids = testing_data_group_by_item_id[data_item_column_name].tolist()

        recommendation_data_group_by_user_id = recommendation_data_dictionary[data_group_by_user_id_dictionary_key]
        recommendation_user_ids = recommendation_data_group_by_user_id[data_user_column_name].tolist()

        n_true_positive = 0
        n_false_positive = 0
        n_true_negative = 0
        n_false_negative = 0

        for index, recommendation_user_id in enumerate(recommendation_user_ids):

            n_user_true_positive = 0
            n_user_false_positive = 0
            n_user_true_negative = 0
            n_user_false_negative = 0
            
            positive_testing_item_ids = testing_data_group_by_user_id.iloc[index][data_item_column_name]
            negative_testing_item_ids = list(set(testing_item_ids).difference(positive_testing_item_ids))
            positive_predition_item_ids = recommendation_data_group_by_user_id.iloc[index][data_item_column_name]
            negative_predition_item_ids = list(set(testing_item_ids).difference(positive_predition_item_ids))

            for positive_predition_item_id in positive_predition_item_ids:
                if positive_predition_item_id in positive_testing_item_ids: n_user_true_positive = n_user_true_positive + 1
                if positive_predition_item_id not in positive_testing_item_ids: n_user_false_positive = n_user_false_positive + 1

            for negative_predition_item_id in negative_predition_item_ids:
                if negative_predition_item_id in negative_testing_item_ids: n_user_true_negative = n_user_true_negative + 1
                if negative_predition_item_id not in negative_testing_item_ids: n_user_false_negative = n_user_false_negative + 1

            print('debug - recommendation_user_id:', recommendation_user_id, end='\n')
            print('debug - n_user_true_positive:', n_user_true_positive, end='\n')
            print('debug - n_user_false_positive:', n_user_false_positive, end='\n')
            print('debug - n_user_true_negative:', n_user_true_negative, end='\n')
            print('debug - n_user_false_negative:', n_user_false_negative, end='\n')
            print('', end='\n')

            n_true_positive = n_true_positive + n_user_true_positive
            n_false_positive = n_false_positive + n_user_false_positive
            n_true_negative = n_true_negative + n_user_true_negative
            n_false_negative = n_false_negative + n_user_false_negative

        print('debug - n_true_positive:', n_true_positive, end='\n')
        print('debug - n_false_positive:', n_false_positive, end='\n')
        print('debug - n_true_negative:', n_true_negative, end='\n')
        print('debug - n_false_negative:', n_false_negative, end='\n')
        print('', end='\n')

        true_positive_rate = n_true_positive / (n_true_positive + n_false_negative)
        false_positive_rate = n_false_positive / (n_false_positive + n_true_negative)

        precision = n_true_positive / (n_true_positive + n_false_positive)

        return true_positive_rate, false_positive_rate, precision

# %%
# train model

training_data_dictionary = DataHelper().load_data_dictionary(training_data_url)

bayseian_personalized_ranking_parameters = []
bayseian_personalized_ranking_parameters.append({
    'random_seed' : 1234, 
    'n_latent_factor' : 15, 
    'n_batch' : 1000, 
    'learning_rate' : 0.1, 
    'regularization_constant' : 0.1
})
bayseian_personalized_ranking_parameters.append({
    'random_seed' : 1234, 
    'n_latent_factor' : 15, 
    'n_batch' : 2000, 
    'learning_rate' : 0.1, 
    'regularization_constant' : 0.1
})
bayseian_personalized_ranking_parameters.append({
    'random_seed' : 1234, 
    'n_latent_factor' : 15, 
    'n_batch' : 3000, 
    'learning_rate' : 0.1, 
    'regularization_constant' : 0.1
})
bayseian_personalized_ranking_parameters.append({
    'random_seed' : 1234, 
    'n_latent_factor' : 15, 
    'n_batch' : 1000, 
    'learning_rate' : 0.2, 
    'regularization_constant' : 0.2
})
bayseian_personalized_ranking_parameters.append({
    'random_seed' : 1234, 
    'n_latent_factor' : 15, 
    'n_batch' : 2000, 
    'learning_rate' : 0.2, 
    'regularization_constant' : 0.2
})
bayseian_personalized_ranking_parameters.append({
    'random_seed' : 1234, 
    'n_latent_factor' : 15, 
    'n_batch' : 3000, 
    'learning_rate' : 0.2, 
    'regularization_constant' : 0.2
})
bayseian_personalized_ranking_parameters.append({
    'random_seed' : 1234, 
    'n_latent_factor' : 15, 
    'n_batch' : 1000, 
    'learning_rate' : 0.3, 
    'regularization_constant' : 0.3
})
bayseian_personalized_ranking_parameters.append({
    'random_seed' : 1234, 
    'n_latent_factor' : 15, 
    'n_batch' : 2000, 
    'learning_rate' : 0.3, 
    'regularization_constant' : 0.3
})
bayseian_personalized_ranking_parameters.append({
    'random_seed' : 1234, 
    'n_latent_factor' : 15, 
    'n_batch' : 3000, 
    'learning_rate' : 0.3, 
    'regularization_constant' : 0.3
})

bayseian_personalized_ranking_models = []
for index, bayseian_personalized_ranking_parameter in enumerate(bayseian_personalized_ranking_parameters):
    bayseian_personalized_ranking_models.append(BayseianPersonalizedRankingModel(**bayseian_personalized_ranking_parameter))
    bayseian_personalized_ranking_models[index].training_data_dictionary = training_data_dictionary
    bayseian_personalized_ranking_models[index].fit()

ModelAnalyzerHelper().plot_error_chart(bayseian_personalized_ranking_models)

DataHelper().save_latent_factor_matrix_dictionarys(bayseian_personalized_ranking_models)
DataHelper().save_root_mean_square_errors(bayseian_personalized_ranking_models)
# Out:
# Streaming output truncated to the last 5000 lines.
# debug - root_mean_square_error: 1939.0048557671607
#
# debug - iteration: 213
# debug - root_mean_square_error: 1928.9248862713494
#
# debug - iteration: 214
# debug - root_mean_square_error: 1919.0291848775453
#
# debug - iteration: 215
# debug - root_mean_square_error: 1908.7802777295747
#
# debug - iteration: 216
# debug - root_mean_square_error: 1898.3823208143374
#
# debug - iteration: 217
# debug - root_mean_square_error: 1888.4570393301449
#
# debug - iteration: 218
# debug - root_mean_square_error: 1878.7004571192342
#
# debug - iteration: 219
# debug - root_mean_square_error: 1869.6039116394288
#
# debug - iteration: 220
# debug - root_mean_square_error: 1860.140710491102
#
# debug - iteration: 221
# debug - root_mean_square_error: 1851.0196734265198
#
# debug - iteration: 222
# debug - root_mean_square_error: 1841.9305089128227
#
# debug - iteration: 223
# debug - root_mean_square_error: 1833.108289048617
#
# debug - iteration: 224
# debug - root_mean_square_error: 1823.2578687230537
#
# debug - iteration: 225
# debug - root_mean_square_error: 1814.0171210150531
#
# debug - iteration: 226
# debug - root_mean_square_error: 1804.513378074735
#
# debug - iteration: 227
# debug - root_mean_square_error: 1795.5961743774235
#
# debug - iteration: 228
# debug - root_mean_square_error: 1787.6182782484464
#
# debug - iteration: 229
# debug - root_mean_square_error: 1779.0940969554813
#
# debug - iteration: 230
# debug - root_mean_square_error: 1770.4474557203898
#
# debug - iteration: 231
# debug - root_mean_square_error: 1762.2074190965664
#
# debug - iteration: 232
# debug - root_mean_square_error: 1754.2749159559803
#
# debug - iteration: 233
# debug - root_mean_square_error: 1746.3186561061639
#
# debug - iteration: 234
# debug - root_mean_square_error: 1738.3991173188708
#
# debug - iteration: 235
# debug - root_mean_square_error: 1730.2262723911879
#
# debug - iteration: 236
# debug - root_mean_square_error: 1722.6394107046249
#
# debug - iteration: 237
# debug - root_mean_square_error: 1713.9386799641761
#
# debug - iteration: 238
# debug - root_mean_square_error: 1705.0887513903594
#
# debug - iteration: 239
# debug - root_mean_square_error: 1697.7553711681776
#
# debug - iteration: 240
# debug - root_mean_square_error: 1689.8641418153009
#
# debug - iteration: 241
# debug - root_mean_square_error: 1682.281099049613
#
# debug - iteration: 242
# debug - root_mean_square_error: 1674.7983029157622
#
# debug - iteration: 243
# debug - root_mean_square_error: 1667.3581107053426
#
# debug - iteration: 244
# debug - root_mean_square_error: 1659.7698191944207
#
# debug - iteration: 245
# debug - root_mean_square_error: 1651.5742565335806
#
# debug - iteration: 246
# debug - root_mean_square_error: 1644.6485877790828
#
# debug - iteration: 247
# debug - root_mean_square_error: 1636.9238978753765
#
# debug - iteration: 248
# debug - root_mean_square_error: 1629.8475985538582
#
# debug - iteration: 249
# debug - root_mean_square_error: 1623.0404985483108
#
# debug - iteration: 250
# debug - root_mean_square_error: 1616.5111165459357
#
# debug - iteration: 251
# debug - root_mean_square_error: 1609.0591014244858
#
# debug - iteration: 252
# debug - root_mean_square_error: 1602.1258873109143
#
# debug - iteration: 253
# debug - root_mean_square_error: 1595.2153761547959
#
# debug - iteration: 254
# debug - root_mean_square_error: 1587.9530345519302
#
# debug - iteration: 255
# debug - root_mean_square_error: 1581.4367486672345
#
# debug - iteration: 256
# debug - root_mean_square_error: 1575.5129563991354
#
# debug - iteration: 257
# debug - root_mean_square_error: 1569.1708435375513
#
# debug - iteration: 258
# debug - root_mean_square_error: 1562.3304828261287
#
# debug - iteration: 259
# debug - root_mean_square_error: 1555.9157512133322
#
# debug - iteration: 260
# debug - root_mean_square_error: 1549.8903263447949
#
# debug - iteration: 261
# debug - root_mean_square_error: 1543.6038472617154
#
# debug - iteration: 262
# debug - root_mean_square_error: 1537.9240198507216
#
# debug - iteration: 263
# debug - root_mean_square_error: 1531.7715817210778
#
# debug - iteration: 264
# debug - root_mean_square_error: 1526.1520616053076
#
# debug - iteration: 265
# debug - root_mean_square_error: 1519.9537868682376
#
# debug - iteration: 266
# debug - root_mean_square_error: 1514.1590526114135
#
# debug - iteration: 267
# debug - root_mean_square_error: 1508.1907579106578
#
# debug - iteration: 268
# debug - root_mean_square_error: 1502.6979944951756
#
# debug - iteration: 269
# debug - root_mean_square_error: 1496.694643277123
#
# debug - iteration: 270
# debug - root_mean_square_error: 1490.9090471269885
#
# debug - iteration: 271
# debug - root_mean_square_error: 1485.2248143430986
#
# debug - iteration: 272
# debug - root_mean_square_error: 1479.6328360804096
#
# debug - iteration: 273
# debug - root_mean_square_error: 1474.0264635046772
#
# debug - iteration: 274
# debug - root_mean_square_error: 1468.462328502343
#
# debug - iteration: 275
# debug - root_mean_square_error: 1462.9883221089376
#
# debug - iteration: 276
# debug - root_mean_square_error: 1457.407306520958
#
# debug - iteration: 277
# debug - root_mean_square_error: 1452.3028127116995
#
# debug - iteration: 278
# debug - root_mean_square_error: 1447.5715540734789
#
# debug - iteration: 279
# debug - root_mean_square_error: 1442.431623669081
#
# debug - iteration: 280
# debug - root_mean_square_error: 1436.6606868507663
#
# debug - iteration: 281
# debug - root_mean_square_error: 1431.3090193735945
#
# debug - iteration: 282
# debug - root_mean_square_error: 1425.7002405785222
#
# debug - iteration: 283
# debug - root_mean_square_error: 1420.652877847545
#
# debug - iteration: 284
# debug - root_mean_square_error: 1415.3663667694511
#
# debug - iteration: 285
# debug - root_mean_square_error: 1410.0826084420876
#
# debug - iteration: 286
# debug - root_mean_square_error: 1405.3290780177067
#
# debug - iteration: 287
# debug - root_mean_square_error: 1400.4779193416261
#
# debug - iteration: 288
# debug - root_mean_square_error: 1395.8599847721696
#
# debug - iteration: 289
# debug - root_mean_square_error: 1391.240274209995
#
# debug - iteration: 290
# debug - root_mean_square_error: 1386.6125106765564
#
# debug - iteration: 291
# debug - root_mean_square_error: 1381.4254182366683
#
# debug - iteration: 292
# debug - root_mean_square_error: 1376.3694448487124
#
# debug - iteration: 293
# debug - root_mean_square_error: 1371.699856260883
#
# debug - iteration: 294
# debug - root_mean_square_error: 1366.7368006592674
#
# debug - iteration: 295
# debug - root_mean_square_error: 1362.155544381409
#
# debug - iteration: 296
# debug - root_mean_square_error: 1357.5330867157354
#
# debug - iteration: 297
# debug - root_mean_square_error: 1352.902414721464
#
# debug - iteration: 298
# debug - root_mean_square_error: 1348.995680558387
#
# debug - iteration: 299
# debug - root_mean_square_error: 1345.0009422109958
#
# debug - iteration: 300
# debug - root_mean_square_error: 1340.804970013417
#
# debug - iteration: 301
# debug - root_mean_square_error: 1335.6459584255547
#
# debug - iteration: 302
# debug - root_mean_square_error: 1331.694528682561
#
# debug - iteration: 303
# debug - root_mean_square_error: 1327.146732828926
#
# debug - iteration: 304
# debug - root_mean_square_error: 1323.0831907345664
#
# debug - iteration: 305
# debug - root_mean_square_error: 1319.5390679950578
#
# debug - iteration: 306
# debug - root_mean_square_error: 1315.4647945505146
#
# debug - iteration: 307
# debug - root_mean_square_error: 1311.2735544953016
#
# debug - iteration: 308
# debug - root_mean_square_error: 1307.1251617211738
#
# debug - iteration: 309
# debug - root_mean_square_error: 1303.0716665846383
#
# debug - iteration: 310
# debug - root_mean_square_error: 1299.5585858767276
#
# debug - iteration: 311
# debug - root_mean_square_error: 1295.8397790704357
#
# debug - iteration: 312
# debug - root_mean_square_error: 1291.4110884495262
#
# debug - iteration: 313
# debug - root_mean_square_error: 1287.2150440724633
#
# debug - iteration: 314
# debug - root_mean_square_error: 1283.6843251099374
#
# debug - iteration: 315
# debug - root_mean_square_error: 1280.0903734375142
#
# debug - iteration: 316
# debug - root_mean_square_error: 1276.6609053233165
#
# debug - iteration: 317
# debug - root_mean_square_error: 1273.3084151934459
#
# debug - iteration: 318
# debug - root_mean_square_error: 1269.7915177840314
#
# debug - iteration: 319
# debug - root_mean_square_error: 1266.1619431568156
#
# debug - iteration: 320
# debug - root_mean_square_error: 1262.6537022169541
#
# debug - iteration: 321
# debug - root_mean_square_error: 1258.8495672676142
#
# debug - iteration: 322
# debug - root_mean_square_error: 1254.8225351447063
#
# debug - iteration: 323
# debug - root_mean_square_error: 1251.423574541177
#
# debug - iteration: 324
# debug - root_mean_square_error: 1247.869865189807
#
# debug - iteration: 325
# debug - root_mean_square_error: 1244.2506189584144
#
# debug - iteration: 326
# debug - root_mean_square_error: 1241.17707627213
#
# debug - iteration: 327
# debug - root_mean_square_error: 1237.7696034661308
#
# debug - iteration: 328
# debug - root_mean_square_error: 1234.679759342926
#
# debug - iteration: 329
# debug - root_mean_square_error: 1231.8702001693314
#
# debug - iteration: 330
# debug - root_mean_square_error: 1228.4372421691771
#
# debug - iteration: 331
# debug - root_mean_square_error: 1225.660593494899
#
# debug - iteration: 332
# debug - root_mean_square_error: 1222.4208432412922
#
# debug - iteration: 333
# debug - root_mean_square_error: 1219.5735607715055
#
# debug - iteration: 334
# debug - root_mean_square_error: 1216.544808375836
#
# debug - iteration: 335
# debug - root_mean_square_error: 1213.6440082961676
#
# debug - iteration: 336
# debug - root_mean_square_error: 1210.4699977847697
#
# debug - iteration: 337
# debug - root_mean_square_error: 1207.8278872239357
#
# debug - iteration: 338
# debug - root_mean_square_error: 1205.0701492980324
#
# debug - iteration: 339
# debug - root_mean_square_error: 1202.757620247361
#
# debug - iteration: 340
# debug - root_mean_square_error: 1199.6301410345925
#
# debug - iteration: 341
# debug - root_mean_square_error: 1196.7052330302665
#
# debug - iteration: 342
# debug - root_mean_square_error: 1194.135725372679
#
# debug - iteration: 343
# debug - root_mean_square_error: 1191.339762557469
#
# debug - iteration: 344
# debug - root_mean_square_error: 1188.5753185559379
#
# debug - iteration: 345
# debug - root_mean_square_error: 1185.3289939183805
#
# debug - iteration: 346
# debug - root_mean_square_error: 1183.0335313534472
#
# debug - iteration: 347
# debug - root_mean_square_error: 1180.4824572016087
#
# debug - iteration: 348
# debug - root_mean_square_error: 1178.0221875676243
#
# debug - iteration: 349
# debug - root_mean_square_error: 1175.0971614831813
#
# debug - iteration: 350
# debug - root_mean_square_error: 1172.6928629550528
#
# debug - iteration: 351
# debug - root_mean_square_error: 1169.644276800935
#
# debug - iteration: 352
# debug - root_mean_square_error: 1167.1567233362518
#
# debug - iteration: 353
# debug - root_mean_square_error: 1164.9009623313104
#
# debug - iteration: 354
# debug - root_mean_square_error: 1162.4088675291248
#
# debug - iteration: 355
# debug - root_mean_square_error: 1160.1640502366893
#
# debug - iteration: 356
# debug - root_mean_square_error: 1157.7886273166953
#
# debug - iteration: 357
# debug - root_mean_square_error: 1155.6614601139058
#
# debug - iteration: 358
# debug - root_mean_square_error: 1153.4704147680372
#
# debug - iteration: 359
# debug - root_mean_square_error: 1150.9787350194704
#
# debug - iteration: 360
# debug - root_mean_square_error: 1148.9706740444474
#
# debug - iteration: 361
# debug - root_mean_square_error: 1146.9143423274068
#
# debug - iteration: 362
# debug - root_mean_square_error: 1144.2677122763557
#
# debug - iteration: 363
# debug - root_mean_square_error: 1141.7726236443339
#
# debug - iteration: 364
# debug - root_mean_square_error: 1140.0025044563715
#
# debug - iteration: 365
# debug - root_mean_square_error: 1138.2913185462132
#
# debug - iteration: 366
# debug - root_mean_square_error: 1136.2631532353632
#
# debug - iteration: 367
# debug - root_mean_square_error: 1134.4044968357362
#
# debug - iteration: 368
# debug - root_mean_square_error: 1132.1614758430123
#
# debug - iteration: 369
# debug - root_mean_square_error: 1130.5577741692007
#
# debug - iteration: 370
# debug - root_mean_square_error: 1128.4479629411398
#
# debug - iteration: 371
# debug - root_mean_square_error: 1126.4673074356892
#
# debug - iteration: 372
# debug - root_mean_square_error: 1124.5915627866566
#
# debug - iteration: 373
# debug - root_mean_square_error: 1123.0894052527137
#
# debug - iteration: 374
# debug - root_mean_square_error: 1121.4987387453912
#
# debug - iteration: 375
# debug - root_mean_square_error: 1119.0972110629841
#
# debug - iteration: 376
# debug - root_mean_square_error: 1116.918469851964
#
# debug - iteration: 377
# debug - root_mean_square_error: 1114.823665073698
#
# debug - iteration: 378
# debug - root_mean_square_error: 1112.9635603604502
#
# debug - iteration: 379
# debug - root_mean_square_error: 1111.315140472533
#
# debug - iteration: 380
# debug - root_mean_square_error: 1109.610273710535
#
# debug - iteration: 381
# debug - root_mean_square_error: 1108.2343190254223
#
# debug - iteration: 382
# debug - root_mean_square_error: 1106.4824776464998
#
# debug - iteration: 383
# debug - root_mean_square_error: 1104.599732650426
#
# debug - iteration: 384
# debug - root_mean_square_error: 1102.610857343622
#
# debug - iteration: 385
# debug - root_mean_square_error: 1100.8420705442106
#
# debug - iteration: 386
# debug - root_mean_square_error: 1099.2653980498112
#
# debug - iteration: 387
# debug - root_mean_square_error: 1097.6401397404566
#
# debug - iteration: 388
# debug - root_mean_square_error: 1096.2346343204265
#
# debug - iteration: 389
# debug - root_mean_square_error: 1094.8747842760185
#
# debug - iteration: 390
# debug - root_mean_square_error: 1093.6193064501126
#
# debug - iteration: 391
# debug - root_mean_square_error: 1092.193143629463
#
# debug - iteration: 392
# debug - root_mean_square_error: 1090.2934068431261
#
# debug - iteration: 393
# debug - root_mean_square_error: 1089.4799391294766
#
# debug - iteration: 394
# debug - root_mean_square_error: 1088.24284663052
#
# debug - iteration: 395
# debug - root_mean_square_error: 1087.1002727925584
#
# debug - iteration: 396
# debug - root_mean_square_error: 1085.560884340642
#
# debug - iteration: 397
# debug - root_mean_square_error: 1083.9526462270471
#
# debug - iteration: 398
# debug - root_mean_square_error: 1082.8823879921908
#
# debug - iteration: 399
# debug - root_mean_square_error: 1081.101169763969
#
# debug - iteration: 400
# debug - root_mean_square_error: 1079.8957031287862
#
# debug - iteration: 401
# debug - root_mean_square_error: 1079.055348227227
#
# debug - iteration: 402
# debug - root_mean_square_error: 1078.1544531768077
#
# debug - iteration: 403
# debug - root_mean_square_error: 1076.897037155528
#
# debug - iteration: 404
# debug - root_mean_square_error: 1076.4287417437565
#
# debug - iteration: 405
# debug - root_mean_square_error: 1075.4066313950448
#
# debug - iteration: 406
# debug - root_mean_square_error: 1074.3975067177812
#
# debug - iteration: 407
# debug - root_mean_square_error: 1073.5440129304882
#
# debug - iteration: 408
# debug - root_mean_square_error: 1072.3925873097871
#
# debug - iteration: 409
# debug - root_mean_square_error: 1071.2283041954367
#
# debug - iteration: 410
# debug - root_mean_square_error: 1070.5965085885298
#
# debug - iteration: 411
# debug - root_mean_square_error: 1069.179868981388
#
# debug - iteration: 412
# debug - root_mean_square_error: 1068.4440245469275
#
# debug - iteration: 413
# debug - root_mean_square_error: 1067.3670263750548
#
# debug - iteration: 414
# debug - root_mean_square_error: 1065.9603511992268
#
# debug - iteration: 415
# debug - root_mean_square_error: 1065.1932512049245
#
# debug - iteration: 416
# debug - root_mean_square_error: 1064.291061563142
#
# debug - iteration: 417
# debug - root_mean_square_error: 1063.287819900814
#
# debug - iteration: 418
# debug - root_mean_square_error: 1062.9098940072913
#
# debug - iteration: 419
# debug - root_mean_square_error: 1062.2147859242082
#
# debug - iteration: 420
# debug - root_mean_square_error: 1061.2238600270139
#
# debug - iteration: 421
# debug - root_mean_square_error: 1060.7475998223308
#
# debug - iteration: 422
# debug - root_mean_square_error: 1059.568965002424
#
# debug - iteration: 423
# debug - root_mean_square_error: 1059.0608449440313
#
# debug - iteration: 424
# debug - root_mean_square_error: 1058.4034851541232
#
# debug - iteration: 425
# debug - root_mean_square_error: 1057.8164935369668
#
# debug - iteration: 426
# debug - root_mean_square_error: 1056.9256387228595
#
# debug - iteration: 427
# debug - root_mean_square_error: 1055.8675117905402
#
# debug - iteration: 428
# debug - root_mean_square_error: 1055.2922435581277
#
# debug - iteration: 429
# debug - root_mean_square_error: 1054.7436585857567
#
# debug - iteration: 430
# debug - root_mean_square_error: 1054.5770594739788
#
# debug - iteration: 431
# debug - root_mean_square_error: 1053.836397397804
#
# debug - iteration: 432
# debug - root_mean_square_error: 1053.4264604586906
#
# debug - iteration: 433
# debug - root_mean_square_error: 1052.4694955756652
#
# debug - iteration: 434
# debug - root_mean_square_error: 1051.9924136016793
#
# debug - iteration: 435
# debug - root_mean_square_error: 1051.5299317825722
#
# debug - iteration: 436
# debug - root_mean_square_error: 1051.0630875020356
#
# debug - iteration: 437
# debug - root_mean_square_error: 1050.0848840605859
#
# debug - iteration: 438
# debug - root_mean_square_error: 1049.460767050881
#
# debug - iteration: 439
# debug - root_mean_square_error: 1049.0665091247354
#
# debug - iteration: 440
# debug - root_mean_square_error: 1049.0690202253477
#
# debug - iteration: 441
# debug - root_mean_square_error: 1048.8888990352111
#
# debug - iteration: 442
# debug - root_mean_square_error: 1048.8136014317604
#
# debug - iteration: 443
# debug - root_mean_square_error: 1048.4242352464898
#
# debug - iteration: 444
# debug - root_mean_square_error: 1048.1774939266497
#
# debug - iteration: 445
# debug - root_mean_square_error: 1047.7346447967361
#
# debug - iteration: 446
# debug - root_mean_square_error: 1047.8102934970047
#
# debug - iteration: 447
# debug - root_mean_square_error: 1048.0116715337283
#
# debug - iteration: 448
# debug - root_mean_square_error: 1047.501771893622
#
# debug - iteration: 449
# debug - root_mean_square_error: 1047.1859495574543
#
# debug - iteration: 450
# debug - root_mean_square_error: 1047.1745008207038
#
# debug - iteration: 451
# debug - root_mean_square_error: 1046.8506798202752
#
# debug - iteration: 452
# debug - root_mean_square_error: 1047.3961890692212
#
# debug - iteration: 453
# debug - root_mean_square_error: 1047.3405798886747
#
# debug - iteration: 454
# debug - root_mean_square_error: 1047.3961204364944
#
# debug - iteration: 455
# debug - root_mean_square_error: 1047.0723751832033
#
# debug - iteration: 456
# debug - root_mean_square_error: 1047.5385235890753
#
# debug - iteration: 457
# debug - root_mean_square_error: 1047.2469229314652
#
# debug - iteration: 458
# debug - root_mean_square_error: 1047.7228609712233
#
# debug - iteration: 459
# debug - root_mean_square_error: 1047.3809316393802
#
# debug - iteration: 460
# debug - root_mean_square_error: 1047.4343480661264
#
# debug - iteration: 461
# debug - root_mean_square_error: 1047.4659101104348
#
# debug - iteration: 462
# debug - root_mean_square_error: 1047.910493526528
#
# debug - iteration: 1
# debug - root_mean_square_error: 11610.370683014116
#
# debug - iteration: 2
# debug - root_mean_square_error: 11350.323789188038
#
# debug - iteration: 3
# debug - root_mean_square_error: 11098.264215667485
#
# debug - iteration: 4
# debug - root_mean_square_error: 10850.978624579975
#
# debug - iteration: 5
# debug - root_mean_square_error: 10613.804822555758
#
# debug - iteration: 6
# debug - root_mean_square_error: 10387.847081634338
#
# debug - iteration: 7
# debug - root_mean_square_error: 10163.962468152573
#
# debug - iteration: 8
# debug - root_mean_square_error: 9953.583144906777
#
# debug - iteration: 9
# debug - root_mean_square_error: 9741.844182598024
#
# debug - iteration: 10
# debug - root_mean_square_error: 9541.177692888088
#
# debug - iteration: 11
# debug - root_mean_square_error: 9342.807750480975
#
# debug - iteration: 12
# debug - root_mean_square_error: 9148.039292973255
#
# debug - iteration: 13
# debug - root_mean_square_error: 8960.369653585807
#
# debug - iteration: 14
# debug - root_mean_square_error: 8773.846628403207
#
# debug - iteration: 15
# debug - root_mean_square_error: 8599.702751857878
#
# debug - iteration: 16
# debug - root_mean_square_error: 8429.243666457623
#
# debug - iteration: 17
# debug - root_mean_square_error: 8258.343400077021
#
# debug - iteration: 18
# debug - root_mean_square_error: 8090.173365956262
#
# debug - iteration: 19
# debug - root_mean_square_error: 7931.570576886792
#
# debug - iteration: 20
# debug - root_mean_square_error: 7774.845997205686
#
# debug - iteration: 21
# debug - root_mean_square_error: 7621.1992595767115
#
# debug - iteration: 22
# debug - root_mean_square_error: 7467.339051809195
#
# debug - iteration: 23
# debug - root_mean_square_error: 7324.999135075832
#
# debug - iteration: 24
# debug - root_mean_square_error: 7188.508295999801
#
# debug - iteration: 25
# debug - root_mean_square_error: 7053.89742662992
#
# debug - iteration: 26
# debug - root_mean_square_error: 6914.890298681677
#
# debug - iteration: 27
# debug - root_mean_square_error: 6785.960163384413
#
# debug - iteration: 28
# debug - root_mean_square_error: 6664.089230835214
#
# debug - iteration: 29
# debug - root_mean_square_error: 6537.817407090145
#
# debug - iteration: 30
# debug - root_mean_square_error: 6416.201878136934
#
# debug - iteration: 31
# debug - root_mean_square_error: 6301.91812411127
#
# debug - iteration: 32
# debug - root_mean_square_error: 6184.7281631430815
#
# debug - iteration: 33
# debug - root_mean_square_error: 6073.9743658329035
#
# debug - iteration: 34
# debug - root_mean_square_error: 5966.463738013915
#
# debug - iteration: 35
# debug - root_mean_square_error: 5858.906250375374
#
# debug - iteration: 36
# debug - root_mean_square_error: 5756.342493354978
#
# debug - iteration: 37
# debug - root_mean_square_error: 5653.489039572337
#
# debug - iteration: 38
# debug - root_mean_square_error: 5551.654908054701
#
# debug - iteration: 39
# debug - root_mean_square_error: 5457.136542128246
#
# debug - iteration: 40
# debug - root_mean_square_error: 5363.90003233985
#
# debug - iteration: 41
# debug - root_mean_square_error: 5269.471695071347
#
# debug - iteration: 42
# debug - root_mean_square_error: 5176.810587043316
#
# debug - iteration: 43
# debug - root_mean_square_error: 5087.723137239615
#
# debug - iteration: 44
# debug - root_mean_square_error: 5004.647688557942
#
# debug - iteration: 45
# debug - root_mean_square_error: 4917.760720907445
#
# debug - iteration: 46
# debug - root_mean_square_error: 4835.582382255125
#
# debug - iteration: 47
# debug - root_mean_square_error: 4753.4871519800445
#
# debug - iteration: 48
# debug - root_mean_square_error: 4674.843889981755
#
# debug - iteration: 49
# debug - root_mean_square_error: 4597.97321419051
#
# debug - iteration: 50
# debug - root_mean_square_error: 4522.257930163738
#
# debug - iteration: 51
# debug - root_mean_square_error: 4450.172167523575
#
# debug - iteration: 52
# debug - root_mean_square_error: 4378.249590967969
#
# debug - iteration: 53
# debug - root_mean_square_error: 4306.492998819945
#
# debug - iteration: 54
# debug - root_mean_square_error: 4237.059203421874
#
# debug - iteration: 55
# debug - root_mean_square_error: 4170.183539116012
#
# debug - iteration: 56
# debug - root_mean_square_error: 4105.017494074216
#
# debug - iteration: 57
# debug - root_mean_square_error: 4043.9818854521723
#
# debug - iteration: 58
# debug - root_mean_square_error: 3980.5321140495216
#
# debug - iteration: 59
# debug - root_mean_square_error: 3919.7378584683606
#
# debug - iteration: 60
# debug - root_mean_square_error: 3861.6507540730263
#
# debug - iteration: 61
# debug - root_mean_square_error: 3803.22421873823
#
# debug - iteration: 62
# debug - root_mean_square_error: 3746.7715749208865
#
# debug - iteration: 63
# debug - root_mean_square_error: 3692.5245608192945
#
# debug - iteration: 64
# debug - root_mean_square_error: 3637.6239167921754
#
# debug - iteration: 65
# debug - root_mean_square_error: 3584.145366301254
#
# debug - iteration: 66
# debug - root_mean_square_error: 3533.060704738434
#
# debug - iteration: 67
# debug - root_mean_square_error: 3480.459610348278
#
# debug - iteration: 68
# debug - root_mean_square_error: 3430.9405112830764
#
# debug - iteration: 69
# debug - root_mean_square_error: 3380.5040675119394
#
# debug - iteration: 70
# debug - root_mean_square_error: 3332.141429331246
#
# debug - iteration: 71
# debug - root_mean_square_error: 3285.8036175147026
#
# debug - iteration: 72
# debug - root_mean_square_error: 3242.351551547737
#
# debug - iteration: 73
# debug - root_mean_square_error: 3197.086913434651
#
# debug - iteration: 74
# debug - root_mean_square_error: 3152.4155611548977
#
# debug - iteration: 75
# debug - root_mean_square_error: 3108.2398428883625
#
# debug - iteration: 76
# debug - root_mean_square_error: 3067.407613359895
#
# debug - iteration: 77
# debug - root_mean_square_error: 3026.7240019988412
#
# debug - iteration: 78
# debug - root_mean_square_error: 2987.089925525197
#
# debug - iteration: 79
# debug - root_mean_square_error: 2948.081141218449
#
# debug - iteration: 80
# debug - root_mean_square_error: 2908.3412881249938
#
# debug - iteration: 81
# debug - root_mean_square_error: 2870.43506354034
#
# debug - iteration: 82
# debug - root_mean_square_error: 2834.172953544809
#
# debug - iteration: 83
# debug - root_mean_square_error: 2797.7650653304677
#
# debug - iteration: 84
# debug - root_mean_square_error: 2762.786436915329
#
# debug - iteration: 85
# debug - root_mean_square_error: 2727.6753906376844
#
# debug - iteration: 86
# debug - root_mean_square_error: 2694.1180939099036
#
# debug - iteration: 87
# debug - root_mean_square_error: 2659.322278528908
#
# debug - iteration: 88
# debug - root_mean_square_error: 2627.076547712769
#
# debug - iteration: 89
# debug - root_mean_square_error: 2596.03363991065
#
# debug - iteration: 90
# debug - root_mean_square_error: 2564.1494898698243
#
# debug - iteration: 91
# debug - root_mean_square_error: 2533.4222764921965
#
# debug - iteration: 92
# debug - root_mean_square_error: 2502.135382456185
#
# debug - iteration: 93
# debug - root_mean_square_error: 2473.3541770222732
#
# debug - iteration: 94
# debug - root_mean_square_error: 2444.6605149442003
#
# debug - iteration: 95
# debug - root_mean_square_error: 2417.1032098943638
#
# debug - iteration: 96
# debug - root_mean_square_error: 2389.5053844963113
#
# debug - iteration: 97
# debug - root_mean_square_error: 2361.132679122087
#
# debug - iteration: 98
# debug - root_mean_square_error: 2333.326389106535
#
# debug - iteration: 99
# debug - root_mean_square_error: 2306.7331846421494
#
# debug - iteration: 100
# debug - root_mean_square_error: 2281.867060062133
#
# debug - iteration: 101
# debug - root_mean_square_error: 2255.7441459563374
#
# debug - iteration: 102
# debug - root_mean_square_error: 2230.6593093446854
#
# debug - iteration: 103
# debug - root_mean_square_error: 2205.652881426786
#
# debug - iteration: 104
# debug - root_mean_square_error: 2182.6304198081566
#
# debug - iteration: 105
# debug - root_mean_square_error: 2158.9360419170175
#
# debug - iteration: 106
# debug - root_mean_square_error: 2135.8479394120545
#
# debug - iteration: 107
# debug - root_mean_square_error: 2113.453406089527
#
# debug - iteration: 108
# debug - root_mean_square_error: 2091.7496655845225
#
# debug - iteration: 109
# debug - root_mean_square_error: 2069.790206530319
#
# debug - iteration: 110
# debug - root_mean_square_error: 2047.9536549213603
#
# debug - iteration: 111
# debug - root_mean_square_error: 2026.8083670835522
#
# debug - iteration: 112
# debug - root_mean_square_error: 2006.3006045751163
#
# debug - iteration: 113
# debug - root_mean_square_error: 1986.2903463008347
#
# debug - iteration: 114
# debug - root_mean_square_error: 1966.5568909321546
#
# debug - iteration: 115
# debug - root_mean_square_error: 1946.0134335338232
#
# debug - iteration: 116
# debug - root_mean_square_error: 1926.129973069432
#
# debug - iteration: 117
# debug - root_mean_square_error: 1907.6660070541868
#
# debug - iteration: 118
# debug - root_mean_square_error: 1889.4551588982276
#
# debug - iteration: 119
# debug - root_mean_square_error: 1871.7075078788737
#
# debug - iteration: 120
# debug - root_mean_square_error: 1853.7503909484178
#
# debug - iteration: 121
# debug - root_mean_square_error: 1836.671381748578
#
# debug - iteration: 122
# debug - root_mean_square_error: 1820.382077305417
#
# debug - iteration: 123
# debug - root_mean_square_error: 1804.0008278426894
#
# debug - iteration: 124
# debug - root_mean_square_error: 1787.8291206207273
#
# debug - iteration: 125
# debug - root_mean_square_error: 1771.6279404235686
#
# debug - iteration: 126
# debug - root_mean_square_error: 1755.4650989420466
#
# debug - iteration: 127
# debug - root_mean_square_error: 1739.347339961169
#
# debug - iteration: 128
# debug - root_mean_square_error: 1724.5296102127613
#
# debug - iteration: 129
# debug - root_mean_square_error: 1708.8134396014918
#
# debug - iteration: 130
# debug - root_mean_square_error: 1693.266665196735
#
# debug - iteration: 131
# debug - root_mean_square_error: 1678.573535373102
#
# debug - iteration: 132
# debug - root_mean_square_error: 1664.2850696939163
#
# debug - iteration: 133
# debug - root_mean_square_error: 1649.9793950312505
#
# debug - iteration: 134
# debug - root_mean_square_error: 1635.118351155062
#
# debug - iteration: 135
# debug - root_mean_square_error: 1621.4358459554833
#
# debug - iteration: 136
# debug - root_mean_square_error: 1608.2255408137148
#
# debug - iteration: 137
# debug - root_mean_square_error: 1594.8807585055736
#
# debug - iteration: 138
# debug - root_mean_square_error: 1582.3622380507438
#
# debug - iteration: 139
# debug - root_mean_square_error: 1569.8766491854783
#
# debug - iteration: 140
# debug - root_mean_square_error: 1557.4044199220043
#
# debug - iteration: 141
# debug - root_mean_square_error: 1544.5094477112416
#
# debug - iteration: 142
# debug - root_mean_square_error: 1532.2981363148674
#
# debug - iteration: 143
# debug - root_mean_square_error: 1520.7769445826123
#
# debug - iteration: 144
# debug - root_mean_square_error: 1509.4377021613284
#
# debug - iteration: 145
# debug - root_mean_square_error: 1498.1251339129867
#
# debug - iteration: 146
# debug - root_mean_square_error: 1486.7849560836141
#
# debug - iteration: 147
# debug - root_mean_square_error: 1475.886806628397
#
# debug - iteration: 148
# debug - root_mean_square_error: 1465.4672872977385
#
# debug - iteration: 149
# debug - root_mean_square_error: 1455.020473117716
#
# debug - iteration: 150
# debug - root_mean_square_error: 1444.7855771550212
#
# debug - iteration: 151
# debug - root_mean_square_error: 1434.604865637272
#
# debug - iteration: 152
# debug - root_mean_square_error: 1423.7047767832146
#
# debug - iteration: 153
# debug - root_mean_square_error: 1413.84550470509
#
# debug - iteration: 154
# debug - root_mean_square_error: 1404.1300076338107
#
# debug - iteration: 155
# debug - root_mean_square_error: 1394.0834643054818
#
# debug - iteration: 156
# debug - root_mean_square_error: 1385.3281268623198
#
# debug - iteration: 157
# debug - root_mean_square_error: 1377.0051053018797
#
# debug - iteration: 158
# debug - root_mean_square_error: 1367.8564688131862
#
# debug - iteration: 159
# debug - root_mean_square_error: 1358.6351415862848
#
# debug - iteration: 160
# debug - root_mean_square_error: 1349.7971786053329
#
# debug - iteration: 161
# debug - root_mean_square_error: 1341.4855223220889
#
# debug - iteration: 162
# debug - root_mean_square_error: 1333.3952271884132
#
# debug - iteration: 163
# debug - root_mean_square_error: 1324.67996175152
#
# debug - iteration: 164
# debug - root_mean_square_error: 1316.5547383992903
#
# debug - iteration: 165
# debug - root_mean_square_error: 1308.760247420285
#
# debug - iteration: 166
# debug - root_mean_square_error: 1300.6757184334253
#
# debug - iteration: 167
# debug - root_mean_square_error: 1292.8701239946986
#
# debug - iteration: 168
# debug - root_mean_square_error: 1285.5294932748016
#
# debug - iteration: 169
# debug - root_mean_square_error: 1278.0714240685304
#
# debug - iteration: 170
# debug - root_mean_square_error: 1271.0574189926433
#
# debug - iteration: 171
# debug - root_mean_square_error: 1263.6730492722156
#
# debug - iteration: 172
# debug - root_mean_square_error: 1256.5227972797402
#
# debug - iteration: 173
# debug - root_mean_square_error: 1249.6572372606452
#
# debug - iteration: 174
# debug - root_mean_square_error: 1242.815438418988
#
# debug - iteration: 175
# debug - root_mean_square_error: 1235.7384298566253
#
# debug - iteration: 176
# debug - root_mean_square_error: 1229.2514917559618
#
# debug - iteration: 177
# debug - root_mean_square_error: 1223.298984648294
#
# debug - iteration: 178
# debug - root_mean_square_error: 1216.882814158992
#
# debug - iteration: 179
# debug - root_mean_square_error: 1210.583968818293
#
# debug - iteration: 180
# debug - root_mean_square_error: 1204.683551256661
#
# debug - iteration: 181
# debug - root_mean_square_error: 1198.0200882431893
#
# debug - iteration: 182
# debug - root_mean_square_error: 1192.1984159257333
#
# debug - iteration: 183
# debug - root_mean_square_error: 1185.9590105055734
#
# debug - iteration: 184
# debug - root_mean_square_error: 1180.2059415562808
#
# debug - iteration: 185
# debug - root_mean_square_error: 1174.5954221231364
#
# debug - iteration: 186
# debug - root_mean_square_error: 1169.2968443997115
#
# debug - iteration: 187
# debug - root_mean_square_error: 1163.9399690942937
#
# debug - iteration: 188
# debug - root_mean_square_error: 1158.752318102155
#
# debug - iteration: 189
# debug - root_mean_square_error: 1153.6482873881366
#
# debug - iteration: 190
# debug - root_mean_square_error: 1148.373243483684
#
# debug - iteration: 191
# debug - root_mean_square_error: 1143.2326360825798
#
# debug - iteration: 192
# debug - root_mean_square_error: 1138.687463174995
#
# debug - iteration: 193
# debug - root_mean_square_error: 1133.9325461701126
#
# debug - iteration: 194
# debug - root_mean_square_error: 1128.359448150614
#
# debug - iteration: 195
# debug - root_mean_square_error: 1123.5241164698873
#
# debug - iteration: 196
# debug - root_mean_square_error: 1118.72628277538
#
# debug - iteration: 197
# debug - root_mean_square_error: 1113.5451068527009
#
# debug - iteration: 198
# debug - root_mean_square_error: 1109.7377909706013
#
# debug - iteration: 199
# debug - root_mean_square_error: 1106.2538712201806
#
# debug - iteration: 200
# debug - root_mean_square_error: 1101.8910244996673
#
# debug - iteration: 201
# debug - root_mean_square_error: 1097.7303229996808
#
# debug - iteration: 202
# debug - root_mean_square_error: 1093.6834818013879
#
# debug - iteration: 203
# debug - root_mean_square_error: 1089.258337848229
#
# debug - iteration: 204
# debug - root_mean_square_error: 1085.2214333887644
#
# debug - iteration: 205
# debug - root_mean_square_error: 1081.5156263859355
#
# debug - iteration: 206
# debug - root_mean_square_error: 1077.1365108106193
#
# debug - iteration: 207
# debug - root_mean_square_error: 1073.2661407946487
#
# debug - iteration: 208
# debug - root_mean_square_error: 1069.379188058068
#
# debug - iteration: 209
# debug - root_mean_square_error: 1066.0172657755995
#
# debug - iteration: 210
# debug - root_mean_square_error: 1062.4047014611203
#
# debug - iteration: 211
# debug - root_mean_square_error: 1058.855511931164
#
# debug - iteration: 212
# debug - root_mean_square_error: 1055.8750298216082
#
# debug - iteration: 213
# debug - root_mean_square_error: 1052.6870118775018
#
# debug - iteration: 214
# debug - root_mean_square_error: 1049.5954815401221
#
# debug - iteration: 215
# debug - root_mean_square_error: 1046.4463150526667
#
# debug - iteration: 216
# debug - root_mean_square_error: 1043.6034649406784
#
# debug - iteration: 217
# debug - root_mean_square_error: 1040.4514803753177
#
# debug - iteration: 218
# debug - root_mean_square_error: 1037.8551177792283
#
# debug - iteration: 219
# debug - root_mean_square_error: 1034.4791326699067
#
# debug - iteration: 220
# debug - root_mean_square_error: 1031.3175341722333
#
# debug - iteration: 221
# debug - root_mean_square_error: 1028.6428556686606
#
# debug - iteration: 222
# debug - root_mean_square_error: 1026.0929386033295
#
# debug - iteration: 223
# debug - root_mean_square_error: 1023.7856180631721
#
# debug - iteration: 224
# debug - root_mean_square_error: 1021.5736768004564
#
# debug - iteration: 225
# debug - root_mean_square_error: 1019.1001776887267
#
# debug - iteration: 226
# debug - root_mean_square_error: 1016.7401627123822
#
# debug - iteration: 227
# debug - root_mean_square_error: 1014.4947017140199
#
# debug - iteration: 228
# debug - root_mean_square_error: 1012.3005125739646
#
# debug - iteration: 229
# debug - root_mean_square_error: 1010.317245919281
#
# debug - iteration: 230
# debug - root_mean_square_error: 1008.3198010039199
#
# debug - iteration: 231
# debug - root_mean_square_error: 1006.7187419930306
#
# debug - iteration: 232
# debug - root_mean_square_error: 1005.3676438453034
#
# debug - iteration: 233
# debug - root_mean_square_error: 1003.0447669125032
#
# debug - iteration: 234
# debug - root_mean_square_error: 1001.6528068558755
#
# debug - iteration: 235
# debug - root_mean_square_error: 999.826261791556
#
# debug - iteration: 236
# debug - root_mean_square_error: 998.5632618285869
#
# debug - iteration: 237
# debug - root_mean_square_error: 997.0083820121673
#
# debug - iteration: 238
# debug - root_mean_square_error: 995.3999090526468
#
# debug - iteration: 239
# debug - root_mean_square_error: 993.6951286941438
#
# debug - iteration: 240
# debug - root_mean_square_error: 991.9831855518397
#
# debug - iteration: 241
# debug - root_mean_square_error: 990.5045385562028
#
# debug - iteration: 242
# debug - root_mean_square_error: 989.4664894516467
#
# debug - iteration: 243
# debug - root_mean_square_error: 988.3193280877789
#
# debug - iteration: 244
# debug - root_mean_square_error: 987.0099546100311
#
# debug - iteration: 245
# debug - root_mean_square_error: 985.8076629221728
#
# debug - iteration: 246
# debug - root_mean_square_error: 985.0265395090031
#
# debug - iteration: 247
# debug - root_mean_square_error: 983.7252076413067
#
# debug - iteration: 248
# debug - root_mean_square_error: 982.4741422560778
#
# debug - iteration: 249
# debug - root_mean_square_error: 981.8877420012348
#
# debug - iteration: 250
# debug - root_mean_square_error: 980.975729831124
#
# debug - iteration: 251
# debug - root_mean_square_error: 980.5480113404335
#
# debug - iteration: 252
# debug - root_mean_square_error: 979.9923054348537
#
# debug - iteration: 253
# debug - root_mean_square_error: 979.1978225410656
#
# debug - iteration: 254
# debug - root_mean_square_error: 979.2603675346347
#
# debug - iteration: 255
# debug - root_mean_square_error: 978.3901244396812
#
# debug - iteration: 256
# debug - root_mean_square_error: 977.9674988120348
#
# debug - iteration: 257
# debug - root_mean_square_error: 977.6034924613001
#
# debug - iteration: 258
# debug - root_mean_square_error: 977.4205415683076
#
# debug - iteration: 259
# debug - root_mean_square_error: 977.1889736550387
#
# debug - iteration: 260
# debug - root_mean_square_error: 976.9932101587759
#
# debug - iteration: 261
# debug - root_mean_square_error: 976.9173535181286
#
# debug - iteration: 262
# debug - root_mean_square_error: 976.4883405979205
#
# debug - iteration: 263
# debug - root_mean_square_error: 975.922345177788
#
# debug - iteration: 264
# debug - root_mean_square_error: 976.2083476299687
#
# debug - iteration: 265
# debug - root_mean_square_error: 976.7600608784209
#
# debug - iteration: 266
# debug - root_mean_square_error: 977.1722278545658
#
# debug - iteration: 1
# debug - root_mean_square_error: 11514.117163585355
#
# debug - iteration: 2
# debug - root_mean_square_error: 11152.849077701996
#
# debug - iteration: 3
# debug - root_mean_square_error: 10817.782569876857
#
# debug - iteration: 4
# debug - root_mean_square_error: 10494.744794326882
#
# debug - iteration: 5
# debug - root_mean_square_error: 10182.803665564217
#
# debug - iteration: 6
# debug - root_mean_square_error: 9878.920583410954
#
# debug - iteration: 7
# debug - root_mean_square_error: 9589.19102292011
#
# debug - iteration: 8
# debug - root_mean_square_error: 9299.986540231364
#
# debug - iteration: 9
# debug - root_mean_square_error: 9035.47470794521
#
# debug - iteration: 10
# debug - root_mean_square_error: 8773.227945879284
#
# debug - iteration: 11
# debug - root_mean_square_error: 8523.03485132935
#
# debug - iteration: 12
# debug - root_mean_square_error: 8287.00762613141
#
# debug - iteration: 13
# debug - root_mean_square_error: 8063.581656028555
#
# debug - iteration: 14
# debug - root_mean_square_error: 7838.537187436538
#
# debug - iteration: 15
# debug - root_mean_square_error: 7630.160006190468
#
# debug - iteration: 16
# debug - root_mean_square_error: 7420.707971016547
#
# debug - iteration: 17
# debug - root_mean_square_error: 7220.53805347351
#
# debug - iteration: 18
# debug - root_mean_square_error: 7027.887570096712
#
# debug - iteration: 19
# debug - root_mean_square_error: 6846.359033862817
#
# debug - iteration: 20
# debug - root_mean_square_error: 6667.604047996168
#
# debug - iteration: 21
# debug - root_mean_square_error: 6493.705338389252
#
# debug - iteration: 22
# debug - root_mean_square_error: 6326.694117698178
#
# debug - iteration: 23
# debug - root_mean_square_error: 6170.348538618862
#
# debug - iteration: 24
# debug - root_mean_square_error: 6011.654400496373
#
# debug - iteration: 25
# debug - root_mean_square_error: 5864.407624398397
#
# debug - iteration: 26
# debug - root_mean_square_error: 5716.341194759235
#
# debug - iteration: 27
# debug - root_mean_square_error: 5574.266308009415
#
# debug - iteration: 28
# debug - root_mean_square_error: 5438.900608386081
#
# debug - iteration: 29
# debug - root_mean_square_error: 5305.011222124678
#
# debug - iteration: 30
# debug - root_mean_square_error: 5177.8372767737865
#
# debug - iteration: 31
# debug - root_mean_square_error: 5055.685126008376
#
# debug - iteration: 32
# debug - root_mean_square_error: 4938.844645091933
#
# debug - iteration: 33
# debug - root_mean_square_error: 4824.433507154513
#
# debug - iteration: 34
# debug - root_mean_square_error: 4711.927513485197
#
# debug - iteration: 35
# debug - root_mean_square_error: 4604.515724772935
#
# debug - iteration: 36
# debug - root_mean_square_error: 4500.305116500039
#
# debug - iteration: 37
# debug - root_mean_square_error: 4400.622374562061
#
# debug - iteration: 38
# debug - root_mean_square_error: 4303.214744249966
#
# debug - iteration: 39
# debug - root_mean_square_error: 4206.89245755924
#
# debug - iteration: 40
# debug - root_mean_square_error: 4115.841247403983
#
# debug - iteration: 41
# debug - root_mean_square_error: 4028.0539106113956
#
# debug - iteration: 42
# debug - root_mean_square_error: 3941.727479742464
#
# debug - iteration: 43
# debug - root_mean_square_error: 3861.057399251548
#
# debug - iteration: 44
# debug - root_mean_square_error: 3779.6987648149147
#
# debug - iteration: 45
# debug - root_mean_square_error: 3697.3216712366952
#
# debug - iteration: 46
# debug - root_mean_square_error: 3619.2819979634096
#
# debug - iteration: 47
# debug - root_mean_square_error: 3545.727770709658
#
# debug - iteration: 48
# debug - root_mean_square_error: 3473.548622888838
#
# debug - iteration: 49
# debug - root_mean_square_error: 3405.2649871070125
#
# debug - iteration: 50
# debug - root_mean_square_error: 3336.548315255446
#
# debug - iteration: 51
# debug - root_mean_square_error: 3270.066961633071
#
# debug - iteration: 52
# debug - root_mean_square_error: 3204.2472040504545
#
# debug - iteration: 53
# debug - root_mean_square_error: 3141.4755403982754
#
# debug - iteration: 54
# debug - root_mean_square_error: 3082.6876138575576
#
# debug - iteration: 55
# debug - root_mean_square_error: 3023.373744009279
#
# debug - iteration: 56
# debug - root_mean_square_error: 2966.9338982065146
#
# debug - iteration: 57
# debug - root_mean_square_error: 2912.0094366030794
#
# debug - iteration: 58
# debug - root_mean_square_error: 2857.028113977697
#
# debug - iteration: 59
# debug - root_mean_square_error: 2805.9796788307867
#
# debug - iteration: 60
# debug - root_mean_square_error: 2755.131933495315
#
# debug - iteration: 61
# debug - root_mean_square_error: 2705.3649262234767
#
# debug - iteration: 62
# debug - root_mean_square_error: 2658.9620201267594
#
# debug - iteration: 63
# debug - root_mean_square_error: 2612.4770155076453
#
# debug - iteration: 64
# debug - root_mean_square_error: 2567.8208442696787
#
# debug - iteration: 65
# debug - root_mean_square_error: 2525.1339961859067
#
# debug - iteration: 66
# debug - root_mean_square_error: 2482.630969922186
#
# debug - iteration: 67
# debug - root_mean_square_error: 2442.4480079288523
#
# debug - iteration: 68
# debug - root_mean_square_error: 2402.4036361222675
#
# debug - iteration: 69
# debug - root_mean_square_error: 2363.081114846864
#
# debug - iteration: 70
# debug - root_mean_square_error: 2326.7208523004097
#
# debug - iteration: 71
# debug - root_mean_square_error: 2289.6585654896444
#
# debug - iteration: 72
# debug - root_mean_square_error: 2254.0166759928566
#
# debug - iteration: 73
# debug - root_mean_square_error: 2219.990706995122
#
# debug - iteration: 74
# debug - root_mean_square_error: 2186.850054135573
#
# debug - iteration: 75
# debug - root_mean_square_error: 2152.853176017332
#
# debug - iteration: 76
# debug - root_mean_square_error: 2119.757799173461
#
# debug - iteration: 77
# debug - root_mean_square_error: 2088.4377944212483
#
# debug - iteration: 78
# debug - root_mean_square_error: 2056.844888634024
#
# debug - iteration: 79
# debug - root_mean_square_error: 2025.6010138926374
#
# debug - iteration: 80
# debug - root_mean_square_error: 1996.9524893719638
#
# debug - iteration: 81
# debug - root_mean_square_error: 1967.8448531340964
#
# debug - iteration: 82
# debug - root_mean_square_error: 1941.5610279952907
#
# debug - iteration: 83
# debug - root_mean_square_error: 1912.7918507477248
#
# debug - iteration: 84
# debug - root_mean_square_error: 1885.933323437776
#
# debug - iteration: 85
# debug - root_mean_square_error: 1861.5608929422247
#
# debug - iteration: 86
# debug - root_mean_square_error: 1834.8791335664205
#
# debug - iteration: 87
# debug - root_mean_square_error: 1811.052041434759
#
# debug - iteration: 88
# debug - root_mean_square_error: 1787.3284599100052
#
# debug - iteration: 89
# debug - root_mean_square_error: 1764.1752050348996
#
# debug - iteration: 90
# debug - root_mean_square_error: 1742.6718219677973
#
# debug - iteration: 91
# debug - root_mean_square_error: 1720.565481303446
#
# debug - iteration: 92
# debug - root_mean_square_error: 1699.44009360951
#
# debug - iteration: 93
# debug - root_mean_square_error: 1678.809270853726
#
# debug - iteration: 94
# debug - root_mean_square_error: 1658.5516211647353
#
# debug - iteration: 95
# debug - root_mean_square_error: 1638.776327672262
#
# debug - iteration: 96
# debug - root_mean_square_error: 1618.7691374252913
#
# debug - iteration: 97
# debug - root_mean_square_error: 1599.919021925426
#
# debug - iteration: 98
# debug - root_mean_square_error: 1581.0561427198788
#
# debug - iteration: 99
# debug - root_mean_square_error: 1563.553554107472
#
# debug - iteration: 100
# debug - root_mean_square_error: 1546.3790659123265
#
# debug - iteration: 101
# debug - root_mean_square_error: 1529.2775730704175
#
# debug - iteration: 102
# debug - root_mean_square_error: 1511.5179865761665
#
# debug - iteration: 103
# debug - root_mean_square_error: 1495.6308245745804
#
# debug - iteration: 104
# debug - root_mean_square_error: 1479.8104615051236
#
# debug - iteration: 105
# debug - root_mean_square_error: 1463.9219341360556
#
# debug - iteration: 106
# debug - root_mean_square_error: 1448.6742719939746
#
# debug - iteration: 107
# debug - root_mean_square_error: 1434.5772179297367
#
# debug - iteration: 108
# debug - root_mean_square_error: 1419.666732552536
#
# debug - iteration: 109
# debug - root_mean_square_error: 1404.7435647563523
#
# debug - iteration: 110
# debug - root_mean_square_error: 1391.358506335471
#
# debug - iteration: 111
# debug - root_mean_square_error: 1377.656201211042
#
# debug - iteration: 112
# debug - root_mean_square_error: 1364.036948470541
#
# debug - iteration: 113
# debug - root_mean_square_error: 1350.8482045176395
#
# debug - iteration: 114
# debug - root_mean_square_error: 1337.5729771610836
#
# debug - iteration: 115
# debug - root_mean_square_error: 1325.5782496220095
#
# debug - iteration: 116
# debug - root_mean_square_error: 1314.0123904260586
#
# debug - iteration: 117
# debug - root_mean_square_error: 1302.591534872241
#
# debug - iteration: 118
# debug - root_mean_square_error: 1291.0510557428854
#
# debug - iteration: 119
# debug - root_mean_square_error: 1279.9640335884008
#
# debug - iteration: 120
# debug - root_mean_square_error: 1269.5052882238788
#
# debug - iteration: 121
# debug - root_mean_square_error: 1258.4878577352429
#
# debug - iteration: 122
# debug - root_mean_square_error: 1248.4876429206552
#
# debug - iteration: 123
# debug - root_mean_square_error: 1237.8512534664014
#
# debug - iteration: 124
# debug - root_mean_square_error: 1228.708674066586
#
# debug - iteration: 125
# debug - root_mean_square_error: 1218.249983677882
#
# debug - iteration: 126
# debug - root_mean_square_error: 1209.1656476371272
#
# debug - iteration: 127
# debug - root_mean_square_error: 1200.185233745604
#
# debug - iteration: 128
# debug - root_mean_square_error: 1190.908270522728
#
# debug - iteration: 129
# debug - root_mean_square_error: 1181.9636615998875
#
# ...
#
# debug - iteration: 8
# debug - root_mean_square_error: 4544.919839947416
#
# debug - iteration: 9
# debug - root_mean_square_error: 4054.9798565752676
#
# debug - iteration: 10
# debug - root_mean_square_error: 3623.153982305118
#
# debug - iteration: 11
# debug - root_mean_square_error: 3243.8187449436596
#
# debug - iteration: 12
# debug - root_mean_square_error: 2903.393127906238
#
# debug - iteration: 13
# debug - root_mean_square_error: 2602.056758502806
#
# debug - iteration: 14
# debug - root_mean_square_error: 2346.540351444454
#
# debug - iteration: 15
# debug - root_mean_square_error: 2116.573391768841
#
# debug - iteration: 16
# debug - root_mean_square_error: 1913.6662883029014
#
# debug - iteration: 17
# debug - root_mean_square_error: 1732.9138325011984
#
# debug - iteration: 18
# debug - root_mean_square_error: 1571.355639161868
#
# debug - iteration: 19
# debug - root_mean_square_error: 1431.0564228969017
#
# debug - iteration: 20
# debug - root_mean_square_error: 1308.259325274244
#
# debug - iteration: 21
# debug - root_mean_square_error: 1197.6603897664554
#
# debug - iteration: 22
# debug - root_mean_square_error: 1096.6400045973858
#
# debug - iteration: 23
# debug - root_mean_square_error: 1006.0720286923757
#
# debug - iteration: 24
# debug - root_mean_square_error: 929.5327730054573
#
# debug - iteration: 25
# debug - root_mean_square_error: 859.5104764943441
#
# debug - iteration: 26
# debug - root_mean_square_error: 797.8477343691027
#
# debug - iteration: 27
# debug - root_mean_square_error: 740.3425763486287
#
# debug - iteration: 28
# debug - root_mean_square_error: 688.9276975056392
#
# debug - iteration: 29
# debug - root_mean_square_error: 640.7699825027776
#
# debug - iteration: 30
# debug - root_mean_square_error: 598.0535590822353
#
# debug - iteration: 31
# debug - root_mean_square_error: 560.8637514013939
#
# debug - iteration: 32
# debug - root_mean_square_error: 528.3171656993619
#
# debug - iteration: 33
# debug - root_mean_square_error: 498.06954284008407
#
# debug - iteration: 34
# debug - root_mean_square_error: 470.8646735031617
#
# debug - iteration: 35
# debug - root_mean_square_error: 445.94631652940393
#
# debug - iteration: 36
# debug - root_mean_square_error: 423.9063534865798
#
# debug - iteration: 37
# debug - root_mean_square_error: 404.3863333319005
#
# debug - iteration: 38
# debug - root_mean_square_error: 386.8130631492615
#
# debug - iteration: 39
# debug - root_mean_square_error: 370.9644972194988
#
# debug - iteration: 40
# debug - root_mean_square_error: 356.83650620782214
#
# debug - iteration: 41
# debug - root_mean_square_error: 344.3299292412146
#
# debug - iteration: 42
# debug - root_mean_square_error: 333.35634363340387
#
# debug - iteration: 43
# debug - root_mean_square_error: 323.1283880128633
#
# debug - iteration: 44
# debug - root_mean_square_error: 314.23033153878356
#
# debug - iteration: 45
# debug - root_mean_square_error: 306.43014312333105
#
# debug - iteration: 46
# debug - root_mean_square_error: 299.82724584351627
#
# debug - iteration: 47
# debug - root_mean_square_error: 293.7558692578976
#
# debug - iteration: 48
# debug - root_mean_square_error: 288.21218399444376
#
# debug - iteration: 49
# debug - root_mean_square_error: 283.69733179237875
#
# debug - iteration: 50
# debug - root_mean_square_error: 279.51408839832413
#
# debug - iteration: 51
# debug - root_mean_square_error: 275.98295774857894
#
# debug - iteration: 52
# debug - root_mean_square_error: 272.7998708155417
#
# debug - iteration: 53
# debug - root_mean_square_error: 269.9625099147825
#
# debug - iteration: 54
# debug - root_mean_square_error: 267.43830747095217
#
# debug - iteration: 55
# debug - root_mean_square_error: 265.2141455889948
#
# debug - iteration: 56
# debug - root_mean_square_error: 263.20973681845766
#
# debug - iteration: 57
# debug - root_mean_square_error: 261.4898437999443
#
# debug - iteration: 58
# debug - root_mean_square_error: 260.0506922207067
#
# debug - iteration: 59
# debug - root_mean_square_error: 258.73883671201554
#
# debug - iteration: 60
# debug - root_mean_square_error: 257.5732186959
#
# debug - iteration: 61
# debug - root_mean_square_error: 256.51637900971565
#
# debug - iteration: 62
# debug - root_mean_square_error: 255.5585691605072
#
# debug - iteration: 63
# debug - root_mean_square_error: 254.8128820917067
#
# debug - iteration: 64
# debug - root_mean_square_error: 254.10554435279047
#
# debug - iteration: 65
# debug - root_mean_square_error: 253.47031239538134
#
# debug - iteration: 66
# debug - root_mean_square_error: 252.92077233343335
#
# debug - iteration: 67
# debug - root_mean_square_error: 252.44277349130624
#
# debug - iteration: 68
# debug - root_mean_square_error: 252.04124331573408
#
# debug - iteration: 69
# debug - root_mean_square_error: 251.63914721144874
#
# debug - iteration: 70
# debug - root_mean_square_error: 251.28846461788888
#
# debug - iteration: 71
# debug - root_mean_square_error: 250.9716948607767
#
# debug - iteration: 72
# debug - root_mean_square_error: 250.70824927830702
#
# debug - iteration: 73
# debug - root_mean_square_error: 250.45138276031628
#
# debug - iteration: 74
# debug - root_mean_square_error: 250.22913353808613
#
# debug - iteration: 75
# debug - root_mean_square_error: 250.03939069357705
#
# debug - iteration: 76
# debug - root_mean_square_error: 249.83037084219268
#
# debug - iteration: 77
# debug - root_mean_square_error: 249.70661473389634
#
# debug - iteration: 78
# debug - root_mean_square_error: 249.5694327152147
#
# debug - iteration: 79
# debug - root_mean_square_error: 249.45699802763042
#
# debug - iteration: 80
# debug - root_mean_square_error: 249.3627040966705
#
# debug - iteration: 81
# debug - root_mean_square_error: 249.2755101109734
#
# debug - iteration: 82
# debug - root_mean_square_error: 249.17798121869964
#
# debug - iteration: 83
# debug - root_mean_square_error: 249.13164042789205
#
# debug - iteration: 84
# debug - root_mean_square_error: 249.05717821548396
#
# debug - iteration: 85
# debug - root_mean_square_error: 249.00497081224344
#
# debug - iteration: 86
# debug - root_mean_square_error: 248.96379227600193
#
# debug - iteration: 87
# debug - root_mean_square_error: 248.90473485712982
#
# debug - iteration: 88
# debug - root_mean_square_error: 248.85818369301623
#
# debug - iteration: 89
# debug - root_mean_square_error: 248.80999988192022
#
# debug - iteration: 90
# debug - root_mean_square_error: 248.78914038249252
#
# debug - iteration: 91
# debug - root_mean_square_error: 248.7218226729952
#
# debug - iteration: 92
# debug - root_mean_square_error: 248.6577699939014
#
# debug - iteration: 93
# debug - root_mean_square_error: 248.64692991163355
#
# debug - iteration: 94
# debug - root_mean_square_error: 248.615524023463
#
# debug - iteration: 95
# debug - root_mean_square_error: 248.5883113163208
#
# debug - iteration: 96
# debug - root_mean_square_error: 248.57635792555095
#
# debug - iteration: 97
# debug - root_mean_square_error: 248.55417562143896
#
# debug - iteration: 98
# debug - root_mean_square_error: 248.53704698070504
#
# debug - iteration: 99
# debug - root_mean_square_error: 248.52042304659173
#
# debug - iteration: 100
# debug - root_mean_square_error: 248.4784415368478
#
# debug - iteration: 101
# debug - root_mean_square_error: 248.46592565724464
#
# debug - iteration: 102
# debug - root_mean_square_error: 248.45617504898598
#
# debug - iteration: 103
# debug - root_mean_square_error: 248.46683995818802
#
# debug - iteration: 104
# debug - root_mean_square_error: 248.46854348085952
#
# debug - iteration: 105
# debug - root_mean_square_error: 248.4585880422842
#
# debug - iteration: 106
# debug - root_mean_square_error: 248.45340883306807
#
# debug - iteration: 107
# debug - root_mean_square_error: 248.4565518743881
#
# debug - iteration: 108
# debug - root_mean_square_error: 248.44038096807586
#
# debug - iteration: 109
# debug - root_mean_square_error: 248.4309629742464
#
# debug - iteration: 110
# debug - root_mean_square_error: 248.4018387376831
#
# debug - iteration: 111
# debug - root_mean_square_error: 248.38003755318798
#
# debug - iteration: 112
# debug - root_mean_square_error: 248.38286412543187
#
# debug - iteration: 113
# debug - root_mean_square_error: 248.38872431046173
#
# debug - iteration: 114
# debug - root_mean_square_error: 248.40534551659036
#
# debug - iteration: 1
# debug - root_mean_square_error: 10006.333306983686
#
# debug - iteration: 2
# debug - root_mean_square_error: 8427.206788028487
#
# debug - iteration: 3
# debug - root_mean_square_error: 7087.9567363394945
#
# debug - iteration: 4
# debug - root_mean_square_error: 5986.301549846846
#
# debug - iteration: 5
# debug - root_mean_square_error: 5052.778868542873
#
# debug - iteration: 6
# debug - root_mean_square_error: 4281.033971862077
#
# debug - iteration: 7
# debug - root_mean_square_error: 3640.3708846525114
#
# debug - iteration: 8
# debug - root_mean_square_error: 3103.733873077067
#
# debug - iteration: 9
# debug - root_mean_square_error: 2652.4931827969845
#
# debug - iteration: 10
# debug - root_mean_square_error: 2279.796249522886
#
# debug - iteration: 11
# debug - root_mean_square_error: 1968.7819207667592
#
# debug - iteration: 12
# debug - root_mean_square_error: 1706.3184395428466
#
# debug - iteration: 13
# debug - root_mean_square_error: 1487.5846118738764
#
# debug - iteration: 14
# debug - root_mean_square_error: 1299.4755725031462
#
# debug - iteration: 15
# debug - root_mean_square_error: 1140.9667842920276
#
# debug - iteration: 16
# debug - root_mean_square_error: 1005.7028695017849
#
# debug - iteration: 17
# debug - root_mean_square_error: 893.7350165441421
#
# debug - iteration: 18
# debug - root_mean_square_error: 796.7936967120123
#
# debug - iteration: 19
# debug - root_mean_square_error: 714.4260676880032
#
# debug - iteration: 20
# debug - root_mean_square_error: 642.7232256986583
#
# debug - iteration: 21
# debug - root_mean_square_error: 583.1381727302404
#
# debug - iteration: 22
# debug - root_mean_square_error: 531.2404604499687
#
# debug - iteration: 23
# debug - root_mean_square_error: 488.1948458135786
#
# debug - iteration: 24
# debug - root_mean_square_error: 450.74531467108847
#
# debug - iteration: 25
# debug - root_mean_square_error: 417.73608472454293
#
# debug - iteration: 26
# debug - root_mean_square_error: 390.6067486584605
#
# debug - iteration: 27
# debug - root_mean_square_error: 367.74166667633386
#
# debug - iteration: 28
# debug - root_mean_square_error: 348.1014660192768
#
# debug - iteration: 29
# debug - root_mean_square_error: 331.2035339216645
#
# debug - iteration: 30
# debug - root_mean_square_error: 317.57367747404976
#
# debug - iteration: 31
# debug - root_mean_square_error: 305.93824422035806
#
# debug - iteration: 32
# debug - root_mean_square_error: 296.3913997270911
#
# debug - iteration: 33
# debug - root_mean_square_error: 288.2188907699795
#
# debug - iteration: 34
# debug - root_mean_square_error: 281.45471350763063
#
# debug - iteration: 35
# debug - root_mean_square_error: 276.0074619274177
#
# debug - iteration: 36
# debug - root_mean_square_error: 271.42510343410316
#
# debug - iteration: 37
# debug - root_mean_square_error: 267.5501667004475
#
# debug - iteration: 38
# debug - root_mean_square_error: 264.3104245901438
#
# debug - iteration: 39
# debug - root_mean_square_error: 261.7011732071227
#
# debug - iteration: 40
# debug - root_mean_square_error: 259.53439936952236
#
# debug - iteration: 41
# debug - root_mean_square_error: 257.7331999286103
#
# debug - iteration: 42
# debug - root_mean_square_error: 256.1959364778514
#
# debug - iteration: 43
# debug - root_mean_square_error: 254.86586978948773
#
# debug - iteration: 44
# debug - root_mean_square_error: 253.84437566413612
#
# debug - iteration: 45
# debug - root_mean_square_error: 252.93562820577085
#
# debug - iteration: 46
# debug - root_mean_square_error: 252.21177966929744
#
# debug - iteration: 47
# debug - root_mean_square_error: 251.53158958578393
#
# debug - iteration: 48
# debug - root_mean_square_error: 251.02278228374195
#
# debug - iteration: 49
# debug - root_mean_square_error: 250.6345919534075
#
# debug - iteration: 50
# debug - root_mean_square_error: 250.28306031864014
#
# debug - iteration: 51
# debug - root_mean_square_error: 249.95568745206958
#
# debug - iteration: 52
# debug - root_mean_square_error: 249.7110154567071
#
# debug - iteration: 53
# debug - root_mean_square_error: 249.5260900419113
#
# debug - iteration: 54
# debug - root_mean_square_error: 249.32600025351687
#
# debug - iteration: 55
# debug - root_mean_square_error: 249.15333561277941
#
# debug - iteration: 56
# debug - root_mean_square_error: 249.02944347241157
#
# debug - iteration: 57
# debug - root_mean_square_error: 248.95301145937617
#
# debug - iteration: 58
# debug - root_mean_square_error: 248.84730039791413
#
# debug - iteration: 59
# debug - root_mean_square_error: 248.75557667080778
#
# debug - iteration: 60
# debug - root_mean_square_error: 248.66020561016822
#
# debug - iteration: 61
# debug - root_mean_square_error: 248.6021699403455
#
# debug - iteration: 62
# debug - root_mean_square_error: 248.5489404048975
#
# debug - iteration: 63
# debug - root_mean_square_error: 248.50165507235556
#
# debug - iteration: 64
# debug - root_mean_square_error: 248.4630733134156
#
# debug - iteration: 65
# debug - root_mean_square_error: 248.4213586095089
#
# debug - iteration: 66
# debug - root_mean_square_error: 248.38740783002947
#
# debug - iteration: 67
# debug - root_mean_square_error: 248.36513067508352
#
# debug - iteration: 68
# debug - root_mean_square_error: 248.3544068171829
#
# debug - iteration: 69
# debug - root_mean_square_error: 248.3329630002242
#
# debug - iteration: 70
# debug - root_mean_square_error: 248.31597090231017
#
# debug - iteration: 71
# debug - root_mean_square_error: 248.32306251988632
#
# debug - iteration: 72
# debug - root_mean_square_error: 248.2981915009618
#
# debug - iteration: 73
# debug - root_mean_square_error: 248.2834025210924
#
# debug - iteration: 74
# debug - root_mean_square_error: 248.27048751013965
#
# debug - iteration: 75
# debug - root_mean_square_error: 248.2442221436817
#
# debug - iteration: 76
# debug - root_mean_square_error: 248.23936945678975
#
# debug - iteration: 77
# debug - root_mean_square_error: 248.24103646040402
#
# debug - iteration: 78
# debug - root_mean_square_error: 248.23826716834606
#
# debug - iteration: 79
# debug - root_mean_square_error: 248.247626621321
#
# debug - iteration: 80
# debug - root_mean_square_error: 248.23328908822728
#
# debug - iteration: 81
# debug - root_mean_square_error: 248.22217315287594
#
# debug - iteration: 82
# debug - root_mean_square_error: 248.22025475263064
#
# debug - iteration: 83
# debug - root_mean_square_error: 248.21358157740545
#
# debug - iteration: 84
# debug - root_mean_square_error: 248.2141936774941
#
# debug - iteration: 85
# debug - root_mean_square_error: 248.20888575770812
#
# debug - iteration: 86
# debug - root_mean_square_error: 248.20224066154734
#
# debug - iteration: 87
# debug - root_mean_square_error: 248.20217484141324
#
# debug - iteration: 88
# debug - root_mean_square_error: 248.20243459954276
#
# debug - iteration: 89
# debug - root_mean_square_error: 248.1997947344214
#
# debug - iteration: 90
# debug - root_mean_square_error: 248.19204783539084
#
# debug - iteration: 91
# debug - root_mean_square_error: 248.18585806211206
#
# debug - iteration: 92
# debug - root_mean_square_error: 248.18455335969577
#
# debug - iteration: 93
# debug - root_mean_square_error: 248.17211069874307
#
# debug - iteration: 94
# debug - root_mean_square_error: 248.16864817859232
#
# debug - iteration: 95
# debug - root_mean_square_error: 248.1694269487348
#
# debug - iteration: 96
# debug - root_mean_square_error: 248.17588991310166
#
# debug - iteration: 97
# debug - root_mean_square_error: 248.16399240433648
#
# debug - iteration: 98
# debug - root_mean_square_error: 248.1577813483471
#
# debug - iteration: 99
# debug - root_mean_square_error: 248.1624696626421
#
# debug - iteration: 100
# debug - root_mean_square_error: 248.1693301953936
#
# debug - iteration: 101
# debug - root_mean_square_error: 248.15906984765613
#
# debug - iteration: 102
# debug - root_mean_square_error: 248.15419051853675
#
# debug - iteration: 103
# debug - root_mean_square_error: 248.1420350612247
#
# debug - iteration: 104
# debug - root_mean_square_error: 248.13734284748182
#
# debug - iteration: 105
# debug - root_mean_square_error: 248.13477748986276
#
# debug - iteration: 106
# debug - root_mean_square_error: 248.13029335449156
#
# debug - iteration: 107
# debug - root_mean_square_error: 248.12920915269544
#
# debug - iteration: 108
# debug - root_mean_square_error: 248.13173160158277
#
# debug - iteration: 109
# debug - root_mean_square_error: 248.1351811862516
#
# debug - iteration: 110
# debug - root_mean_square_error: 248.13774638989486

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# load model data

n_bayseian_personalized_ranking_model = len(bayseian_personalized_ranking_models)
latent_factor_matrix_dictionarys = DataHelper().load_latent_factor_matrix_dictionarys(n_bayseian_personalized_ranking_model)
root_mean_square_errors = DataHelper().load_root_mean_square_errors(n_bayseian_personalized_ranking_model)

# %%
# validate model

training_data_dictionary = DataHelper().load_data_dictionary(training_data_url)
validation_data_dictionary = DataHelper().load_data_dictionary(validation_data_url)

user_ids = validation_data_dictionary[data_group_by_user_id_dictionary_key][data_user_column_name].tolist()
user_id = np.random.choice(user_ids)

n_item = len(validation_data_dictionary[data_group_by_item_id_dictionary_key][data_item_column_name])
n_best_recommendations = [int(n_item * 0.1), int(n_item * 0.2), int(n_item * 0.3), int(n_item * 0.4), int(n_item * 0.5)]

bayseian_personalized_ranking_model_index = 1

bayseian_personalized_ranking_parameter = {
    'random_seed' : 1234, 
    'n_latent_factor' : 15, 
    'n_batch' : 2000, 
    'learning_rate' : 0.2, 
    'regularization_constant' : 0.2
}
bayseian_personalized_ranking_model = BayseianPersonalizedRankingModel(**bayseian_personalized_ranking_parameter)
bayseian_personalized_ranking_model.training_data_dictionary = training_data_dictionary
bayseian_personalized_ranking_model.testing_data_dictionary = validation_data_dictionary
bayseian_personalized_ranking_model.latent_factor_matrix_dictionary = latent_factor_matrix_dictionarys[bayseian_personalized_ranking_model_index]
bayseian_personalized_ranking_model.root_mean_square_errors = root_mean_square_errors[bayseian_personalized_ranking_model_index]

true_positive_rates = []
false_positive_rates = []
precisions = []
for n_best_recommendation in n_best_recommendations:
    recommendation_data_dictionary = bayseian_personalized_ranking_model.recommend(n_best_recommendation)
    true_positive_rate, false_positive_rate, precision = ModelAnalyzerHelper().evaluate(validation_data_dictionary, recommendation_data_dictionary)
    true_positive_rates.append(true_positive_rate)
    false_positive_rates.append(false_positive_rate)
    precisions.append(precision)

print('debug - true_positive_rates:', true_positive_rates, end='\n')
print('debug - false_positive_rates:', false_positive_rates, end='\n')
print('debug - precisions:', precisions, end='\n')
print('', end='\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 732
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1540
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 733
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 734
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 735
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1534
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 736
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 737
# debug - n_user_true_positive: 13
# debug - n_user_false_positive: 1485
# debug - n_user_true_negative: 1508
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 738
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 739
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 740
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1532
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 741
# debug - n_user_true_positive: 12
# debug - n_user_false_positive: 1486
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 742
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1524
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 743
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 744
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1528
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 745
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 746
# debug - n_user_true_positive: 16
# debug - n_user_false_positive: 1482
# debug - n_user_true_negative: 1511
# debug - n_user_false_negative: 5
#
# debug - recommendation_user_id: 747
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 748
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 749
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 750
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 751
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 752
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 753
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 754
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 755
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 756
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 757
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 758
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 6
#
# debug - recommendation_user_id: 759
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 760
# debug - n_user_true_positive: 12
# debug - n_user_false_positive: 1486
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 5
#
# debug - recommendation_user_id: 761
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 762
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 763
# debug - n_user_true_positive: 12
# debug - n_user_false_positive: 1486
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 764
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1528
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 765
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 766
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1509
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 767
# debug - n_user_true_positive: 0
# debug - n_user_false_positive: 1498
# debug - n_user_true_negative: 1532
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 768
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 769
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 770
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 771
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 772
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1526
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 773
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 774
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 775
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 776
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 777
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 778
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 779
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 780
# debug - n_user_true_positive: 14
# debug - n_user_false_positive: 1484
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 781
# debug - n_user_true_positive: 15
# debug - n_user_false_positive: 1483
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 782
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 783
# debug - n_user_true_positive: 17
# debug - n_user_false_positive: 1481
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 784
# debug - n_user_true_positive: 13
# debug - n_user_false_positive: 1485
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 785
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 786
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 787
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 788
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 789
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 791
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1509
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 792
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 793
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1508
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 794
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 795
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 6
#
# debug - recommendation_user_id: 796
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1524
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 797
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1522
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 798
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1534
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 799
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1526
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 800
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1526
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 801
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1522
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 802
# debug - n_user_true_positive: 15
# debug - n_user_false_positive: 1483
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 803
# debug - n_user_true_positive: 0
# debug - n_user_false_positive: 1498
# debug - n_user_true_negative: 1527
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 804
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 805
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 806
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1542
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 807
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 808
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1524
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 809
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1528
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 810
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1530
# debug - n_user_false_negative: 13
#
# debug - recommendation_user_id: 812
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1524
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 813
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 814
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 815
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 816
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 817
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 818
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1529
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 819
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 820
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1527
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 821
# debug - n_user_true_positive: 12
# debug - n_user_false_positive: 1486
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 822
# debug - n_user_true_positive: 0
# debug - n_user_false_positive: 1498
# debug - n_user_true_negative: 1529
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 823
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 824
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1525
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 825
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 826
# debug - n_user_true_positive: 0
# debug - n_user_false_positive: 1498
# debug - n_user_true_negative: 1528
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 827
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 828
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 829
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1538
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 830
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 831
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 6
#
# debug - recommendation_user_id: 832
# debug - n_user_true_positive: 14
# debug - n_user_false_positive: 1484
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 833
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 834
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1527
# debug - n_user_false_negative: 6
#
# debug - recommendation_user_id: 835
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1524
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 836
# debug - n_user_true_positive: 14
# debug - n_user_false_positive: 1484
# debug - n_user_true_negative: 1525
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 837
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1531
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 838
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1523
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 839
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 840
# debug - n_user_true_positive: 15
# debug - n_user_false_positive: 1483
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 841
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 842
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 843
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 844
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 845
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1534
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 846
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 847
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1526
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 848
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 849
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 850
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1525
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 851
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1511
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 852
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 853
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 854
# debug - n_user_true_positive: 0
# debug - n_user_false_positive: 1498
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 855
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 856
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 857
# debug - n_user_true_positive: 0
# debug - n_user_false_positive: 1498
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 858
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 859
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 860
# debug - n_user_true_positive: 0
# debug - n_user_false_positive: 1498
# debug - n_user_true_negative: 1530
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 861
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1524
# debug - n_user_false_negative: 5
#
# debug - recommendation_user_id: 862
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1523
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 863
# debug - n_user_true_positive: 11
# debug - n_user_false_positive: 1487
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 864
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 5
#
# debug - recommendation_user_id: 865
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1522
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 866
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 867
# debug - n_user_true_positive: 14
# debug - n_user_false_positive: 1484
# debug - n_user_true_negative: 1502
# debug - n_user_false_negative: 16
#
# debug - recommendation_user_id: 868
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 869
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 870
# debug - n_user_true_positive: 11
# debug - n_user_false_positive: 1487
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 871
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 872
# debug - n_user_true_positive: 21
# debug - n_user_false_positive: 1477
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 873
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1508
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 874
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1508
# debug - n_user_false_negative: 8
#
# debug - recommendation_user_id: 875
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 876
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 6
#
# debug - recommendation_user_id: 877
# debug - n_user_true_positive: 18
# debug - n_user_false_positive: 1480
# debug - n_user_true_negative: 1510
# debug - n_user_false_negative: 5
#
# debug - recommendation_user_id: 878
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 879
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 880
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 881
# debug - n_user_true_positive: 11
# debug - n_user_false_positive: 1487
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 882
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 883
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 884
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 885
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 5
#
# debug - recommendation_user_id: 886
# debug - n_user_true_positive: 0
# debug - n_user_false_positive: 1498
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 887
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 888
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 6
#
# debug - recommendation_user_id: 889
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 890
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 891
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1528
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 892
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1509
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 893
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1522
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 894
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 895
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1529
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 896
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 897
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 898
# debug - n_user_true_positive: 19
# debug - n_user_false_positive: 1479
# debug - n_user_true_negative: 1511
# debug - n_user_false_negative: 8
#
# debug - recommendation_user_id: 899
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1543
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 900
# debug - n_user_true_positive: 20
# debug - n_user_false_positive: 1478
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 901
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1527
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 902
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 903
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1530
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 904
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 905
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1527
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 906
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1528
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 907
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 908
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 5
#
# debug - recommendation_user_id: 909
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 910
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 911
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1522
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 912
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 913
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 914
# debug - n_user_true_positive: 16
# debug - n_user_false_positive: 1482
# debug - n_user_true_negative: 1511
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 915
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1523
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 916
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 917
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 918
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 919
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1511
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 920
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 921
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 922
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 923
# debug - n_user_true_positive: 0
# debug - n_user_false_positive: 1498
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 924
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1527
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 925
# debug - n_user_true_positive: 0
# debug - n_user_false_positive: 1498
# debug - n_user_true_negative: 1537
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 926
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 927
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 928
# debug - n_user_true_positive: 16
# debug - n_user_false_positive: 1482
# debug - n_user_true_negative: 1511
# debug - n_user_false_negative: 6
#
# debug - recommendation_user_id: 929
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 930
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 931
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1522
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 932
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 933
# debug - n_user_true_positive: 16
# debug - n_user_false_positive: 1482
# debug - n_user_true_negative: 1511
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 934
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 935
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 936
# debug - n_user_true_positive: 13
# debug - n_user_false_positive: 1485
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 6
#
# debug - recommendation_user_id: 937
# debug - n_user_true_positive: 11
# debug - n_user_false_positive: 1487
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 938
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1511
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 939
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 940
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 941
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1522
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 942
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 943
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 944
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1522
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 945
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1510
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 946
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1509
# debug - n_user_false_negative: 5
#
# debug - recommendation_user_id: 947
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1524
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 948
# debug - n_user_true_positive: 0
# debug - n_user_false_positive: 1498
# debug - n_user_true_negative: 1523
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 949
# debug - n_user_true_positive: 15
# debug - n_user_false_positive: 1483
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 950
# debug - n_user_true_positive: 12
# debug - n_user_false_positive: 1486
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 951
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 952
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 5
#
# debug - recommendation_user_id: 953
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 6
#
# debug - recommendation_user_id: 954
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 955
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1524
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 956
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1510
# debug - n_user_false_negative: 6
#
# debug - recommendation_user_id: 957
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 958
# debug - n_user_true_positive: 11
# debug - n_user_false_positive: 1487
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 959
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 960
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 961
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 962
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 963
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 6
#
# debug - recommendation_user_id: 964
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 965
# debug - n_user_true_positive: 14
# debug - n_user_false_positive: 1484
# debug - n_user_true_negative: 1511
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 966
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 967
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 968
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 5
#
# debug - recommendation_user_id: 969
# debug - n_user_true_positive: 12
# debug - n_user_false_positive: 1486
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 970
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 971
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 5
#
# debug - recommendation_user_id: 972
# debug - n_user_true_positive: 24
# debug - n_user_false_positive: 1474
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 973
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 974
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 975
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 976
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 977
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 978
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 979
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1511
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 980
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1524
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 981
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 982
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 983
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 984
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 985
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 986
# debug - n_user_true_positive: 13
# debug - n_user_false_positive: 1485
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 987
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 988
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1528
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 989
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 990
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 991
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 992
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 993
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 5
#
# debug - recommendation_user_id: 994
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 995
# debug - n_user_true_positive: 13
# debug - n_user_false_positive: 1485
# debug - n_user_true_negative: 1511
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 996
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 997
# debug - n_user_true_positive: 19
# debug - n_user_false_positive: 1479
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 998
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 6
#
# debug - recommendation_user_id: 999
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1000
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1523
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1001
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1002
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1507
# debug - n_user_false_negative: 9
#
# debug - recommendation_user_id: 1003
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1509
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 1004
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1511
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1005
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 6
#
# debug - recommendation_user_id: 1006
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1007
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1530
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1008
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1009
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1010
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# ...
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1479
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1523
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 1480
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1481
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 5
#
# debug - recommendation_user_id: 1482
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1522
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1483
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 6
#
# debug - recommendation_user_id: 1484
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1485
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1529
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1486
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1487
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1537
# debug - n_user_false_negative: 5
#
# debug - recommendation_user_id: 1488
# debug - n_user_true_positive: 15
# debug - n_user_false_positive: 1483
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 1489
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1490
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1524
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1491
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1492
# debug - n_user_true_positive: 11
# debug - n_user_false_positive: 1487
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1493
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1523
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 1494
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1495
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1496
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1537
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 1497
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1498
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 1499
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1529
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1500
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1501
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1502
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1503
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1522
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1504
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1505
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1506
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 1507
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1508
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 1509
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1510
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 1511
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1512
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1510
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 1513
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1514
# debug - n_user_true_positive: 0
# debug - n_user_false_positive: 1498
# debug - n_user_true_negative: 1529
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1515
# debug - n_user_true_positive: 11
# debug - n_user_false_positive: 1487
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1516
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 1517
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1518
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1519
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 1520
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1522
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1521
# debug - n_user_true_positive: 11
# debug - n_user_false_positive: 1487
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1522
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1523
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1524
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1525
# debug - n_user_true_positive: 9
# debug - n_user_false_positive: 1489
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 9
#
# debug - recommendation_user_id: 1526
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1527
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 6
#
# debug - recommendation_user_id: 1528
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1529
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1522
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1530
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1531
# debug - n_user_true_positive: 11
# debug - n_user_false_positive: 1487
# debug - n_user_true_negative: 1504
# debug - n_user_false_negative: 10
#
# debug - recommendation_user_id: 1532
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1511
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 1533
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1528
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1534
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1535
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1536
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1522
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1537
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1522
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1538
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1527
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 1539
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1526
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1540
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1541
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1527
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 1542
# debug - n_user_true_positive: 11
# debug - n_user_false_positive: 1487
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 1543
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1534
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1544
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1545
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1514
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1546
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1515
# debug - n_user_false_negative: 4
#
# debug - recommendation_user_id: 1547
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1548
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1522
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1549
# debug - n_user_true_positive: 11
# debug - n_user_false_positive: 1487
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 1550
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 1551
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1518
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1552
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1553
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 2
#
# debug - recommendation_user_id: 1554
# debug - n_user_true_positive: 10
# debug - n_user_false_positive: 1488
# debug - n_user_true_negative: 1508
# debug - n_user_false_negative: 10
#
# debug - recommendation_user_id: 1555
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1556
# debug - n_user_true_positive: 7
# debug - n_user_false_positive: 1491
# debug - n_user_true_negative: 1513
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1557
# debug - n_user_true_positive: 11
# debug - n_user_false_positive: 1487
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 1558
# debug - n_user_true_positive: 1
# debug - n_user_false_positive: 1497
# debug - n_user_true_negative: 1524
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1559
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1523
# debug - n_user_false_negative: 7
#
# debug - recommendation_user_id: 1560
# debug - n_user_true_positive: 0
# debug - n_user_false_positive: 1498
# debug - n_user_true_negative: 1536
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1561
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1521
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1562
# debug - n_user_true_positive: 8
# debug - n_user_false_positive: 1490
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 3
#
# debug - recommendation_user_id: 1563
# debug - n_user_true_positive: 2
# debug - n_user_false_positive: 1496
# debug - n_user_true_negative: 1516
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1564
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1523
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1565
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1520
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1567
# debug - n_user_true_positive: 4
# debug - n_user_false_positive: 1494
# debug - n_user_true_negative: 1517
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1568
# debug - n_user_true_positive: 3
# debug - n_user_false_positive: 1495
# debug - n_user_true_negative: 1519
# debug - n_user_false_negative: 0
#
# debug - recommendation_user_id: 1569
# debug - n_user_true_positive: 5
# debug - n_user_false_positive: 1493
# debug - n_user_true_negative: 1510
# debug - n_user_false_negative: 1
#
# debug - recommendation_user_id: 1570
# debug - n_user_true_positive: 6
# debug - n_user_false_positive: 1492
# debug - n_user_true_negative: 1512
# debug - n_user_false_negative: 3
