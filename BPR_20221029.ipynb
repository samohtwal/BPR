# %% [markdown]
# <a href="https://colab.research.google.com/github/samohtwal/BPR/blob/20221027/BPR_20221029.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import torch
import copy
from itertools import islice
from google.colab import files
import os
import matplotlib.pyplot as plt

# %%
global data_user_column_name
data_user_column_name = 'user_id'

global data_item_column_name
data_item_column_name = 'item_id'

global data_group_by_user_id_dictionary_key
data_group_by_user_id_dictionary_key = 'data_group_by_user_id'

global data_group_by_item_id_dictionary_key
data_group_by_item_id_dictionary_key = 'data_group_by_item_id'

global user_latent_factor_matrix_dictionary_key
user_latent_factor_matrix_dictionary_key = 'user_latent_factor_matrix'

global item_latent_factor_matrix_dictionary_key
item_latent_factor_matrix_dictionary_key = 'item_latent_factor_matrix'

global working_file_path
working_file_path = '/content/working/'

global user_latent_factor_matrix_file_name
user_latent_factor_matrix_file_name = 'user_latent_factor_matrix.csv'

global item_latent_factor_matrix_file_name
item_latent_factor_matrix_file_name = 'item_latent_factor_matrix.csv'

global root_mean_square_error_file_name
root_mean_square_error_file_name = 'root_mean_square_error.csv'

# %%
class DataHelper:

    def load_raw_data_dictionary(self, data_url):

        column_names = [data_user_column_name, data_item_column_name]
        raw_data = pd.read_csv(data_url, names = column_names, header=0)

        data_group_by_user_id = raw_data.groupby(data_user_column_name)[data_item_column_name].apply(list).reset_index(name=data_item_column_name).sort_values(by=[data_user_column_name])
        data_group_by_item_id = raw_data.groupby(data_item_column_name)[data_user_column_name].apply(list).reset_index(name=data_user_column_name).sort_values(by=[data_item_column_name])

        data_dictionary = {
            data_group_by_user_id_dictionary_key: data_group_by_user_id, 
            data_group_by_item_id_dictionary_key: data_group_by_item_id
        }

        return data_dictionary

    def save_latent_factor_matrix_dictionary(self, latent_factor_matrix_dictionary):

        user_latent_factor_matrix = latent_factor_matrix_dictionary[user_latent_factor_matrix_dictionary_key]
        item_latent_factor_matrix = latent_factor_matrix_dictionary[item_latent_factor_matrix_dictionary_key]
        
        if os.path.exists(working_file_path) == False:
            os.mkdir(working_file_path)

        pd.DataFrame(user_latent_factor_matrix).to_csv(working_file_path + user_latent_factor_matrix_file_name, index=False, header=False)
        pd.DataFrame(item_latent_factor_matrix).to_csv(working_file_path + item_latent_factor_matrix_file_name, index=False, header=False)

        return None

    def load_latent_factor_matrix_dictionary(self):

        user_latent_factor_matrix = pd.read_csv(working_file_path + user_latent_factor_matrix_file_name, header=None).values
        item_latent_factor_matrix = pd.read_csv(working_file_path + item_latent_factor_matrix_file_name, header=None).values

        latent_factor_matrix_dictionary = {
            user_latent_factor_matrix_dictionary_key: user_latent_factor_matrix, 
            item_latent_factor_matrix_dictionary_key: item_latent_factor_matrix
        }

        return latent_factor_matrix_dictionary
    
    def save_root_mean_square_error(self, errors):
        if os.path.exists(working_file_path) == False:
            os.mkdir(working_file_path)
        pd.DataFrame(errors).to_csv(working_file_path + root_mean_square_error_file_name, index=False, header=False)

        return None

# %%
class BayseianPersonalizedRankingModel:

    def __init__(self, random_seed = 1234, n_latent_factor = 15, n_batch = 10, learning_rate = 0.01, regularization_constant = 0.01):
        self.random_seed = random_seed
        self.n_latent_factor = n_latent_factor
        self.n_batch = n_batch
        self.learning_rate = learning_rate
        self.regularization_constant = regularization_constant

    def fit(self, training_data_dictionary):

        training_data_group_by_user_id = training_data_dictionary[data_group_by_user_id_dictionary_key]
        training_data_group_by_item_id = training_data_dictionary[data_group_by_item_id_dictionary_key]

        n_user = len(training_data_group_by_user_id[data_user_column_name])
        n_item = len(training_data_group_by_item_id[data_item_column_name])

        rstate = np.random.RandomState(self.random_seed)

        user_latent_factor_matrix = rstate.normal(size = (n_user, self.n_latent_factor))
        item_latent_factor_matrix = rstate.normal(size = (n_item, self.n_latent_factor))

        user_item_rating_matrix = self._create_user_item_rating_matrix(training_data_group_by_user_id, training_data_group_by_item_id)

        user_latent_factor_matrixes = []
        item_latent_factor_matrixes = []
        root_mean_square_errors = []

        is_converge = True
        index = 0
        while is_converge:

            # self.learning_rate = self.learning_rate * np.exp(-5*index)
            # self.learning_rate = self.learning_rate / (1 + 2 * index)
            
            sample_latent_factor_matrix_row_indexes = self._create_sample_latent_factor_matrix_row_indexes(training_data_group_by_user_id, training_data_group_by_item_id)
            sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes = sample_latent_factor_matrix_row_indexes
            user_latent_factor_matrix, item_latent_factor_matrix = self._update_sample_latent_factor_matrix_rows(user_latent_factor_matrix, item_latent_factor_matrix, sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes)
            
            sum_of_square_error = np.sum((user_item_rating_matrix - self._predict(user_latent_factor_matrix, item_latent_factor_matrix))**2)
            root_mean_square_error = np.sqrt((sum_of_square_error / n_user * n_item))

            user_latent_factor_matrixes.append(user_latent_factor_matrix)
            item_latent_factor_matrixes.append(item_latent_factor_matrix)
            root_mean_square_errors.append(root_mean_square_error)
            
            print('debug - iteration:', index+1, end='\n')
            print('debug - root_mean_square_error:', root_mean_square_error, end='\n')
            print('', end='\n')
            
            # if (root_mean_square_errors[index] > root_mean_square_errors[index-1] 
            #     and root_mean_square_errors[index-1] > root_mean_square_errors[index-2]
            #     and root_mean_square_errors[index-2] > root_mean_square_errors[index-3]):
            if index == 10:
                is_converge = False

            index = index + 1

        latent_factor_matrix_dictionary = {
            user_latent_factor_matrix_dictionary_key: user_latent_factor_matrixes[index-4], 
            item_latent_factor_matrix_dictionary_key: item_latent_factor_matrixes[index-4]
        }

        return latent_factor_matrix_dictionary, root_mean_square_errors[0:index-4]

    def _create_user_item_rating_matrix(self, training_data_group_by_user_id, training_data_group_by_item_id):

        n_user = len(training_data_group_by_user_id[data_user_column_name])
        n_item = len(training_data_group_by_item_id[data_item_column_name])

        user_ids = training_data_group_by_user_id[data_user_column_name].tolist()
        item_ids = training_data_group_by_item_id[data_item_column_name].tolist()

        user_item_rating_matrix = np.zeros((n_user, n_item), dtype = np.int64)
        for user_id_index, user_id in enumerate(user_ids):
            item_id_indexes = np.where(np.isin(training_data_group_by_user_id.iloc[user_id_index][data_item_column_name],item_ids))[0]
            for item_id_index in item_id_indexes:
                user_item_rating_matrix[user_id_index, item_id_index] = 1

        return user_item_rating_matrix

    def _create_sample_latent_factor_matrix_row_indexes(self, training_data_group_by_user_id, training_data_group_by_item_id):

        n_user = len(training_data_group_by_user_id[data_user_column_name])
        n_item = len(training_data_group_by_item_id[data_item_column_name])

        item_ids = training_data_group_by_item_id[data_item_column_name].tolist()

        sample_user_id_indexes = np.random.choice(n_user, size = self.n_batch, replace = False)
        sample_positive_item_id_indexes = np.zeros(self.n_batch, dtype = np.int64)
        sample_negative_item_id_indexes = np.zeros(self.n_batch, dtype = np.int64)

        for index, sampled_user_id_index in enumerate(sample_user_id_indexes):
            possible_positive_item_ids = training_data_group_by_user_id.iloc[sampled_user_id_index][data_item_column_name]
            possible_negative_item_ids = list(set(item_ids).difference(possible_positive_item_ids))
            sample_positive_item_id = np.random.choice(possible_positive_item_ids)
            sample_negative_item_id = np.random.choice(possible_negative_item_ids)
            sample_positive_item_id_indexes[index] = item_ids.index(sample_positive_item_id)
            sample_negative_item_id_indexes[index] = item_ids.index(sample_negative_item_id)

        return sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes

    def _update_sample_latent_factor_matrix_rows(self, user_latent_factor_matrix, item_latent_factor_matrix, sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes):

        sample_user_latent_factor_matrix_tuple = user_latent_factor_matrix[sample_user_id_indexes]
        sample_item_latent_factor_matrix_positive_item_tuple = item_latent_factor_matrix[sample_positive_item_id_indexes]
        sample_item_latent_factor_matrix_negative_item_tuple = item_latent_factor_matrix[sample_negative_item_id_indexes]

        r_uij = np.sum(sample_user_latent_factor_matrix_tuple * (sample_item_latent_factor_matrix_positive_item_tuple - sample_item_latent_factor_matrix_negative_item_tuple), axis = 1)
        sigmoid = np.exp(-r_uij) / (1.0 + np.exp(-r_uij))
        sigmoid_tiled = np.tile(sigmoid, (self.n_latent_factor, 1)).T

        gradient_user = sigmoid_tiled * (sample_item_latent_factor_matrix_negative_item_tuple - sample_item_latent_factor_matrix_positive_item_tuple) + self.regularization_constant * sample_user_latent_factor_matrix_tuple
        gradient_positive_item = sigmoid_tiled * -sample_user_latent_factor_matrix_tuple + self.regularization_constant * sample_item_latent_factor_matrix_positive_item_tuple
        gradient_negative_item = sigmoid_tiled * sample_user_latent_factor_matrix_tuple + self.regularization_constant * sample_item_latent_factor_matrix_negative_item_tuple

        user_latent_factor_matrix[sample_user_id_indexes] -= self.learning_rate * gradient_user
        item_latent_factor_matrix[sample_positive_item_id_indexes] -= self.learning_rate * gradient_positive_item
        item_latent_factor_matrix[sample_negative_item_id_indexes] -= self.learning_rate * gradient_negative_item

        return user_latent_factor_matrix, item_latent_factor_matrix

    def recommend(self, testing_data_dictionary, training_data_dictionary, latent_factor_matrix_dictionary, n_best_recommendation):

        testing_data_group_by_user_id = testing_data_dictionary[data_group_by_user_id_dictionary_key]

        n_user = len(testing_data_group_by_user_id[data_user_column_name])
        user_ids = user_ids = testing_data_group_by_user_id[data_user_column_name].tolist()

        recommendation_user_ids = []
        recommendation_item_ids = []
        for user_id in user_ids:
            best_recommendition_item_ids = self.recommend_user(training_data_dictionary, latent_factor_matrix_dictionary, user_id, n_best_recommendation)
            for item_id in best_recommendition_item_ids:
                recommendation_user_ids.append(user_id)
                recommendation_item_ids.append(item_id)

        data = {'user_id': recommendation_user_ids, 'item_id': recommendation_item_ids}
        recommendation_data = pd.DataFrame.from_dict(data)

        recommendation_data_group_by_user_id = recommendation_data.groupby(data_user_column_name)[data_item_column_name].apply(list).reset_index(name=data_item_column_name).sort_values(by=[data_user_column_name])
        recommendation_data_group_by_item_id = recommendation_data.groupby(data_item_column_name)[data_user_column_name].apply(list).reset_index(name=data_user_column_name).sort_values(by=[data_item_column_name])

        recommendation_data_dictionary = {
            data_group_by_user_id_dictionary_key: recommendation_data_group_by_user_id, 
            data_group_by_item_id_dictionary_key: recommendation_data_group_by_item_id
        }

        return recommendation_data_dictionary

    def recommend_user(self, training_data_dictionary, latent_factor_matrix_dictionary, user_id, n_best_recommendation):

        training_data_group_by_user_id = training_data_dictionary[data_group_by_user_id_dictionary_key]
        training_data_group_by_item_id = training_data_dictionary[data_group_by_item_id_dictionary_key]

        user_latent_factor_matrix = latent_factor_matrix_dictionary[user_latent_factor_matrix_dictionary_key]
        item_latent_factor_matrix = latent_factor_matrix_dictionary[item_latent_factor_matrix_dictionary_key]

        user_ids = training_data_group_by_user_id[data_user_column_name].tolist()
        item_ids = training_data_group_by_item_id[data_item_column_name].tolist()

        n_item = len(training_data_group_by_item_id[data_item_column_name])

        user_index = user_ids.index(user_id)

        scores = self._predict_user(user_latent_factor_matrix, item_latent_factor_matrix, user_index)

        item_score_dictionary = {item_ids[i]: scores[i] for i in range(len(item_ids))}
        positive_item_ids = training_data_group_by_user_id.iloc[user_index][data_item_column_name]

        item_score_dictionary = {item_ids[i]: scores[i] for i in range(len(item_ids))}
        item_score_dictionary = {key: item_score_dictionary[key] for key in item_ids if key not in positive_item_ids}
        item_score_dictionary = dict(sorted(item_score_dictionary.items(), key=lambda item: item[1], reverse=True))

        best_recommendition_items = dict(islice(item_score_dictionary.items(), n_best_recommendation))

        best_recommendition_item_ids = list(best_recommendition_items.keys())[0:n_best_recommendation]

        '''
        print('debug - user_id:', user_id, end='\n')
        print('debug - best_recommendation:', best_recommendition_item_ids, end='\n')
        print('', end='\n')
        '''

        return best_recommendition_item_ids

    def _predict(self, user_latent_factor_matrix, item_latent_factor_matrix):
        return user_latent_factor_matrix.dot(item_latent_factor_matrix.T)

    def _predict_user(self, user_latent_factor_matrix, item_latent_factor_matrix, user_index):
        return user_latent_factor_matrix[user_index].dot(item_latent_factor_matrix.T)

# %%
class ModelAnalyzerHelper:

    def plot_error_chart(self, root_mean_square_errors, bayseian_personalized_ranking_parameters):

        x  = range(len(root_mean_square_errors))
        y = root_mean_square_errors
        plt.plot(x, y, label='Learning Rate = ' + str(bayseian_personalized_ranking_parameters['learning_rate']))
        plt.plot()

        plt.xlabel("Iteration")
        plt.ylabel("Root Mean Square Error")
        plt.title("Root Mean Square Error / Iteration")
        plt.legend()
        plt.show()

        return None
    
    def evaluate(self, testing_data_dictionary, recommendation_data_dictionary):

        testing_data_group_by_user_id = testing_data_dictionary[data_group_by_user_id_dictionary_key]
        testing_user_ids = testing_data_group_by_user_id[data_user_column_name].tolist()

        testing_data_group_by_item_id = testing_data_dictionary[data_group_by_item_id_dictionary_key]
        testing_item_ids = testing_data_group_by_item_id[data_item_column_name].tolist()

        recommendation_data_group_by_user_id = recommendation_data_dictionary[data_group_by_user_id_dictionary_key]
        recommendation_user_ids = recommendation_data_group_by_user_id[data_user_column_name].tolist()

        print('debug - testing_data_group_by_user_id.shpape:', end='\n')
        print(testing_data_group_by_user_id.shape, end='\n')
        print('', end='\n')

        print('debug - recommendation_data_group_by_user_id.shpape:', end='\n')
        print(recommendation_data_group_by_user_id.shape, end='\n')
        print('', end='\n')

        n_true_positive = 0
        n_false_positive = 0
        n_true_negative = 0
        n_false_negative = 0

        for index, recommendation_user_id in enumerate(recommendation_user_ids):
            
            positive_testing_item_ids = testing_data_group_by_user_id.iloc[index][data_item_column_name]
            negative_testing_item_ids = list(set(testing_item_ids).difference(positive_testing_item_ids))
            positive_predition_item_ids = recommendation_data_group_by_user_id.iloc[index][data_item_column_name]
            negative_predition_item_ids = list(set(testing_item_ids).difference(positive_predition_item_ids))

            for positive_predition_item_id in positive_predition_item_ids:
                if positive_predition_item_id in positive_testing_item_ids: n_true_positive = n_true_positive + 1
                if positive_predition_item_id not in positive_testing_item_ids: n_false_positive = n_false_positive + 1

            for negative_predition_item_id in negative_predition_item_ids:
                if negative_predition_item_id in negative_testing_item_ids: n_true_negative = n_true_negative + 1
                if negative_predition_item_id not in negative_testing_item_ids: n_false_negative = n_false_negative + 1

            print('debug - n_true_positive:', n_true_positive, end='\n')
            print('debug - n_false_positive:', n_false_positive, end='\n')
            print('debug - n_true_negative:', n_true_negative, end='\n')
            print('debug - n_false_negative:', n_false_negative, end='\n')
            print('', end='\n')



        sensitivity = n_true_positive / (n_true_positive + n_false_negative)

        return sensitivity

# %%
data_helper = DataHelper()
bayseian_personalized_ranking_parameters = {
    'random_seed' : 1234, 
    'n_latent_factor' : 15, 
    'n_batch' : 1000, 
    'learning_rate' : 0.1, 
    'regularization_constant' : 0.1
}
bayseian_personalized_ranking_model = BayseianPersonalizedRankingModel(**bayseian_personalized_ranking_parameters)
model_analyzer_helper = ModelAnalyzerHelper()

# %%
training_data_url = 'https://raw.githubusercontent.com/samohtwal/BPR/20221027/data/train-20221026.csv'
training_data_dictionary = data_helper.load_raw_data_dictionary(training_data_url)

# %%
latent_factor_matrix_dictionary, root_mean_square_errors = bayseian_personalized_ranking_model.fit(training_data_dictionary)
data_helper.save_latent_factor_matrix_dictionary(latent_factor_matrix_dictionary)
data_helper.save_root_mean_square_error(root_mean_square_errors)
# Out:
# debug - iteration: 1
# debug - root_mean_square_error: 11723.278757099908
#
# debug - iteration: 2
# debug - root_mean_square_error: 11579.77772019943
#
# debug - iteration: 3
# debug - root_mean_square_error: 11431.64793762178
#
# debug - iteration: 4
# debug - root_mean_square_error: 11287.404079747199
#
# debug - iteration: 5
# debug - root_mean_square_error: 11150.16805188887
#
# debug - iteration: 6
# debug - root_mean_square_error: 11012.372523903095
#
# debug - iteration: 7
# debug - root_mean_square_error: 10881.281053577752
#
# debug - iteration: 8
# debug - root_mean_square_error: 10757.793763018864
#
# debug - iteration: 9
# debug - root_mean_square_error: 10632.640204844673
#
# debug - iteration: 10
# debug - root_mean_square_error: 10504.739895291255
#
# debug - iteration: 11
# debug - root_mean_square_error: 10382.10538486583

# %%
model_analyzer_helper.plot_error_chart(root_mean_square_errors, bayseian_personalized_ranking_parameters)

# %%
latent_factor_matrix_dictionary = data_helper.load_latent_factor_matrix_dictionary()

# %%
vali_data_url = 'https://raw.githubusercontent.com/samohtwal/BPR/20221027/data/vali-20221026.csv'
vali_data_dictionary = data_helper.load_raw_data_dictionary(vali_data_url)

user_ids = vali_data_dictionary[data_group_by_user_id_dictionary_key][data_user_column_name].tolist()
user_id = np.random.choice(user_ids)
n_best_recommendation = 10
best_recommendation = bayseian_personalized_ranking_model.recommend_user(training_data_dictionary, latent_factor_matrix_dictionary, user_id, n_best_recommendation)

recommendation_data_dictionary = bayseian_personalized_ranking_model.recommend(vali_data_dictionary, training_data_dictionary, latent_factor_matrix_dictionary, n_best_recommendation)

# %%
model_analyzer_helper = ModelAnalyzerHelper()
model_analyzer_helper.evaluate(vali_data_dictionary, recommendation_data_dictionary)
# Out:
# Streaming output truncated to the last 5000 lines.
# debug - n_true_positive: 49
# debug - n_false_positive: 28601
# debug - n_true_negative: 8538060
# debug - n_false_negative: 20596
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28611
# debug - n_true_negative: 8541043
# debug - n_false_negative: 20600
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28621
# debug - n_true_negative: 8544026
# debug - n_false_negative: 20605
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28631
# debug - n_true_negative: 8547010
# debug - n_false_negative: 20608
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28641
# debug - n_true_negative: 8549996
# debug - n_false_negative: 20610
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28651
# debug - n_true_negative: 8552984
# debug - n_false_negative: 20611
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28661
# debug - n_true_negative: 8555969
# debug - n_false_negative: 20614
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28671
# debug - n_true_negative: 8558952
# debug - n_false_negative: 20618
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28681
# debug - n_true_negative: 8561934
# debug - n_false_negative: 20623
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28691
# debug - n_true_negative: 8564919
# debug - n_false_negative: 20625
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28701
# debug - n_true_negative: 8567899
# debug - n_false_negative: 20633
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28711
# debug - n_true_negative: 8570883
# debug - n_false_negative: 20636
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28721
# debug - n_true_negative: 8573865
# debug - n_false_negative: 20641
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28731
# debug - n_true_negative: 8576845
# debug - n_false_negative: 20648
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28741
# debug - n_true_negative: 8579826
# debug - n_false_negative: 20654
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28751
# debug - n_true_negative: 8582808
# debug - n_false_negative: 20660
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28761
# debug - n_true_negative: 8585787
# debug - n_false_negative: 20668
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28771
# debug - n_true_negative: 8588767
# debug - n_false_negative: 20675
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28781
# debug - n_true_negative: 8591752
# debug - n_false_negative: 20678
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28791
# debug - n_true_negative: 8594734
# debug - n_false_negative: 20683
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28801
# debug - n_true_negative: 8597719
# debug - n_false_negative: 20685
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28811
# debug - n_true_negative: 8600702
# debug - n_false_negative: 20689
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28821
# debug - n_true_negative: 8603686
# debug - n_false_negative: 20692
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28831
# debug - n_true_negative: 8606669
# debug - n_false_negative: 20696
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28841
# debug - n_true_negative: 8609653
# debug - n_false_negative: 20699
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28851
# debug - n_true_negative: 8612631
# debug - n_false_negative: 20708
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28861
# debug - n_true_negative: 8615617
# debug - n_false_negative: 20710
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28871
# debug - n_true_negative: 8618600
# debug - n_false_negative: 20714
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28881
# debug - n_true_negative: 8621585
# debug - n_false_negative: 20716
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28891
# debug - n_true_negative: 8624559
# debug - n_false_negative: 20729
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28901
# debug - n_true_negative: 8627543
# debug - n_false_negative: 20733
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28911
# debug - n_true_negative: 8630526
# debug - n_false_negative: 20738
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28921
# debug - n_true_negative: 8633511
# debug - n_false_negative: 20740
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28931
# debug - n_true_negative: 8636495
# debug - n_false_negative: 20744
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28941
# debug - n_true_negative: 8639480
# debug - n_false_negative: 20748
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28951
# debug - n_true_negative: 8642462
# debug - n_false_negative: 20753
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28961
# debug - n_true_negative: 8645443
# debug - n_false_negative: 20759
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28971
# debug - n_true_negative: 8648428
# debug - n_false_negative: 20762
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28981
# debug - n_true_negative: 8651415
# debug - n_false_negative: 20763
#
# debug - n_true_positive: 49
# debug - n_false_positive: 28991
# debug - n_true_negative: 8654392
# debug - n_false_negative: 20773
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29001
# debug - n_true_negative: 8657378
# debug - n_false_negative: 20775
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29011
# debug - n_true_negative: 8660361
# debug - n_false_negative: 20779
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29021
# debug - n_true_negative: 8663341
# debug - n_false_negative: 20786
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29031
# debug - n_true_negative: 8666326
# debug - n_false_negative: 20788
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29041
# debug - n_true_negative: 8669311
# debug - n_false_negative: 20790
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29051
# debug - n_true_negative: 8672297
# debug - n_false_negative: 20791
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29061
# debug - n_true_negative: 8675276
# debug - n_false_negative: 20799
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29071
# debug - n_true_negative: 8678258
# debug - n_false_negative: 20804
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29081
# debug - n_true_negative: 8681243
# debug - n_false_negative: 20806
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29091
# debug - n_true_negative: 8684226
# debug - n_false_negative: 20811
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29101
# debug - n_true_negative: 8687201
# debug - n_false_negative: 20823
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29111
# debug - n_true_negative: 8690185
# debug - n_false_negative: 20826
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29121
# debug - n_true_negative: 8693170
# debug - n_false_negative: 20829
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29131
# debug - n_true_negative: 8696151
# debug - n_false_negative: 20835
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29141
# debug - n_true_negative: 8699132
# debug - n_false_negative: 20841
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29151
# debug - n_true_negative: 8702115
# debug - n_false_negative: 20845
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29161
# debug - n_true_negative: 8705100
# debug - n_false_negative: 20847
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29171
# debug - n_true_negative: 8708085
# debug - n_false_negative: 20850
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29181
# debug - n_true_negative: 8711058
# debug - n_false_negative: 20865
#
# debug - n_true_positive: 49
# debug - n_false_positive: 29191
# debug - n_true_negative: 8714043
# debug - n_false_negative: 20867
#
# debug - n_true_positive: 50
# debug - n_false_positive: 29200
# debug - n_true_negative: 8717024
# debug - n_false_negative: 20873
#
# debug - n_true_positive: 50
# debug - n_false_positive: 29210
# debug - n_true_negative: 8720007
# debug - n_false_negative: 20878
#
# debug - n_true_positive: 50
# debug - n_false_positive: 29220
# debug - n_true_negative: 8722979
# debug - n_false_negative: 20893
#
# debug - n_true_positive: 50
# debug - n_false_positive: 29230
# debug - n_true_negative: 8725961
# debug - n_false_negative: 20899
#
# debug - n_true_positive: 50
# debug - n_false_positive: 29240
# debug - n_true_negative: 8728942
# debug - n_false_negative: 20905
#
# debug - n_true_positive: 50
# debug - n_false_positive: 29250
# debug - n_true_negative: 8731924
# debug - n_false_negative: 20910
#
# debug - n_true_positive: 50
# debug - n_false_positive: 29260
# debug - n_true_negative: 8734907
# debug - n_false_negative: 20914
#
# debug - n_true_positive: 50
# debug - n_false_positive: 29270
# debug - n_true_negative: 8737889
# debug - n_false_negative: 20920
#
# debug - n_true_positive: 50
# debug - n_false_positive: 29280
# debug - n_true_negative: 8740870
# debug - n_false_negative: 20926
#
# debug - n_true_positive: 50
# debug - n_false_positive: 29290
# debug - n_true_negative: 8743855
# debug - n_false_negative: 20928
#
# debug - n_true_positive: 50
# debug - n_false_positive: 29300
# debug - n_true_negative: 8746839
# debug - n_false_negative: 20931
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29309
# debug - n_true_negative: 8749817
# debug - n_false_negative: 20940
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29319
# debug - n_true_negative: 8752798
# debug - n_false_negative: 20947
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29329
# debug - n_true_negative: 8755782
# debug - n_false_negative: 20950
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29339
# debug - n_true_negative: 8758762
# debug - n_false_negative: 20958
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29349
# debug - n_true_negative: 8761743
# debug - n_false_negative: 20964
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29359
# debug - n_true_negative: 8764723
# debug - n_false_negative: 20972
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29369
# debug - n_true_negative: 8767707
# debug - n_false_negative: 20975
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29379
# debug - n_true_negative: 8770692
# debug - n_false_negative: 20977
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29389
# debug - n_true_negative: 8773676
# debug - n_false_negative: 20980
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29399
# debug - n_true_negative: 8776660
# debug - n_false_negative: 20983
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29409
# debug - n_true_negative: 8779642
# debug - n_false_negative: 20988
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29419
# debug - n_true_negative: 8782623
# debug - n_false_negative: 20995
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29429
# debug - n_true_negative: 8785607
# debug - n_false_negative: 20998
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29439
# debug - n_true_negative: 8788590
# debug - n_false_negative: 21002
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29449
# debug - n_true_negative: 8791572
# debug - n_false_negative: 21008
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29459
# debug - n_true_negative: 8794555
# debug - n_false_negative: 21012
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29469
# debug - n_true_negative: 8797541
# debug - n_false_negative: 21014
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29479
# debug - n_true_negative: 8800526
# debug - n_false_negative: 21017
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29489
# debug - n_true_negative: 8803509
# debug - n_false_negative: 21021
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29499
# debug - n_true_negative: 8806491
# debug - n_false_negative: 21026
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29509
# debug - n_true_negative: 8809473
# debug - n_false_negative: 21031
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29519
# debug - n_true_negative: 8812455
# debug - n_false_negative: 21036
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29529
# debug - n_true_negative: 8815437
# debug - n_false_negative: 21041
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29539
# debug - n_true_negative: 8818420
# debug - n_false_negative: 21045
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29549
# debug - n_true_negative: 8821401
# debug - n_false_negative: 21051
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29559
# debug - n_true_negative: 8824382
# debug - n_false_negative: 21057
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29569
# debug - n_true_negative: 8827364
# debug - n_false_negative: 21062
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29579
# debug - n_true_negative: 8830337
# debug - n_false_negative: 21077
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29589
# debug - n_true_negative: 8833309
# debug - n_false_negative: 21092
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29599
# debug - n_true_negative: 8836291
# debug - n_false_negative: 21097
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29609
# debug - n_true_negative: 8839275
# debug - n_false_negative: 21101
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29619
# debug - n_true_negative: 8842259
# debug - n_false_negative: 21104
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29629
# debug - n_true_negative: 8845243
# debug - n_false_negative: 21107
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29639
# debug - n_true_negative: 8848227
# debug - n_false_negative: 21110
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29649
# debug - n_true_negative: 8851205
# debug - n_false_negative: 21119
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29659
# debug - n_true_negative: 8854188
# debug - n_false_negative: 21123
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29669
# debug - n_true_negative: 8857174
# debug - n_false_negative: 21125
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29679
# debug - n_true_negative: 8860158
# debug - n_false_negative: 21128
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29689
# debug - n_true_negative: 8863137
# debug - n_false_negative: 21136
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29699
# debug - n_true_negative: 8866113
# debug - n_false_negative: 21148
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29709
# debug - n_true_negative: 8869098
# debug - n_false_negative: 21151
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29719
# debug - n_true_negative: 8872083
# debug - n_false_negative: 21153
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29729
# debug - n_true_negative: 8875050
# debug - n_false_negative: 21173
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29739
# debug - n_true_negative: 8878034
# debug - n_false_negative: 21176
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29749
# debug - n_true_negative: 8881018
# debug - n_false_negative: 21179
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29759
# debug - n_true_negative: 8883980
# debug - n_false_negative: 21204
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29769
# debug - n_true_negative: 8886965
# debug - n_false_negative: 21206
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29779
# debug - n_true_negative: 8889945
# debug - n_false_negative: 21213
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29789
# debug - n_true_negative: 8892925
# debug - n_false_negative: 21222
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29799
# debug - n_true_negative: 8895910
# debug - n_false_negative: 21224
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29809
# debug - n_true_negative: 8898893
# debug - n_false_negative: 21228
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29819
# debug - n_true_negative: 8901877
# debug - n_false_negative: 21232
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29829
# debug - n_true_negative: 8904860
# debug - n_false_negative: 21236
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29839
# debug - n_true_negative: 8907845
# debug - n_false_negative: 21239
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29849
# debug - n_true_negative: 8910831
# debug - n_false_negative: 21240
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29859
# debug - n_true_negative: 8913816
# debug - n_false_negative: 21242
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29869
# debug - n_true_negative: 8916788
# debug - n_false_negative: 21257
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29879
# debug - n_true_negative: 8919760
# debug - n_false_negative: 21272
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29889
# debug - n_true_negative: 8922741
# debug - n_false_negative: 21278
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29899
# debug - n_true_negative: 8925719
# debug - n_false_negative: 21287
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29909
# debug - n_true_negative: 8928701
# debug - n_false_negative: 21292
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29919
# debug - n_true_negative: 8931680
# debug - n_false_negative: 21301
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29929
# debug - n_true_negative: 8934665
# debug - n_false_negative: 21303
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29939
# debug - n_true_negative: 8937644
# debug - n_false_negative: 21311
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29949
# debug - n_true_negative: 8940619
# debug - n_false_negative: 21323
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29959
# debug - n_true_negative: 8943599
# debug - n_false_negative: 21331
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29969
# debug - n_true_negative: 8946578
# debug - n_false_negative: 21339
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29979
# debug - n_true_negative: 8949563
# debug - n_false_negative: 21342
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29989
# debug - n_true_negative: 8952545
# debug - n_false_negative: 21347
#
# debug - n_true_positive: 51
# debug - n_false_positive: 29999
# debug - n_true_negative: 8955531
# debug - n_false_negative: 21349
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30009
# debug - n_true_negative: 8958501
# debug - n_false_negative: 21366
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30019
# debug - n_true_negative: 8961483
# debug - n_false_negative: 21371
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30029
# debug - n_true_negative: 8964463
# debug - n_false_negative: 21378
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30039
# debug - n_true_negative: 8967447
# debug - n_false_negative: 21381
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30049
# debug - n_true_negative: 8970432
# debug - n_false_negative: 21384
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30059
# debug - n_true_negative: 8973416
# debug - n_false_negative: 21387
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30069
# debug - n_true_negative: 8976396
# debug - n_false_negative: 21395
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30079
# debug - n_true_negative: 8979382
# debug - n_false_negative: 21396
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30089
# debug - n_true_negative: 8982368
# debug - n_false_negative: 21398
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30099
# debug - n_true_negative: 8985350
# debug - n_false_negative: 21403
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30109
# debug - n_true_negative: 8988330
# debug - n_false_negative: 21410
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30119
# debug - n_true_negative: 8991306
# debug - n_false_negative: 21421
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30129
# debug - n_true_negative: 8994288
# debug - n_false_negative: 21426
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30139
# debug - n_true_negative: 8997270
# debug - n_false_negative: 21431
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30149
# debug - n_true_negative: 9000257
# debug - n_false_negative: 21433
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30159
# debug - n_true_negative: 9003240
# debug - n_false_negative: 21437
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30169
# debug - n_true_negative: 9006221
# debug - n_false_negative: 21444
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30179
# debug - n_true_negative: 9009205
# debug - n_false_negative: 21448
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30189
# debug - n_true_negative: 9012191
# debug - n_false_negative: 21450
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30199
# debug - n_true_negative: 9015177
# debug - n_false_negative: 21452
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30209
# debug - n_true_negative: 9018164
# debug - n_false_negative: 21453
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30219
# debug - n_true_negative: 9021126
# debug - n_false_negative: 21478
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30229
# debug - n_true_negative: 9024111
# debug - n_false_negative: 21480
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30239
# debug - n_true_negative: 9027097
# debug - n_false_negative: 21481
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30249
# debug - n_true_negative: 9030078
# debug - n_false_negative: 21487
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30259
# debug - n_true_negative: 9033063
# debug - n_false_negative: 21490
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30269
# debug - n_true_negative: 9036048
# debug - n_false_negative: 21493
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30279
# debug - n_true_negative: 9039032
# debug - n_false_negative: 21496
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30289
# debug - n_true_negative: 9042017
# debug - n_false_negative: 21499
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30299
# debug - n_true_negative: 9045001
# debug - n_false_negative: 21502
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30309
# debug - n_true_negative: 9047983
# debug - n_false_negative: 21508
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30319
# debug - n_true_negative: 9050968
# debug - n_false_negative: 21511
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30329
# debug - n_true_negative: 9053954
# debug - n_false_negative: 21513
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30339
# debug - n_true_negative: 9056933
# debug - n_false_negative: 21521
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30349
# debug - n_true_negative: 9059916
# debug - n_false_negative: 21526
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30359
# debug - n_true_negative: 9062901
# debug - n_false_negative: 21528
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30369
# debug - n_true_negative: 9065885
# debug - n_false_negative: 21531
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30379
# debug - n_true_negative: 9068871
# debug - n_false_negative: 21534
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30389
# debug - n_true_negative: 9071854
# debug - n_false_negative: 21538
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30399
# debug - n_true_negative: 9074839
# debug - n_false_negative: 21541
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30409
# debug - n_true_negative: 9077817
# debug - n_false_negative: 21550
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30419
# debug - n_true_negative: 9080799
# debug - n_false_negative: 21555
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30429
# debug - n_true_negative: 9083784
# debug - n_false_negative: 21557
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30439
# debug - n_true_negative: 9086767
# debug - n_false_negative: 21561
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30449
# debug - n_true_negative: 9089751
# debug - n_false_negative: 21565
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30459
# debug - n_true_negative: 9092737
# debug - n_false_negative: 21567
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30469
# debug - n_true_negative: 9095720
# debug - n_false_negative: 21571
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30479
# debug - n_true_negative: 9098704
# debug - n_false_negative: 21574
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30489
# debug - n_true_negative: 9101687
# debug - n_false_negative: 21578
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30499
# debug - n_true_negative: 9104672
# debug - n_false_negative: 21580
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30509
# debug - n_true_negative: 9107652
# debug - n_false_negative: 21588
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30519
# debug - n_true_negative: 9110637
# debug - n_false_negative: 21591
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30529
# debug - n_true_negative: 9113617
# debug - n_false_negative: 21598
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30539
# debug - n_true_negative: 9116600
# debug - n_false_negative: 21602
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30549
# debug - n_true_negative: 9119575
# debug - n_false_negative: 21614
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30559
# debug - n_true_negative: 9122562
# debug - n_false_negative: 21615
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30569
# debug - n_true_negative: 9125548
# debug - n_false_negative: 21616
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30579
# debug - n_true_negative: 9128533
# debug - n_false_negative: 21619
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30589
# debug - n_true_negative: 9131515
# debug - n_false_negative: 21624
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30599
# debug - n_true_negative: 9134499
# debug - n_false_negative: 21627
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30609
# debug - n_true_negative: 9137483
# debug - n_false_negative: 21631
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30619
# debug - n_true_negative: 9140462
# debug - n_false_negative: 21640
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30629
# debug - n_true_negative: 9143446
# debug - n_false_negative: 21645
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30639
# debug - n_true_negative: 9146431
# debug - n_false_negative: 21647
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30649
# debug - n_true_negative: 9149416
# debug - n_false_negative: 21649
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30659
# debug - n_true_negative: 9152396
# debug - n_false_negative: 21656
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30669
# debug - n_true_negative: 9155381
# debug - n_false_negative: 21658
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30679
# debug - n_true_negative: 9158365
# debug - n_false_negative: 21663
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30689
# debug - n_true_negative: 9161349
# debug - n_false_negative: 21666
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30699
# debug - n_true_negative: 9164334
# debug - n_false_negative: 21668
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30709
# debug - n_true_negative: 9167317
# debug - n_false_negative: 21672
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30719
# debug - n_true_negative: 9170290
# debug - n_false_negative: 21686
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30729
# debug - n_true_negative: 9173275
# debug - n_false_negative: 21689
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30739
# debug - n_true_negative: 9176253
# debug - n_false_negative: 21698
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30749
# debug - n_true_negative: 9179226
# debug - n_false_negative: 21713
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30759
# debug - n_true_negative: 9182205
# debug - n_false_negative: 21721
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30769
# debug - n_true_negative: 9185186
# debug - n_false_negative: 21727
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30779
# debug - n_true_negative: 9188171
# debug - n_false_negative: 21729
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30789
# debug - n_true_negative: 9191149
# debug - n_false_negative: 21739
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30799
# debug - n_true_negative: 9194132
# debug - n_false_negative: 21743
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30809
# debug - n_true_negative: 9197111
# debug - n_false_negative: 21752
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30819
# debug - n_true_negative: 9200090
# debug - n_false_negative: 21761
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30829
# debug - n_true_negative: 9203076
# debug - n_false_negative: 21762
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30839
# debug - n_true_negative: 9206057
# debug - n_false_negative: 21768
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30849
# debug - n_true_negative: 9209040
# debug - n_false_negative: 21773
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30859
# debug - n_true_negative: 9212021
# debug - n_false_negative: 21779
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30869
# debug - n_true_negative: 9215004
# debug - n_false_negative: 21783
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30879
# debug - n_true_negative: 9217987
# debug - n_false_negative: 21787
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30889
# debug - n_true_negative: 9220965
# debug - n_false_negative: 21796
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30899
# debug - n_true_negative: 9223950
# debug - n_false_negative: 21798
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30909
# debug - n_true_negative: 9226934
# debug - n_false_negative: 21801
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30919
# debug - n_true_negative: 9229916
# debug - n_false_negative: 21806
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30929
# debug - n_true_negative: 9232901
# debug - n_false_negative: 21808
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30939
# debug - n_true_negative: 9235885
# debug - n_false_negative: 21811
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30949
# debug - n_true_negative: 9238863
# debug - n_false_negative: 21821
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30959
# debug - n_true_negative: 9241834
# debug - n_false_negative: 21837
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30969
# debug - n_true_negative: 9244819
# debug - n_false_negative: 21839
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30979
# debug - n_true_negative: 9247802
# debug - n_false_negative: 21844
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30989
# debug - n_true_negative: 9250788
# debug - n_false_negative: 21845
#
# debug - n_true_positive: 51
# debug - n_false_positive: 30999
# debug - n_true_negative: 9253767
# debug - n_false_negative: 21853
#
# debug - n_true_positive: 51
# debug - n_false_positive: 31009
# debug - n_true_negative: 9256741
# debug - n_false_negative: 21867
#
# debug - n_true_positive: 51
# debug - n_false_positive: 31019
# debug - n_true_negative: 9259720
# debug - n_false_negative: 21875
#
# debug - n_true_positive: 51
# debug - n_false_positive: 31029
# debug - n_true_negative: 9262703
# debug - n_false_negative: 21880
#
# debug - n_true_positive: 51
# debug - n_false_positive: 31039
# debug - n_true_negative: 9265683
# debug - n_false_negative: 21887
#
# debug - n_true_positive: 51
# debug - n_false_positive: 31049
# debug - n_true_negative: 9268667
# debug - n_false_negative: 21890
#
# debug - n_true_positive: 51
# debug - n_false_positive: 31059
# debug - n_true_negative: 9271652
# debug - n_false_negative: 21892
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31068
# debug - n_true_negative: 9274636
# debug - n_false_negative: 21895
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31078
# debug - n_true_negative: 9277613
# debug - n_false_negative: 21906
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31088
# debug - n_true_negative: 9280600
# debug - n_false_negative: 21907
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31098
# debug - n_true_negative: 9283585
# debug - n_false_negative: 21909
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31108
# debug - n_true_negative: 9286570
# debug - n_false_negative: 21911
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31118
# debug - n_true_negative: 9289553
# debug - n_false_negative: 21915
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31128
# debug - n_true_negative: 9292529
# debug - n_false_negative: 21926
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31138
# debug - n_true_negative: 9295512
# debug - n_false_negative: 21930
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31148
# debug - n_true_negative: 9298492
# debug - n_false_negative: 21937
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31158
# debug - n_true_negative: 9301474
# debug - n_false_negative: 21943
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31168
# debug - n_true_negative: 9304456
# debug - n_false_negative: 21948
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31178
# debug - n_true_negative: 9307437
# debug - n_false_negative: 21954
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31188
# debug - n_true_negative: 9310419
# debug - n_false_negative: 21959
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31198
# debug - n_true_negative: 9313405
# debug - n_false_negative: 21960
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31208
# debug - n_true_negative: 9316386
# debug - n_false_negative: 21966
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31218
# debug - n_true_negative: 9319372
# debug - n_false_negative: 21968
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31228
# debug - n_true_negative: 9322357
# debug - n_false_negative: 21970
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31238
# debug - n_true_negative: 9325335
# debug - n_false_negative: 21979
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31248
# debug - n_true_negative: 9328320
# debug - n_false_negative: 21983
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31258
# debug - n_true_negative: 9331302
# debug - n_false_negative: 21988
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31268
# debug - n_true_negative: 9334288
# debug - n_false_negative: 21989
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31278
# debug - n_true_negative: 9337273
# debug - n_false_negative: 21991
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31288
# debug - n_true_negative: 9340246
# debug - n_false_negative: 22005
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31298
# debug - n_true_negative: 9343231
# debug - n_false_negative: 22007
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31308
# debug - n_true_negative: 9346215
# debug - n_false_negative: 22010
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31318
# debug - n_true_negative: 9349194
# debug - n_false_negative: 22019
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31328
# debug - n_true_negative: 9352177
# debug - n_false_negative: 22024
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31338
# debug - n_true_negative: 9355165
# debug - n_false_negative: 22025
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31348
# debug - n_true_negative: 9358149
# debug - n_false_negative: 22028
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31358
# debug - n_true_negative: 9361130
# debug - n_false_negative: 22034
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31368
# debug - n_true_negative: 9364114
# debug - n_false_negative: 22037
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31378
# debug - n_true_negative: 9367096
# debug - n_false_negative: 22042
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31388
# debug - n_true_negative: 9370081
# debug - n_false_negative: 22044
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31398
# debug - n_true_negative: 9373061
# debug - n_false_negative: 22051
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31408
# debug - n_true_negative: 9376039
# debug - n_false_negative: 22060
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31418
# debug - n_true_negative: 9379020
# debug - n_false_negative: 22066
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31428
# debug - n_true_negative: 9382004
# debug - n_false_negative: 22069
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31438
# debug - n_true_negative: 9384989
# debug - n_false_negative: 22071
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31448
# debug - n_true_negative: 9387974
# debug - n_false_negative: 22073
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31458
# debug - n_true_negative: 9390960
# debug - n_false_negative: 22075
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31468
# debug - n_true_negative: 9393942
# debug - n_false_negative: 22080
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31478
# debug - n_true_negative: 9396922
# debug - n_false_negative: 22088
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31488
# debug - n_true_negative: 9399905
# debug - n_false_negative: 22092
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31498
# debug - n_true_negative: 9402889
# debug - n_false_negative: 22095
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31508
# debug - n_true_negative: 9405864
# debug - n_false_negative: 22107
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31518
# debug - n_true_negative: 9408850
# debug - n_false_negative: 22108
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31528
# debug - n_true_negative: 9411827
# debug - n_false_negative: 22118
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31538
# debug - n_true_negative: 9414811
# debug - n_false_negative: 22122
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31548
# debug - n_true_negative: 9417796
# debug - n_false_negative: 22124
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31558
# debug - n_true_negative: 9420782
# debug - n_false_negative: 22126
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31568
# debug - n_true_negative: 9423764
# debug - n_false_negative: 22131
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31578
# debug - n_true_negative: 9426742
# debug - n_false_negative: 22140
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31588
# debug - n_true_negative: 9429729
# debug - n_false_negative: 22141
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31598
# debug - n_true_negative: 9432712
# debug - n_false_negative: 22145
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31608
# debug - n_true_negative: 9435697
# debug - n_false_negative: 22147
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31618
# debug - n_true_negative: 9438682
# debug - n_false_negative: 22150
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31628
# debug - n_true_negative: 9441665
# debug - n_false_negative: 22154
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31638
# debug - n_true_negative: 9444649
# debug - n_false_negative: 22157
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31648
# debug - n_true_negative: 9447633
# debug - n_false_negative: 22160
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31658
# debug - n_true_negative: 9450617
# debug - n_false_negative: 22163
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31668
# debug - n_true_negative: 9453588
# debug - n_false_negative: 22180
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31678
# debug - n_true_negative: 9456571
# debug - n_false_negative: 22184
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31688
# debug - n_true_negative: 9459545
# debug - n_false_negative: 22197
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31698
# debug - n_true_negative: 9462528
# debug - n_false_negative: 22202
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31708
# debug - n_true_negative: 9465504
# debug - n_false_negative: 22213
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31718
# debug - n_true_negative: 9468488
# debug - n_false_negative: 22216
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31728
# debug - n_true_negative: 9471468
# debug - n_false_negative: 22224
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31738
# debug - n_true_negative: 9474445
# debug - n_false_negative: 22235
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31748
# debug - n_true_negative: 9477429
# debug - n_false_negative: 22238
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31758
# debug - n_true_negative: 9480410
# debug - n_false_negative: 22244
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31768
# debug - n_true_negative: 9483386
# debug - n_false_negative: 22256
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31778
# debug - n_true_negative: 9486370
# debug - n_false_negative: 22259
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31788
# debug - n_true_negative: 9489356
# debug - n_false_negative: 22261
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31798
# debug - n_true_negative: 9492340
# debug - n_false_negative: 22264
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31808
# debug - n_true_negative: 9495325
# debug - n_false_negative: 22267
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31818
# debug - n_true_negative: 9498305
# debug - n_false_negative: 22274
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31828
# debug - n_true_negative: 9501287
# debug - n_false_negative: 22279
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31838
# debug - n_true_negative: 9504272
# debug - n_false_negative: 22281
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31848
# debug - n_true_negative: 9507255
# debug - n_false_negative: 22286
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31858
# debug - n_true_negative: 9510237
# debug - n_false_negative: 22291
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31868
# debug - n_true_negative: 9513219
# debug - n_false_negative: 22296
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31878
# debug - n_true_negative: 9516202
# debug - n_false_negative: 22301
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31888
# debug - n_true_negative: 9519187
# debug - n_false_negative: 22304
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31898
# debug - n_true_negative: 9522172
# debug - n_false_negative: 22306
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31908
# debug - n_true_negative: 9525152
# debug - n_false_negative: 22313
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31918
# debug - n_true_negative: 9528136
# debug - n_false_negative: 22317
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31928
# debug - n_true_negative: 9531120
# debug - n_false_negative: 22320
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31938
# debug - n_true_negative: 9534104
# debug - n_false_negative: 22323
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31948
# debug - n_true_negative: 9537082
# debug - n_false_negative: 22332
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31958
# debug - n_true_negative: 9540057
# debug - n_false_negative: 22344
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31968
# debug - n_true_negative: 9543043
# debug - n_false_negative: 22345
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31978
# debug - n_true_negative: 9546026
# debug - n_false_negative: 22350
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31988
# debug - n_true_negative: 9549003
# debug - n_false_negative: 22360
#
# debug - n_true_positive: 52
# debug - n_false_positive: 31998
# debug - n_true_negative: 9551987
# debug - n_false_negative: 22363
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32008
# debug - n_true_negative: 9554972
# debug - n_false_negative: 22366
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32018
# debug - n_true_negative: 9557957
# debug - n_false_negative: 22368
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32028
# debug - n_true_negative: 9560935
# debug - n_false_negative: 22377
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32038
# debug - n_true_negative: 9563916
# debug - n_false_negative: 22383
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32048
# debug - n_true_negative: 9566892
# debug - n_false_negative: 22394
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32058
# debug - n_true_negative: 9569874
# debug - n_false_negative: 22399
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32068
# debug - n_true_negative: 9572861
# debug - n_false_negative: 22400
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32078
# debug - n_true_negative: 9575846
# debug - n_false_negative: 22402
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32088
# debug - n_true_negative: 9578832
# debug - n_false_negative: 22403
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32098
# debug - n_true_negative: 9581816
# debug - n_false_negative: 22406
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32108
# debug - n_true_negative: 9584798
# debug - n_false_negative: 22411
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32118
# debug - n_true_negative: 9587782
# debug - n_false_negative: 22414
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32128
# debug - n_true_negative: 9590767
# debug - n_false_negative: 22416
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32138
# debug - n_true_negative: 9593746
# debug - n_false_negative: 22425
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32148
# debug - n_true_negative: 9596729
# debug - n_false_negative: 22430
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32158
# debug - n_true_negative: 9599714
# debug - n_false_negative: 22432
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32168
# debug - n_true_negative: 9602700
# debug - n_false_negative: 22434
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32178
# debug - n_true_negative: 9605683
# debug - n_false_negative: 22438
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32188
# debug - n_true_negative: 9608670
# debug - n_false_negative: 22439
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32198
# debug - n_true_negative: 9611652
# debug - n_false_negative: 22444
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32208
# debug - n_true_negative: 9614637
# debug - n_false_negative: 22446
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32218
# debug - n_true_negative: 9617619
# debug - n_false_negative: 22451
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32228
# debug - n_true_negative: 9620603
# debug - n_false_negative: 22454
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32238
# debug - n_true_negative: 9623585
# debug - n_false_negative: 22460
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32248
# debug - n_true_negative: 9626571
# debug - n_false_negative: 22461
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32258
# debug - n_true_negative: 9629556
# debug - n_false_negative: 22463
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32268
# debug - n_true_negative: 9632540
# debug - n_false_negative: 22467
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32278
# debug - n_true_negative: 9635519
# debug - n_false_negative: 22475
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32288
# debug - n_true_negative: 9638503
# debug - n_false_negative: 22478
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32298
# debug - n_true_negative: 9641489
# debug - n_false_negative: 22479
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32308
# debug - n_true_negative: 9644469
# debug - n_false_negative: 22487
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32318
# debug - n_true_negative: 9647451
# debug - n_false_negative: 22492
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32328
# debug - n_true_negative: 9650435
# debug - n_false_negative: 22495
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32338
# debug - n_true_negative: 9653414
# debug - n_false_negative: 22503
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32348
# debug - n_true_negative: 9656398
# debug - n_false_negative: 22506
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32358
# debug - n_true_negative: 9659381
# debug - n_false_negative: 22510
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32368
# debug - n_true_negative: 9662363
# debug - n_false_negative: 22515
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32378
# debug - n_true_negative: 9665346
# debug - n_false_negative: 22519
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32388
# debug - n_true_negative: 9668327
# debug - n_false_negative: 22525
#
# debug - n_true_positive: 52
# debug - n_false_positive: 32398
# ...
# debug - n_false_positive: 37333
# debug - n_true_negative: 11144961
# debug - n_false_negative: 24619
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37343
# debug - n_true_negative: 11147947
# debug - n_false_negative: 24620
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37353
# debug - n_true_negative: 11150930
# debug - n_false_negative: 24624
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37363
# debug - n_true_negative: 11153915
# debug - n_false_negative: 24626
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37373
# debug - n_true_negative: 11156900
# debug - n_false_negative: 24628
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37383
# debug - n_true_negative: 11159885
# debug - n_false_negative: 24630
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37393
# debug - n_true_negative: 11162866
# debug - n_false_negative: 24636
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37403
# debug - n_true_negative: 11165852
# debug - n_false_negative: 24638
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37413
# debug - n_true_negative: 11168838
# debug - n_false_negative: 24640
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37423
# debug - n_true_negative: 11171820
# debug - n_false_negative: 24646
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37433
# debug - n_true_negative: 11174805
# debug - n_false_negative: 24649
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37443
# debug - n_true_negative: 11177790
# debug - n_false_negative: 24651
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37453
# debug - n_true_negative: 11180777
# debug - n_false_negative: 24652
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37463
# debug - n_true_negative: 11183761
# debug - n_false_negative: 24655
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37473
# debug - n_true_negative: 11186739
# debug - n_false_negative: 24664
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37483
# debug - n_true_negative: 11189725
# debug - n_false_negative: 24665
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37493
# debug - n_true_negative: 11192709
# debug - n_false_negative: 24669
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37503
# debug - n_true_negative: 11195695
# debug - n_false_negative: 24670
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37513
# debug - n_true_negative: 11198681
# debug - n_false_negative: 24672
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37523
# debug - n_true_negative: 11201667
# debug - n_false_negative: 24674
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37533
# debug - n_true_negative: 11204647
# debug - n_false_negative: 24681
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37543
# debug - n_true_negative: 11207629
# debug - n_false_negative: 24686
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37553
# debug - n_true_negative: 11210603
# debug - n_false_negative: 24700
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37563
# debug - n_true_negative: 11213587
# debug - n_false_negative: 24703
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37573
# debug - n_true_negative: 11216573
# debug - n_false_negative: 24705
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37583
# debug - n_true_negative: 11219559
# debug - n_false_negative: 24707
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37593
# debug - n_true_negative: 11222538
# debug - n_false_negative: 24717
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37603
# debug - n_true_negative: 11225522
# debug - n_false_negative: 24721
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37613
# debug - n_true_negative: 11228506
# debug - n_false_negative: 24724
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37623
# debug - n_true_negative: 11231491
# debug - n_false_negative: 24726
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37633
# debug - n_true_negative: 11234477
# debug - n_false_negative: 24727
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37643
# debug - n_true_negative: 11237462
# debug - n_false_negative: 24729
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37653
# debug - n_true_negative: 11240446
# debug - n_false_negative: 24732
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37663
# debug - n_true_negative: 11243432
# debug - n_false_negative: 24734
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37673
# debug - n_true_negative: 11246416
# debug - n_false_negative: 24737
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37683
# debug - n_true_negative: 11249401
# debug - n_false_negative: 24740
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37693
# debug - n_true_negative: 11252385
# debug - n_false_negative: 24743
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37703
# debug - n_true_negative: 11255361
# debug - n_false_negative: 24755
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37713
# debug - n_true_negative: 11258347
# debug - n_false_negative: 24757
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37723
# debug - n_true_negative: 11261330
# debug - n_false_negative: 24761
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37733
# debug - n_true_negative: 11264315
# debug - n_false_negative: 24764
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37743
# debug - n_true_negative: 11267297
# debug - n_false_negative: 24769
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37753
# debug - n_true_negative: 11270281
# debug - n_false_negative: 24772
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37763
# debug - n_true_negative: 11273265
# debug - n_false_negative: 24775
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37773
# debug - n_true_negative: 11276248
# debug - n_false_negative: 24779
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37783
# debug - n_true_negative: 11279234
# debug - n_false_negative: 24782
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37793
# debug - n_true_negative: 11282219
# debug - n_false_negative: 24785
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37803
# debug - n_true_negative: 11285203
# debug - n_false_negative: 24788
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37813
# debug - n_true_negative: 11288186
# debug - n_false_negative: 24793
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37823
# debug - n_true_negative: 11291171
# debug - n_false_negative: 24795
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37833
# debug - n_true_negative: 11294152
# debug - n_false_negative: 24801
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37843
# debug - n_true_negative: 11297135
# debug - n_false_negative: 24806
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37853
# debug - n_true_negative: 11300119
# debug - n_false_negative: 24809
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37863
# debug - n_true_negative: 11303103
# debug - n_false_negative: 24812
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37873
# debug - n_true_negative: 11306089
# debug - n_false_negative: 24814
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37883
# debug - n_true_negative: 11309074
# debug - n_false_negative: 24817
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37893
# debug - n_true_negative: 11312059
# debug - n_false_negative: 24820
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37903
# debug - n_true_negative: 11315039
# debug - n_false_negative: 24827
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37913
# debug - n_true_negative: 11318023
# debug - n_false_negative: 24830
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37923
# debug - n_true_negative: 11321009
# debug - n_false_negative: 24832
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37933
# debug - n_true_negative: 11323994
# debug - n_false_negative: 24834
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37943
# debug - n_true_negative: 11326980
# debug - n_false_negative: 24835
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37953
# debug - n_true_negative: 11329965
# debug - n_false_negative: 24840
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37963
# debug - n_true_negative: 11332950
# debug - n_false_negative: 24842
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37973
# debug - n_true_negative: 11335935
# debug - n_false_negative: 24844
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37983
# debug - n_true_negative: 11338921
# debug - n_false_negative: 24845
#
# debug - n_true_positive: 57
# debug - n_false_positive: 37993
# debug - n_true_negative: 11341907
# debug - n_false_negative: 24847
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38003
# debug - n_true_negative: 11344892
# debug - n_false_negative: 24850
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38013
# debug - n_true_negative: 11347878
# debug - n_false_negative: 24852
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38023
# debug - n_true_negative: 11350861
# debug - n_false_negative: 24856
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38033
# debug - n_true_negative: 11353845
# debug - n_false_negative: 24861
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38043
# debug - n_true_negative: 11356829
# debug - n_false_negative: 24864
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38053
# debug - n_true_negative: 11359812
# debug - n_false_negative: 24868
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38063
# debug - n_true_negative: 11362798
# debug - n_false_negative: 24870
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38073
# debug - n_true_negative: 11365785
# debug - n_false_negative: 24872
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38083
# debug - n_true_negative: 11368771
# debug - n_false_negative: 24873
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38093
# debug - n_true_negative: 11371757
# debug - n_false_negative: 24875
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38103
# debug - n_true_negative: 11374740
# debug - n_false_negative: 24879
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38113
# debug - n_true_negative: 11377724
# debug - n_false_negative: 24882
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38123
# debug - n_true_negative: 11380710
# debug - n_false_negative: 24883
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38133
# debug - n_true_negative: 11383696
# debug - n_false_negative: 24885
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38143
# debug - n_true_negative: 11386676
# debug - n_false_negative: 24892
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38153
# debug - n_true_negative: 11389662
# debug - n_false_negative: 24893
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38163
# debug - n_true_negative: 11392645
# debug - n_false_negative: 24898
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38173
# debug - n_true_negative: 11395631
# debug - n_false_negative: 24899
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38183
# debug - n_true_negative: 11398615
# debug - n_false_negative: 24903
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38193
# debug - n_true_negative: 11401600
# debug - n_false_negative: 24905
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38203
# debug - n_true_negative: 11404586
# debug - n_false_negative: 24906
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38213
# debug - n_true_negative: 11407573
# debug - n_false_negative: 24907
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38223
# debug - n_true_negative: 11410557
# debug - n_false_negative: 24910
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38233
# debug - n_true_negative: 11413544
# debug - n_false_negative: 24911
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38243
# debug - n_true_negative: 11416529
# debug - n_false_negative: 24913
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38253
# debug - n_true_negative: 11419514
# debug - n_false_negative: 24915
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38263
# debug - n_true_negative: 11422498
# debug - n_false_negative: 24918
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38273
# debug - n_true_negative: 11425482
# debug - n_false_negative: 24921
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38283
# debug - n_true_negative: 11428467
# debug - n_false_negative: 24924
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38293
# debug - n_true_negative: 11431452
# debug - n_false_negative: 24927
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38303
# debug - n_true_negative: 11434435
# debug - n_false_negative: 24931
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38313
# debug - n_true_negative: 11437420
# debug - n_false_negative: 24933
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38323
# debug - n_true_negative: 11440406
# debug - n_false_negative: 24935
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38333
# debug - n_true_negative: 11443391
# debug - n_false_negative: 24937
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38343
# debug - n_true_negative: 11446375
# debug - n_false_negative: 24940
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38353
# debug - n_true_negative: 11449360
# debug - n_false_negative: 24942
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38363
# debug - n_true_negative: 11452344
# debug - n_false_negative: 24945
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38373
# debug - n_true_negative: 11455330
# debug - n_false_negative: 24946
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38383
# debug - n_true_negative: 11458316
# debug - n_false_negative: 24947
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38393
# debug - n_true_negative: 11461301
# debug - n_false_negative: 24949
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38403
# debug - n_true_negative: 11464288
# debug - n_false_negative: 24951
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38413
# debug - n_true_negative: 11467269
# debug - n_false_negative: 24957
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38423
# debug - n_true_negative: 11470252
# debug - n_false_negative: 24961
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38433
# debug - n_true_negative: 11473237
# debug - n_false_negative: 24963
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38443
# debug - n_true_negative: 11476221
# debug - n_false_negative: 24966
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38453
# debug - n_true_negative: 11479207
# debug - n_false_negative: 24968
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38463
# debug - n_true_negative: 11482192
# debug - n_false_negative: 24971
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38473
# debug - n_true_negative: 11485177
# debug - n_false_negative: 24973
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38483
# debug - n_true_negative: 11488162
# debug - n_false_negative: 24975
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38493
# debug - n_true_negative: 11491148
# debug - n_false_negative: 24976
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38503
# debug - n_true_negative: 11494135
# debug - n_false_negative: 24977
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38513
# debug - n_true_negative: 11497121
# debug - n_false_negative: 24978
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38523
# debug - n_true_negative: 11500105
# debug - n_false_negative: 24981
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38533
# debug - n_true_negative: 11503091
# debug - n_false_negative: 24982
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38543
# debug - n_true_negative: 11506077
# debug - n_false_negative: 24984
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38553
# debug - n_true_negative: 11509061
# debug - n_false_negative: 24987
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38563
# debug - n_true_negative: 11512046
# debug - n_false_negative: 24989
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38573
# debug - n_true_negative: 11515031
# debug - n_false_negative: 24992
#
# debug - n_true_positive: 57
# debug - n_false_positive: 38583
# debug - n_true_negative: 11518012
# debug - n_false_negative: 24998
# 0.0014751552795031057
