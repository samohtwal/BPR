# %% [markdown]
# <a href="https://colab.research.google.com/github/samohtwal/BPR/blob/20221027/BPR_20221029.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import torch
import copy
from itertools import islice
from google.colab import files
import os
import matplotlib.pyplot as plt

# %%
global data_user_column_name
data_user_column_name = 'user_id'

global data_item_column_name
data_item_column_name = 'item_id'

global data_group_by_user_id_dictionary_key
data_group_by_user_id_dictionary_key = 'data_group_by_user_id'

global data_group_by_item_id_dictionary_key
data_group_by_item_id_dictionary_key = 'data_group_by_item_id'

global user_latent_factor_matrix_dictionary_key
user_latent_factor_matrix_dictionary_key = 'user_latent_factor_matrix'

global item_latent_factor_matrix_dictionary_key
item_latent_factor_matrix_dictionary_key = 'item_latent_factor_matrix'

global working_file_path
working_file_path = '/content/working/'

global user_latent_factor_matrix_file_name
user_latent_factor_matrix_file_name = 'user_latent_factor_matrix.csv'

global item_latent_factor_matrix_file_name
item_latent_factor_matrix_file_name = 'item_latent_factor_matrix.csv'

global root_mean_square_error_file_name
root_mean_square_error_file_name = 'root_mean_square_error.csv'

# %%
class DataHelper:

    def load_raw_data_dictionary(self, data_url):

        column_names = [data_user_column_name, data_item_column_name]
        raw_data = pd.read_csv(data_url, names = column_names, header=0)

        data_group_by_user_id = raw_data.groupby(data_user_column_name)[data_item_column_name].apply(list).reset_index(name=data_item_column_name).sort_values(by=[data_user_column_name])
        data_group_by_item_id = raw_data.groupby(data_item_column_name)[data_user_column_name].apply(list).reset_index(name=data_user_column_name).sort_values(by=[data_item_column_name])

        data_dictionary = {
            data_group_by_user_id_dictionary_key: data_group_by_user_id, 
            data_group_by_item_id_dictionary_key: data_group_by_item_id
        }

        return data_dictionary

    def save_latent_factor_matrix_dictionary(self, latent_factor_matrix_dictionary):

        user_latent_factor_matrix = latent_factor_matrix_dictionary[user_latent_factor_matrix_dictionary_key]
        item_latent_factor_matrix = latent_factor_matrix_dictionary[item_latent_factor_matrix_dictionary_key]
        
        if os.path.exists(working_file_path) == False:
            os.mkdir(working_file_path)

        pd.DataFrame(user_latent_factor_matrix).to_csv(working_file_path + user_latent_factor_matrix_file_name, index=False, header=False)
        pd.DataFrame(item_latent_factor_matrix).to_csv(working_file_path + item_latent_factor_matrix_file_name, index=False, header=False)

        return None

    def load_latent_factor_matrix_dictionary(self):

        user_latent_factor_matrix = pd.read_csv(working_file_path + user_latent_factor_matrix_file_name, header=None).values
        item_latent_factor_matrix = pd.read_csv(working_file_path + item_latent_factor_matrix_file_name, header=None).values

        latent_factor_matrix_dictionary = {
            user_latent_factor_matrix_dictionary_key: user_latent_factor_matrix, 
            item_latent_factor_matrix_dictionary_key: item_latent_factor_matrix
        }

        return latent_factor_matrix_dictionary
    
    def save_root_mean_square_error(self, errors):
        if os.path.exists(working_file_path) == False:
            os.mkdir(working_file_path)
        pd.DataFrame(errors).to_csv(working_file_path + root_mean_square_error_file_name, index=False, header=False)

        return None

# %%
class BayseianPersonalizedRankingModel:

    def __init__(self, random_seed = 1234, n_latent_factor = 15, n_batch = 10, learning_rate = 0.01, regularization_constant = 0.01):
        self.random_seed = random_seed
        self.n_latent_factor = n_latent_factor
        self.n_batch = n_batch
        self.learning_rate = learning_rate
        self.regularization_constant = regularization_constant

    def fit(self, training_data_dictionary):

        training_data_group_by_user_id = training_data_dictionary[data_group_by_user_id_dictionary_key]
        training_data_group_by_item_id = training_data_dictionary[data_group_by_item_id_dictionary_key]

        n_user = len(training_data_group_by_user_id[data_user_column_name])
        n_item = len(training_data_group_by_item_id[data_item_column_name])

        rstate = np.random.RandomState(self.random_seed)

        user_latent_factor_matrix = rstate.normal(size = (n_user, self.n_latent_factor))
        item_latent_factor_matrix = rstate.normal(size = (n_item, self.n_latent_factor))

        user_item_rating_matrix = self._create_user_item_rating_matrix(training_data_group_by_user_id, training_data_group_by_item_id)

        user_latent_factor_matrixes = []
        item_latent_factor_matrixes = []
        root_mean_square_errors = []

        is_converge = True
        index = 0
        while is_converge:

            # self.learning_rate = self.learning_rate * np.exp(-5*index)
            # self.learning_rate = self.learning_rate / (1 + 2 * index)
            
            sample_latent_factor_matrix_row_indexes = self._create_sample_latent_factor_matrix_row_indexes(training_data_group_by_user_id, training_data_group_by_item_id)
            sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes = sample_latent_factor_matrix_row_indexes
            user_latent_factor_matrix, item_latent_factor_matrix = self._update_sample_latent_factor_matrix_rows(user_latent_factor_matrix, item_latent_factor_matrix, sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes)
            
            sum_of_square_error = np.sum((user_item_rating_matrix - self._predict(user_latent_factor_matrix, item_latent_factor_matrix))**2)
            root_mean_square_error = np.sqrt((sum_of_square_error / n_user * n_item))

            user_latent_factor_matrixes.append(user_latent_factor_matrix)
            item_latent_factor_matrixes.append(item_latent_factor_matrix)
            root_mean_square_errors.append(root_mean_square_error)
            
            print('debug - iteration:', index+1, end='\n')
            print('debug - root_mean_square_error:', root_mean_square_error, end='\n')
            print('', end='\n')
            
            if (root_mean_square_errors[index] > root_mean_square_errors[index-1] 
                and root_mean_square_errors[index-1] > root_mean_square_errors[index-2]
                and root_mean_square_errors[index-2] > root_mean_square_errors[index-3]):
            # if index == 10:
                is_converge = False

            index = index + 1

        latent_factor_matrix_dictionary = {
            user_latent_factor_matrix_dictionary_key: user_latent_factor_matrixes[index-4], 
            item_latent_factor_matrix_dictionary_key: item_latent_factor_matrixes[index-4]
        }

        return latent_factor_matrix_dictionary, root_mean_square_errors[0:index-4]

    def _create_user_item_rating_matrix(self, training_data_group_by_user_id, training_data_group_by_item_id):

        n_user = len(training_data_group_by_user_id[data_user_column_name])
        n_item = len(training_data_group_by_item_id[data_item_column_name])

        user_ids = training_data_group_by_user_id[data_user_column_name].tolist()
        item_ids = training_data_group_by_item_id[data_item_column_name].tolist()

        user_item_rating_matrix = np.zeros((n_user, n_item), dtype = np.int64)
        for user_id_index, user_id in enumerate(user_ids):
            item_id_indexes = np.where(np.isin(training_data_group_by_user_id.iloc[user_id_index][data_item_column_name],item_ids))[0]
            for item_id_index in item_id_indexes:
                user_item_rating_matrix[user_id_index, item_id_index] = 1

        return user_item_rating_matrix

    def _create_sample_latent_factor_matrix_row_indexes(self, training_data_group_by_user_id, training_data_group_by_item_id):

        n_user = len(training_data_group_by_user_id[data_user_column_name])
        n_item = len(training_data_group_by_item_id[data_item_column_name])

        item_ids = training_data_group_by_item_id[data_item_column_name].tolist()

        sample_user_id_indexes = np.random.choice(n_user, size = self.n_batch, replace = False)
        sample_positive_item_id_indexes = np.zeros(self.n_batch, dtype = np.int64)
        sample_negative_item_id_indexes = np.zeros(self.n_batch, dtype = np.int64)

        for index, sampled_user_id_index in enumerate(sample_user_id_indexes):
            possible_positive_item_ids = training_data_group_by_user_id.iloc[sampled_user_id_index][data_item_column_name]
            possible_negative_item_ids = list(set(item_ids).difference(possible_positive_item_ids))
            sample_positive_item_id = np.random.choice(possible_positive_item_ids)
            sample_negative_item_id = np.random.choice(possible_negative_item_ids)
            sample_positive_item_id_indexes[index] = item_ids.index(sample_positive_item_id)
            sample_negative_item_id_indexes[index] = item_ids.index(sample_negative_item_id)

        return sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes

    def _update_sample_latent_factor_matrix_rows(self, user_latent_factor_matrix, item_latent_factor_matrix, sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes):

        sample_user_latent_factor_matrix_tuple = user_latent_factor_matrix[sample_user_id_indexes]
        sample_item_latent_factor_matrix_positive_item_tuple = item_latent_factor_matrix[sample_positive_item_id_indexes]
        sample_item_latent_factor_matrix_negative_item_tuple = item_latent_factor_matrix[sample_negative_item_id_indexes]

        r_uij = np.sum(sample_user_latent_factor_matrix_tuple * (sample_item_latent_factor_matrix_positive_item_tuple - sample_item_latent_factor_matrix_negative_item_tuple), axis = 1)
        sigmoid = np.exp(-r_uij) / (1.0 + np.exp(-r_uij))
        sigmoid_tiled = np.tile(sigmoid, (self.n_latent_factor, 1)).T

        gradient_user = sigmoid_tiled * (sample_item_latent_factor_matrix_negative_item_tuple - sample_item_latent_factor_matrix_positive_item_tuple) + self.regularization_constant * sample_user_latent_factor_matrix_tuple
        gradient_positive_item = sigmoid_tiled * -sample_user_latent_factor_matrix_tuple + self.regularization_constant * sample_item_latent_factor_matrix_positive_item_tuple
        gradient_negative_item = sigmoid_tiled * sample_user_latent_factor_matrix_tuple + self.regularization_constant * sample_item_latent_factor_matrix_negative_item_tuple

        user_latent_factor_matrix[sample_user_id_indexes] -= self.learning_rate * gradient_user
        item_latent_factor_matrix[sample_positive_item_id_indexes] -= self.learning_rate * gradient_positive_item
        item_latent_factor_matrix[sample_negative_item_id_indexes] -= self.learning_rate * gradient_negative_item

        return user_latent_factor_matrix, item_latent_factor_matrix

    def recommend(self, testing_data_dictionary, training_data_dictionary, latent_factor_matrix_dictionary, n_best_recommendation):

        testing_data_group_by_user_id = testing_data_dictionary[data_group_by_user_id_dictionary_key]

        n_user = len(testing_data_group_by_user_id[data_user_column_name])
        user_ids = user_ids = testing_data_group_by_user_id[data_user_column_name].tolist()

        recommendation_user_ids = []
        recommendation_item_ids = []
        for user_id in user_ids:
            best_recommendition_item_ids = self.recommend_user(training_data_dictionary, latent_factor_matrix_dictionary, user_id, n_best_recommendation)
            for item_id in best_recommendition_item_ids:
                recommendation_user_ids.append(user_id)
                recommendation_item_ids.append(item_id)

        data = {'user_id': recommendation_user_ids, 'item_id': recommendation_item_ids}
        recommendation_data = pd.DataFrame.from_dict(data)

        recommendation_data_group_by_user_id = recommendation_data.groupby(data_user_column_name)[data_item_column_name].apply(list).reset_index(name=data_item_column_name).sort_values(by=[data_user_column_name])
        recommendation_data_group_by_item_id = recommendation_data.groupby(data_item_column_name)[data_user_column_name].apply(list).reset_index(name=data_user_column_name).sort_values(by=[data_item_column_name])

        recommendation_data_dictionary = {
            data_group_by_user_id_dictionary_key: recommendation_data_group_by_user_id, 
            data_group_by_item_id_dictionary_key: recommendation_data_group_by_item_id
        }

        return recommendation_data_dictionary

    def recommend_user(self, training_data_dictionary, latent_factor_matrix_dictionary, user_id, n_best_recommendation):

        training_data_group_by_user_id = training_data_dictionary[data_group_by_user_id_dictionary_key]
        training_data_group_by_item_id = training_data_dictionary[data_group_by_item_id_dictionary_key]

        user_latent_factor_matrix = latent_factor_matrix_dictionary[user_latent_factor_matrix_dictionary_key]
        item_latent_factor_matrix = latent_factor_matrix_dictionary[item_latent_factor_matrix_dictionary_key]

        user_ids = training_data_group_by_user_id[data_user_column_name].tolist()
        item_ids = training_data_group_by_item_id[data_item_column_name].tolist()

        n_item = len(training_data_group_by_item_id[data_item_column_name])

        user_index = user_ids.index(user_id)

        scores = self._predict_user(user_latent_factor_matrix, item_latent_factor_matrix, user_index)

        item_score_dictionary = {item_ids[i]: scores[i] for i in range(len(item_ids))}
        positive_item_ids = training_data_group_by_user_id.iloc[user_index][data_item_column_name]

        item_score_dictionary = {item_ids[i]: scores[i] for i in range(len(item_ids))}
        item_score_dictionary = {key: item_score_dictionary[key] for key in item_ids if key not in positive_item_ids}
        item_score_dictionary = dict(sorted(item_score_dictionary.items(), key=lambda item: item[1], reverse=True))

        best_recommendition_items = dict(islice(item_score_dictionary.items(), n_best_recommendation))

        best_recommendition_item_ids = list(best_recommendition_items.keys())[0:n_best_recommendation]

        '''
        print('debug - user_id:', user_id, end='\n')
        print('debug - best_recommendation:', best_recommendition_item_ids, end='\n')
        print('', end='\n')
        '''

        return best_recommendition_item_ids

    def _predict(self, user_latent_factor_matrix, item_latent_factor_matrix):
        return user_latent_factor_matrix.dot(item_latent_factor_matrix.T)

    def _predict_user(self, user_latent_factor_matrix, item_latent_factor_matrix, user_index):
        return user_latent_factor_matrix[user_index].dot(item_latent_factor_matrix.T)

# %%
class ModelAnalyzerHelper:

    def plot_error_chart(self, root_mean_square_errors, bayseian_personalized_ranking_parameters):

        x  = range(len(root_mean_square_errors))
        y = root_mean_square_errors
        plt.plot(x, y, label='Learning Rate = ' + str(bayseian_personalized_ranking_parameters['learning_rate']))
        plt.plot()

        plt.xlabel("Iteration")
        plt.ylabel("Root Mean Square Error")
        plt.title("Root Mean Square Error / Iteration")
        plt.legend()
        plt.show()

        return None
    
    def evaluate(self, testing_data_dictionary, recommendation_data_dictionary):

        testing_data_group_by_user_id = testing_data_dictionary[data_group_by_user_id_dictionary_key]
        testing_user_ids = testing_data_group_by_user_id[data_user_column_name].tolist()

        testing_data_group_by_item_id = testing_data_dictionary[data_group_by_item_id_dictionary_key]
        testing_item_ids = testing_data_group_by_item_id[data_item_column_name].tolist()

        recommendation_data_group_by_user_id = recommendation_data_dictionary[data_group_by_user_id_dictionary_key]
        recommendation_user_ids = recommendation_data_group_by_user_id[data_user_column_name].tolist()

        print('debug - testing_data_group_by_user_id.shpape:', end='\n')
        print(testing_data_group_by_user_id.shape, end='\n')
        print('', end='\n')

        print('debug - recommendation_data_group_by_user_id.shpape:', end='\n')
        print(recommendation_data_group_by_user_id.shape, end='\n')
        print('', end='\n')

        n_true_positive = 0
        n_false_positive = 0
        n_true_negative = 0
        n_false_negative = 0

        for index, recommendation_user_id in enumerate(recommendation_user_ids):
            
            positive_testing_item_ids = testing_data_group_by_user_id.iloc[index][data_item_column_name]
            negative_testing_item_ids = list(set(testing_item_ids).difference(positive_testing_item_ids))
            positive_predition_item_ids = recommendation_data_group_by_user_id.iloc[index][data_item_column_name]
            negative_predition_item_ids = list(set(testing_item_ids).difference(positive_predition_item_ids))

            for positive_predition_item_id in positive_predition_item_ids:
                if positive_predition_item_id in positive_testing_item_ids: n_true_positive = n_true_positive + 1
                if positive_predition_item_id not in positive_testing_item_ids: n_false_positive = n_false_positive + 1

            for negative_predition_item_id in negative_predition_item_ids:
                if negative_predition_item_id in negative_testing_item_ids: n_true_negative = n_true_negative + 1
                if negative_predition_item_id not in negative_testing_item_ids: n_false_negative = n_false_negative + 1

            print('debug - n_true_positive:', n_true_positive, end='\n')
            print('debug - n_false_positive:', n_false_positive, end='\n')
            print('debug - n_true_negative:', n_true_negative, end='\n')
            print('debug - n_false_negative:', n_false_negative, end='\n')
            print('', end='\n')

        true_positive_rate = n_true_positive / (n_true_positive + n_false_negative)
        false_positive_rate = n_false_positive / (n_false_positive + n_true_negative)

        return true_positive_rate, false_positive_rate

# %%
data_helper = DataHelper()
bayseian_personalized_ranking_parameters = {
    'random_seed' : 1234, 
    'n_latent_factor' : 15, 
    'n_batch' : 1000, 
    'learning_rate' : 0.1, 
    'regularization_constant' : 0.1
}
bayseian_personalized_ranking_model = BayseianPersonalizedRankingModel(**bayseian_personalized_ranking_parameters)
model_analyzer_helper = ModelAnalyzerHelper()

# %%
training_data_url = 'https://raw.githubusercontent.com/samohtwal/BPR/20221027/data/train-20221026.csv'
training_data_dictionary = data_helper.load_raw_data_dictionary(training_data_url)

# %%
latent_factor_matrix_dictionary, root_mean_square_errors = bayseian_personalized_ranking_model.fit(training_data_dictionary)
data_helper.save_latent_factor_matrix_dictionary(latent_factor_matrix_dictionary)
data_helper.save_root_mean_square_error(root_mean_square_errors)
# Out:
# debug - iteration: 1
# debug - root_mean_square_error: 11723.278757099908
#
# debug - iteration: 2
# debug - root_mean_square_error: 11579.77772019943
#
# debug - iteration: 3
# debug - root_mean_square_error: 11431.64793762178
#
# debug - iteration: 4
# debug - root_mean_square_error: 11287.404079747199
#
# debug - iteration: 5
# debug - root_mean_square_error: 11150.16805188887
#
# debug - iteration: 6
# debug - root_mean_square_error: 11012.372523903095
#
# debug - iteration: 7
# debug - root_mean_square_error: 10881.281053577752
#
# debug - iteration: 8
# debug - root_mean_square_error: 10757.793763018864
#
# debug - iteration: 9
# debug - root_mean_square_error: 10632.640204844673
#
# debug - iteration: 10
# debug - root_mean_square_error: 10504.739895291255
#
# debug - iteration: 11
# debug - root_mean_square_error: 10382.10538486583

# %%
model_analyzer_helper.plot_error_chart(root_mean_square_errors, bayseian_personalized_ranking_parameters)

# %%
latent_factor_matrix_dictionary = data_helper.load_latent_factor_matrix_dictionary()

# %%
vali_data_url = 'https://raw.githubusercontent.com/samohtwal/BPR/20221027/data/vali-20221026.csv'
vali_data_dictionary = data_helper.load_raw_data_dictionary(vali_data_url)

user_ids = vali_data_dictionary[data_group_by_user_id_dictionary_key][data_user_column_name].tolist()
user_id = np.random.choice(user_ids)
n_best_recommendation = 10
best_recommendation = bayseian_personalized_ranking_model.recommend_user(training_data_dictionary, latent_factor_matrix_dictionary, user_id, n_best_recommendation)

recommendation_data_dictionary = bayseian_personalized_ranking_model.recommend(vali_data_dictionary, training_data_dictionary, latent_factor_matrix_dictionary, n_best_recommendation)

# %%
model_analyzer_helper = ModelAnalyzerHelper()
model_analyzer_helper.evaluate(vali_data_dictionary, recommendation_data_dictionary)
# Out:
# debug - testing_data_group_by_user_id.shpape:
# (3864, 2)
#
# debug - recommendation_data_group_by_user_id.shpape:
# (3864, 2)
#
# debug - n_true_positive: 0
# debug - n_false_positive: 100
# debug - n_true_negative: 2895
# debug - n_false_negative: 4
#
# debug - n_true_positive: 0
# debug - n_false_positive: 200
# debug - n_true_negative: 5784
# debug - n_false_negative: 13
#
# debug - n_true_positive: 0
# debug - n_false_positive: 300
# debug - n_true_negative: 8684
# debug - n_false_negative: 14
#
# debug - n_true_positive: 1
# debug - n_false_positive: 399
# debug - n_true_negative: 11537
# debug - n_false_negative: 59
#
# debug - n_true_positive: 1
# debug - n_false_positive: 499
# debug - n_true_negative: 14438
# debug - n_false_negative: 60
#
# debug - n_true_positive: 1
# debug - n_false_positive: 599
# debug - n_true_negative: 17334
# debug - n_false_negative: 63
#
# debug - n_true_positive: 1
# debug - n_false_positive: 699
# debug - n_true_negative: 20229
# debug - n_false_negative: 67
#
# debug - n_true_positive: 1
# debug - n_false_positive: 799
# debug - n_true_negative: 23122
# debug - n_false_negative: 72
#
# debug - n_true_positive: 2
# debug - n_false_positive: 898
# debug - n_true_negative: 26022
# debug - n_false_negative: 73
#
# debug - n_true_positive: 2
# debug - n_false_positive: 998
# debug - n_true_negative: 28916
# debug - n_false_negative: 78
#
# debug - n_true_positive: 3
# debug - n_false_positive: 1097
# debug - n_true_negative: 31815
# debug - n_false_negative: 81
#
# debug - n_true_positive: 3
# debug - n_false_positive: 1197
# debug - n_true_negative: 34709
# debug - n_false_negative: 84
#
# debug - n_true_positive: 3
# debug - n_false_positive: 1297
# debug - n_true_negative: 37603
# debug - n_false_negative: 89
#
# debug - n_true_positive: 5
# debug - n_false_positive: 1395
# debug - n_true_negative: 40502
# debug - n_false_negative: 92
#
# debug - n_true_positive: 5
# debug - n_false_positive: 1495
# debug - n_true_negative: 43399
# debug - n_false_negative: 94
#
# debug - n_true_positive: 5
# debug - n_false_positive: 1595
# debug - n_true_negative: 46298
# debug - n_false_negative: 95
#
# debug - n_true_positive: 5
# debug - n_false_positive: 1695
# debug - n_true_negative: 49191
# debug - n_false_negative: 105
#
# debug - n_true_positive: 5
# debug - n_false_positive: 1795
# debug - n_true_negative: 52087
# debug - n_false_negative: 107
#
# debug - n_true_positive: 5
# debug - n_false_positive: 1895
# debug - n_true_negative: 54976
# debug - n_false_negative: 119
#
# debug - n_true_positive: 5
# debug - n_false_positive: 1995
# debug - n_true_negative: 57857
# debug - n_false_negative: 135
#
# debug - n_true_positive: 5
# debug - n_false_positive: 2095
# debug - n_true_negative: 60755
# debug - n_false_negative: 136
#
# debug - n_true_positive: 5
# debug - n_false_positive: 2195
# debug - n_true_negative: 63652
# debug - n_false_negative: 137
#
# debug - n_true_positive: 5
# debug - n_false_positive: 2295
# debug - n_true_negative: 66545
# debug - n_false_negative: 141
#
# debug - n_true_positive: 5
# debug - n_false_positive: 2395
# debug - n_true_negative: 69441
# debug - n_false_negative: 145
#
# debug - n_true_positive: 5
# debug - n_false_positive: 2495
# debug - n_true_negative: 72329
# debug - n_false_negative: 156
#
# debug - n_true_positive: 5
# debug - n_false_positive: 2595
# debug - n_true_negative: 75211
# debug - n_false_negative: 172
#
# debug - n_true_positive: 6
# debug - n_false_positive: 2694
# debug - n_true_negative: 78110
# debug - n_false_negative: 172
#
# debug - n_true_positive: 6
# debug - n_false_positive: 2794
# debug - n_true_negative: 81008
# debug - n_false_negative: 174
#
# debug - n_true_positive: 6
# debug - n_false_positive: 2894
# debug - n_true_negative: 83895
# debug - n_false_negative: 185
#
# debug - n_true_positive: 6
# debug - n_false_positive: 2994
# debug - n_true_negative: 86797
# debug - n_false_negative: 187
#
# debug - n_true_positive: 6
# debug - n_false_positive: 3094
# debug - n_true_negative: 89691
# debug - n_false_negative: 191
#
# debug - n_true_positive: 6
# debug - n_false_positive: 3194
# debug - n_true_negative: 92583
# debug - n_false_negative: 200
#
# debug - n_true_positive: 6
# debug - n_false_positive: 3294
# debug - n_true_negative: 95481
# debug - n_false_negative: 201
#
# debug - n_true_positive: 6
# debug - n_false_positive: 3394
# debug - n_true_negative: 98375
# debug - n_false_negative: 205
#
# debug - n_true_positive: 7
# debug - n_false_positive: 3493
# debug - n_true_negative: 101265
# debug - n_false_negative: 215
#
# debug - n_true_positive: 7
# debug - n_false_positive: 3593
# debug - n_true_negative: 104163
# debug - n_false_negative: 217
#
# debug - n_true_positive: 7
# debug - n_false_positive: 3693
# debug - n_true_negative: 107058
# debug - n_false_negative: 222
#
# debug - n_true_positive: 7
# debug - n_false_positive: 3793
# debug - n_true_negative: 109954
# debug - n_false_negative: 224
#
# debug - n_true_positive: 7
# debug - n_false_positive: 3893
# debug - n_true_negative: 112847
# debug - n_false_negative: 229
#
# debug - n_true_positive: 8
# debug - n_false_positive: 3992
# debug - n_true_negative: 115749
# debug - n_false_negative: 230
#
# debug - n_true_positive: 8
# debug - n_false_positive: 4092
# debug - n_true_negative: 118641
# debug - n_false_negative: 235
#
# debug - n_true_positive: 10
# debug - n_false_positive: 4190
# debug - n_true_negative: 121512
# debug - n_false_negative: 264
#
# debug - n_true_positive: 10
# debug - n_false_positive: 4290
# debug - n_true_negative: 124399
# debug - n_false_negative: 277
#
# debug - n_true_positive: 12
# debug - n_false_positive: 4388
# debug - n_true_negative: 127266
# debug - n_false_negative: 309
#
# debug - n_true_positive: 12
# debug - n_false_positive: 4488
# debug - n_true_negative: 130148
# debug - n_false_negative: 330
#
# debug - n_true_positive: 12
# debug - n_false_positive: 4588
# debug - n_true_negative: 133027
# debug - n_false_negative: 349
#
# debug - n_true_positive: 14
# debug - n_false_positive: 4686
# debug - n_true_negative: 135915
# debug - n_false_negative: 360
#
# debug - n_true_positive: 15
# debug - n_false_positive: 4785
# debug - n_true_negative: 138811
# debug - n_false_negative: 367
#
# debug - n_true_positive: 15
# debug - n_false_positive: 4885
# debug - n_true_negative: 141694
# debug - n_false_negative: 384
#
# debug - n_true_positive: 15
# debug - n_false_positive: 4985
# debug - n_true_negative: 144577
# debug - n_false_negative: 399
#
# debug - n_true_positive: 15
# debug - n_false_positive: 5085
# debug - n_true_negative: 147472
# debug - n_false_negative: 402
#
# debug - n_true_positive: 16
# debug - n_false_positive: 5184
# debug - n_true_negative: 150364
# debug - n_false_negative: 410
#
# debug - n_true_positive: 17
# debug - n_false_positive: 5283
# debug - n_true_negative: 153250
# debug - n_false_negative: 424
#
# debug - n_true_positive: 18
# debug - n_false_positive: 5382
# debug - n_true_negative: 156149
# debug - n_false_negative: 424
#
# debug - n_true_positive: 18
# debug - n_false_positive: 5482
# debug - n_true_negative: 159044
# debug - n_false_negative: 430
#
# debug - n_true_positive: 18
# debug - n_false_positive: 5582
# debug - n_true_negative: 161937
# debug - n_false_negative: 438
#
# debug - n_true_positive: 18
# debug - n_false_positive: 5682
# debug - n_true_negative: 164828
# debug - n_false_negative: 445
#
# debug - n_true_positive: 18
# debug - n_false_positive: 5782
# debug - n_true_negative: 167729
# debug - n_false_negative: 446
#
# debug - n_true_positive: 18
# debug - n_false_positive: 5882
# debug - n_true_negative: 170626
# debug - n_false_negative: 450
#
# debug - n_true_positive: 18
# debug - n_false_positive: 5982
# debug - n_true_negative: 173520
# debug - n_false_negative: 456
#
# debug - n_true_positive: 18
# debug - n_false_positive: 6082
# debug - n_true_negative: 176415
# debug - n_false_negative: 460
#
# debug - n_true_positive: 18
# debug - n_false_positive: 6182
# debug - n_true_negative: 179313
# debug - n_false_negative: 462
#
# debug - n_true_positive: 18
# debug - n_false_positive: 6282
# debug - n_true_negative: 182206
# debug - n_false_negative: 468
#
# debug - n_true_positive: 18
# debug - n_false_positive: 6382
# debug - n_true_negative: 185093
# debug - n_false_negative: 481
#
# debug - n_true_positive: 18
# debug - n_false_positive: 6482
# debug - n_true_negative: 187965
# debug - n_false_negative: 508
#
# debug - n_true_positive: 18
# debug - n_false_positive: 6582
# debug - n_true_negative: 190858
# debug - n_false_negative: 514
#
# debug - n_true_positive: 18
# debug - n_false_positive: 6682
# debug - n_true_negative: 193742
# debug - n_false_negative: 528
#
# debug - n_true_positive: 18
# debug - n_false_positive: 6782
# debug - n_true_negative: 196639
# debug - n_false_negative: 530
#
# debug - n_true_positive: 18
# debug - n_false_positive: 6882
# debug - n_true_negative: 199535
# debug - n_false_negative: 534
#
# debug - n_true_positive: 19
# debug - n_false_positive: 6981
# debug - n_true_negative: 202421
# debug - n_false_negative: 548
#
# debug - n_true_positive: 19
# debug - n_false_positive: 7081
# debug - n_true_negative: 205319
# debug - n_false_negative: 552
#
# debug - n_true_positive: 19
# debug - n_false_positive: 7181
# debug - n_true_negative: 208211
# debug - n_false_negative: 558
#
# debug - n_true_positive: 19
# debug - n_false_positive: 7281
# debug - n_true_negative: 211102
# debug - n_false_negative: 564
#
# debug - n_true_positive: 19
# debug - n_false_positive: 7381
# debug - n_true_negative: 213993
# debug - n_false_negative: 572
#
# debug - n_true_positive: 19
# debug - n_false_positive: 7481
# debug - n_true_negative: 216889
# debug - n_false_negative: 574
#
# debug - n_true_positive: 19
# debug - n_false_positive: 7581
# debug - n_true_negative: 219773
# debug - n_false_negative: 590
#
# debug - n_true_positive: 19
# debug - n_false_positive: 7681
# debug - n_true_negative: 222666
# debug - n_false_negative: 595
#
# debug - n_true_positive: 19
# debug - n_false_positive: 7781
# debug - n_true_negative: 225566
# debug - n_false_negative: 598
#
# debug - n_true_positive: 19
# debug - n_false_positive: 7881
# debug - n_true_negative: 228457
# debug - n_false_negative: 605
#
# debug - n_true_positive: 19
# debug - n_false_positive: 7981
# debug - n_true_negative: 231353
# debug - n_false_negative: 607
#
# debug - n_true_positive: 19
# debug - n_false_positive: 8081
# debug - n_true_negative: 234248
# debug - n_false_negative: 611
#
# debug - n_true_positive: 19
# debug - n_false_positive: 8181
# debug - n_true_negative: 237139
# debug - n_false_negative: 619
#
# debug - n_true_positive: 19
# debug - n_false_positive: 8281
# debug - n_true_negative: 240025
# debug - n_false_negative: 633
#
# debug - n_true_positive: 19
# debug - n_false_positive: 8381
# debug - n_true_negative: 242911
# debug - n_false_negative: 648
#
# debug - n_true_positive: 19
# debug - n_false_positive: 8481
# debug - n_true_negative: 245807
# debug - n_false_negative: 651
#
# debug - n_true_positive: 19
# debug - n_false_positive: 8581
# debug - n_true_negative: 248697
# debug - n_false_negative: 659
#
# debug - n_true_positive: 19
# debug - n_false_positive: 8681
# debug - n_true_negative: 251591
# debug - n_false_negative: 664
#
# debug - n_true_positive: 19
# debug - n_false_positive: 8781
# debug - n_true_negative: 254489
# debug - n_false_negative: 668
#
# debug - n_true_positive: 19
# debug - n_false_positive: 8881
# debug - n_true_negative: 257385
# debug - n_false_negative: 674
#
# debug - n_true_positive: 19
# debug - n_false_positive: 8981
# debug - n_true_negative: 260279
# debug - n_false_negative: 678
#
# debug - n_true_positive: 19
# debug - n_false_positive: 9081
# debug - n_true_negative: 263174
# debug - n_false_negative: 682
#
# debug - n_true_positive: 20
# debug - n_false_positive: 9180
# debug - n_true_negative: 266067
# debug - n_false_negative: 690
#
# debug - n_true_positive: 21
# debug - n_false_positive: 9279
# debug - n_true_negative: 268958
# debug - n_false_negative: 697
#
# debug - n_true_positive: 21
# debug - n_false_positive: 9379
# debug - n_true_negative: 271840
# debug - n_false_negative: 714
#
# debug - n_true_positive: 21
# debug - n_false_positive: 9479
# debug - n_true_negative: 274738
# debug - n_false_negative: 716
#
# debug - n_true_positive: 21
# debug - n_false_positive: 9579
# debug - n_true_negative: 277625
# debug - n_false_negative: 730
#
# debug - n_true_positive: 21
# debug - n_false_positive: 9679
# debug - n_true_negative: 280513
# debug - n_false_negative: 743
#
# debug - n_true_positive: 21
# debug - n_false_positive: 9779
# debug - n_true_negative: 283404
# debug - n_false_negative: 751
#
# debug - n_true_positive: 21
# debug - n_false_positive: 9879
# debug - n_true_negative: 286300
# debug - n_false_negative: 753
#
# debug - n_true_positive: 21
# debug - n_false_positive: 9979
# debug - n_true_negative: 289193
# debug - n_false_negative: 759
#
# debug - n_true_positive: 21
# debug - n_false_positive: 10079
# debug - n_true_negative: 292091
# debug - n_false_negative: 760
#
# debug - n_true_positive: 21
# debug - n_false_positive: 10179
# debug - n_true_negative: 294983
# debug - n_false_negative: 768
#
# debug - n_true_positive: 21
# debug - n_false_positive: 10279
# debug - n_true_negative: 297876
# debug - n_false_negative: 774
#
# debug - n_true_positive: 21
# debug - n_false_positive: 10379
# debug - n_true_negative: 300774
# debug - n_false_negative: 777
#
# debug - n_true_positive: 21
# debug - n_false_positive: 10479
# debug - n_true_negative: 303655
# debug - n_false_negative: 795
#
# debug - n_true_positive: 21
# debug - n_false_positive: 10579
# debug - n_true_negative: 306552
# debug - n_false_negative: 799
#
# debug - n_true_positive: 21
# debug - n_false_positive: 10679
# debug - n_true_negative: 309446
# debug - n_false_negative: 803
#
# debug - n_true_positive: 21
# debug - n_false_positive: 10779
# debug - n_true_negative: 312332
# debug - n_false_negative: 815
#
# debug - n_true_positive: 21
# debug - n_false_positive: 10879
# debug - n_true_negative: 315214
# debug - n_false_negative: 834
#
# debug - n_true_positive: 21
# debug - n_false_positive: 10979
# debug - n_true_negative: 318106
# debug - n_false_negative: 841
#
# debug - n_true_positive: 21
# debug - n_false_positive: 11079
# debug - n_true_negative: 321004
# debug - n_false_negative: 843
#
# debug - n_true_positive: 21
# debug - n_false_positive: 11179
# debug - n_true_negative: 323902
# debug - n_false_negative: 844
#
# debug - n_true_positive: 21
# debug - n_false_positive: 11279
# debug - n_true_negative: 326796
# debug - n_false_negative: 851
#
# debug - n_true_positive: 21
# debug - n_false_positive: 11379
# debug - n_true_negative: 329694
# debug - n_false_negative: 856
#
# debug - n_true_positive: 21
# debug - n_false_positive: 11479
# debug - n_true_negative: 332590
# debug - n_false_negative: 862
#
# debug - n_true_positive: 21
# debug - n_false_positive: 11579
# debug - n_true_negative: 335477
# debug - n_false_negative: 873
#
# debug - n_true_positive: 21
# debug - n_false_positive: 11679
# debug - n_true_negative: 338366
# debug - n_false_negative: 881
#
# debug - n_true_positive: 21
# debug - n_false_positive: 11779
# debug - n_true_negative: 341247
# debug - n_false_negative: 897
#
# debug - n_true_positive: 21
# debug - n_false_positive: 11879
# debug - n_true_negative: 344144
# debug - n_false_negative: 900
#
# debug - n_true_positive: 21
# debug - n_false_positive: 11979
# debug - n_true_negative: 347042
# debug - n_false_negative: 902
#
# debug - n_true_positive: 21
# debug - n_false_positive: 12079
# debug - n_true_negative: 349935
# debug - n_false_negative: 906
#
# debug - n_true_positive: 21
# debug - n_false_positive: 12179
# debug - n_true_negative: 352816
# debug - n_false_negative: 924
#
# debug - n_true_positive: 21
# debug - n_false_positive: 12279
# debug - n_true_negative: 355712
# debug - n_false_negative: 927
#
# debug - n_true_positive: 21
# debug - n_false_positive: 12379
# debug - n_true_negative: 358612
# debug - n_false_negative: 928
#
# debug - n_true_positive: 21
# debug - n_false_positive: 12479
# debug - n_true_negative: 361512
# debug - n_false_negative: 931
#
# debug - n_true_positive: 21
# debug - n_false_positive: 12579
# debug - n_true_negative: 364395
# debug - n_false_negative: 946
#
# debug - n_true_positive: 21
# debug - n_false_positive: 12679
# debug - n_true_negative: 367293
# debug - n_false_negative: 949
#
# debug - n_true_positive: 21
# debug - n_false_positive: 12779
# debug - n_true_negative: 370177
# debug - n_false_negative: 963
#
# debug - n_true_positive: 21
# debug - n_false_positive: 12879
# debug - n_true_negative: 373063
# debug - n_false_negative: 977
#
# debug - n_true_positive: 21
# debug - n_false_positive: 12979
# debug - n_true_negative: 375958
# debug - n_false_negative: 982
#
# debug - n_true_positive: 21
# debug - n_false_positive: 13079
# debug - n_true_negative: 378854
# debug - n_false_negative: 986
#
# debug - n_true_positive: 21
# debug - n_false_positive: 13179
# debug - n_true_negative: 381749
# debug - n_false_negative: 989
#
# debug - n_true_positive: 21
# debug - n_false_positive: 13279
# debug - n_true_negative: 384645
# debug - n_false_negative: 992
#
# debug - n_true_positive: 21
# debug - n_false_positive: 13379
# debug - n_true_negative: 387535
# debug - n_false_negative: 1002
#
# debug - n_true_positive: 21
# debug - n_false_positive: 13479
# debug - n_true_negative: 390427
# debug - n_false_negative: 1008
#
# debug - n_true_positive: 21
# debug - n_false_positive: 13579
# debug - n_true_negative: 393324
# debug - n_false_negative: 1011
#
# debug - n_true_positive: 21
# debug - n_false_positive: 13679
# debug - n_true_negative: 396220
# debug - n_false_negative: 1013
#
# debug - n_true_positive: 21
# debug - n_false_positive: 13779
# debug - n_true_negative: 399117
# debug - n_false_negative: 1015
#
# debug - n_true_positive: 22
# debug - n_false_positive: 13878
# debug - n_true_negative: 401995
# debug - n_false_negative: 1034
#
# debug - n_true_positive: 23
# debug - n_false_positive: 13977
# debug - n_true_negative: 404889
# debug - n_false_negative: 1037
#
# debug - n_true_positive: 25
# debug - n_false_positive: 14075
# debug - n_true_negative: 407774
# debug - n_false_negative: 1051
#
# debug - n_true_positive: 25
# debug - n_false_positive: 14175
# debug - n_true_negative: 410671
# debug - n_false_negative: 1053
#
# debug - n_true_positive: 25
# debug - n_false_positive: 14275
# debug - n_true_negative: 413563
# debug - n_false_negative: 1061
#
# debug - n_true_positive: 26
# debug - n_false_positive: 14374
# debug - n_true_negative: 416455
# debug - n_false_negative: 1070
#
# debug - n_true_positive: 26
# debug - n_false_positive: 14474
# debug - n_true_negative: 419347
# debug - n_false_negative: 1076
#
# debug - n_true_positive: 26
# debug - n_false_positive: 14574
# debug - n_true_negative: 422236
# debug - n_false_negative: 1089
#
# debug - n_true_positive: 26
# debug - n_false_positive: 14674
# debug - n_true_negative: 425134
# debug - n_false_negative: 1092
#
# debug - n_true_positive: 26
# debug - n_false_positive: 14774
# debug - n_true_negative: 428026
# debug - n_false_negative: 1099
#
# debug - n_true_positive: 26
# debug - n_false_positive: 14874
# debug - n_true_negative: 430913
# debug - n_false_negative: 1113
#
# debug - n_true_positive: 27
# debug - n_false_positive: 14973
# debug - n_true_negative: 433786
# debug - n_false_negative: 1139
#
# debug - n_true_positive: 28
# debug - n_false_positive: 15072
# debug - n_true_negative: 436654
# debug - n_false_negative: 1170
#
# debug - n_true_positive: 28
# debug - n_false_positive: 15172
# debug - n_true_negative: 439550
# debug - n_false_negative: 1175
#
# debug - n_true_positive: 28
# debug - n_false_positive: 15272
# debug - n_true_negative: 442446
# debug - n_false_negative: 1176
#
# debug - n_true_positive: 28
# debug - n_false_positive: 15372
# debug - n_true_negative: 445342
# debug - n_false_negative: 1178
#
# debug - n_true_positive: 28
# debug - n_false_positive: 15472
# debug - n_true_negative: 448239
# debug - n_false_negative: 1182
#
# debug - n_true_positive: 28
# debug - n_false_positive: 15572
# debug - n_true_negative: 451134
# debug - n_false_negative: 1186
#
# debug - n_true_positive: 28
# debug - n_false_positive: 15672
# debug - n_true_negative: 454030
# debug - n_false_negative: 1189
#
# debug - n_true_positive: 28
# debug - n_false_positive: 15772
# debug - n_true_negative: 456921
# debug - n_false_negative: 1197
#
# debug - n_true_positive: 28
# debug - n_false_positive: 15872
# debug - n_true_negative: 459819
# debug - n_false_negative: 1198
#
# debug - n_true_positive: 28
# debug - n_false_positive: 15972
# debug - n_true_negative: 462710
# debug - n_false_negative: 1206
#
# debug - n_true_positive: 28
# debug - n_false_positive: 16072
# debug - n_true_negative: 465602
# debug - n_false_negative: 1215
#
# debug - n_true_positive: 28
# debug - n_false_positive: 16172
# debug - n_true_negative: 468490
# debug - n_false_negative: 1226
#
# debug - n_true_positive: 28
# debug - n_false_positive: 16272
# debug - n_true_negative: 471383
# debug - n_false_negative: 1233
#
# debug - n_true_positive: 28
# debug - n_false_positive: 16372
# debug - n_true_negative: 474275
# debug - n_false_negative: 1243
#
# debug - n_true_positive: 29
# debug - n_false_positive: 16471
# debug - n_true_negative: 477169
# debug - n_false_negative: 1248
#
# debug - n_true_positive: 29
# debug - n_false_positive: 16571
# debug - n_true_negative: 480065
# debug - n_false_negative: 1251
#
# debug - n_true_positive: 29
# debug - n_false_positive: 16671
# debug - n_true_negative: 482963
# debug - n_false_negative: 1254
#
# debug - n_true_positive: 29
# debug - n_false_positive: 16771
# debug - n_true_negative: 485852
# debug - n_false_negative: 1265
#
# debug - n_true_positive: 30
# debug - n_false_positive: 16870
# debug - n_true_negative: 488741
# debug - n_false_negative: 1275
#
# debug - n_true_positive: 30
# debug - n_false_positive: 16970
# debug - n_true_negative: 491626
# debug - n_false_negative: 1289
#
# debug - n_true_positive: 30
# debug - n_false_positive: 17070
# debug - n_true_negative: 494518
# debug - n_false_negative: 1296
#
# debug - n_true_positive: 30
# debug - n_false_positive: 17170
# debug - n_true_negative: 497414
# debug - n_false_negative: 1298
#
# debug - n_true_positive: 31
# debug - n_false_positive: 17269
# debug - n_true_negative: 500299
# debug - n_false_negative: 1312
#
# debug - n_true_positive: 31
# debug - n_false_positive: 17369
# debug - n_true_negative: 503187
# debug - n_false_negative: 1325
#
# debug - n_true_positive: 31
# debug - n_false_positive: 17469
# debug - n_true_negative: 506077
# debug - n_false_negative: 1334
#
# debug - n_true_positive: 31
# debug - n_false_positive: 17569
# debug - n_true_negative: 508959
# debug - n_false_negative: 1352
#
# debug - n_true_positive: 32
# debug - n_false_positive: 17668
# debug - n_true_negative: 511854
# debug - n_false_negative: 1355
#
# debug - n_true_positive: 32
# debug - n_false_positive: 17768
# debug - n_true_negative: 514750
# debug - n_false_negative: 1360
#
# debug - n_true_positive: 32
# debug - n_false_positive: 17868
# debug - n_true_negative: 517645
# debug - n_false_negative: 1363
#
# debug - n_true_positive: 32
# debug - n_false_positive: 17968
# debug - n_true_negative: 520541
# debug - n_false_negative: 1366
#
# debug - n_true_positive: 32
# debug - n_false_positive: 18068
# debug - n_true_negative: 523437
# debug - n_false_negative: 1370
#
# debug - n_true_positive: 32
# debug - n_false_positive: 18168
# debug - n_true_negative: 526333
# debug - n_false_negative: 1373
#
# debug - n_true_positive: 32
# debug - n_false_positive: 18268
# debug - n_true_negative: 529232
# debug - n_false_negative: 1375
#
# debug - n_true_positive: 32
# debug - n_false_positive: 18368
# debug - n_true_negative: 532128
# debug - n_false_negative: 1379
#
# debug - n_true_positive: 35
# debug - n_false_positive: 18465
# debug - n_true_negative: 535009
# debug - n_false_negative: 1397
#
# debug - n_true_positive: 35
# debug - n_false_positive: 18565
# debug - n_true_negative: 537907
# debug - n_false_negative: 1399
#
# debug - n_true_positive: 35
# debug - n_false_positive: 18665
# debug - n_true_negative: 540797
# debug - n_false_negative: 1409
#
# debug - n_true_positive: 35
# debug - n_false_positive: 18765
# debug - n_true_negative: 543693
# debug - n_false_negative: 1413
#
# debug - n_true_positive: 35
# debug - n_false_positive: 18865
# debug - n_true_negative: 546591
# debug - n_false_negative: 1414
#
# debug - n_true_positive: 35
# debug - n_false_positive: 18965
# debug - n_true_negative: 549487
# debug - n_false_negative: 1416
#
# debug - n_true_positive: 37
# debug - n_false_positive: 19063
# debug - n_true_negative: 552378
# debug - n_false_negative: 1427
#
# debug - n_true_positive: 37
# debug - n_false_positive: 19163
# debug - n_true_negative: 555276
# debug - n_false_negative: 1430
#
# debug - n_true_positive: 37
# debug - n_false_positive: 19263
# debug - n_true_negative: 558172
# debug - n_false_negative: 1433
#
# debug - n_true_positive: 38
# debug - n_false_positive: 19362
# debug - n_true_negative: 561062
# debug - n_false_negative: 1443
#
# debug - n_true_positive: 38
# debug - n_false_positive: 19462
# debug - n_true_negative: 563956
# debug - n_false_negative: 1449
#
# debug - n_true_positive: 39
# debug - n_false_positive: 19561
# debug - n_true_negative: 566834
# debug - n_false_negative: 1470
#
# debug - n_true_positive: 39
# debug - n_false_positive: 19661
# debug - n_true_negative: 569729
# debug - n_false_negative: 1476
#
# debug - n_true_positive: 39
# debug - n_false_positive: 19761
# debug - n_true_negative: 572625
# debug - n_false_negative: 1480
#
# debug - n_true_positive: 40
# debug - n_false_positive: 19860
# debug - n_true_negative: 575516
# debug - n_false_negative: 1489
#
# debug - n_true_positive: 41
# debug - n_false_positive: 19959
# debug - n_true_negative: 578410
# debug - n_false_negative: 1496
#
# debug - n_true_positive: 42
# debug - n_false_positive: 20058
# debug - n_true_negative: 581308
# debug - n_false_negative: 1497
#
# debug - n_true_positive: 43
# debug - n_false_positive: 20157
# debug - n_true_negative: 584207
# debug - n_false_negative: 1499
#
# debug - n_true_positive: 43
# debug - n_false_positive: 20257
# debug - n_true_negative: 587100
# debug - n_false_negative: 1506
#
# debug - n_true_positive: 43
# debug - n_false_positive: 20357
# debug - n_true_negative: 589996
# debug - n_false_negative: 1509
#
# debug - n_true_positive: 43
# debug - n_false_positive: 20457
# debug - n_true_negative: 592886
# debug - n_false_negative: 1518
#
# debug - n_true_positive: 43
# debug - n_false_positive: 20557
# debug - n_true_negative: 595783
# debug - n_false_negative: 1520
#
# debug - n_true_positive: 43
# debug - n_false_positive: 20657
# debug - n_true_negative: 598678
# debug - n_false_negative: 1523
#
# debug - n_true_positive: 43
# debug - n_false_positive: 20757
# debug - n_true_negative: 601568
# debug - n_false_negative: 1534
#
# debug - n_true_positive: 43
# debug - n_false_positive: 20857
# debug - n_true_negative: 604462
# debug - n_false_negative: 1538
#
# debug - n_true_positive: 43
# debug - n_false_positive: 20957
# debug - n_true_negative: 607350
# debug - n_false_negative: 1551
#
# debug - n_true_positive: 43
# debug - n_false_positive: 21057
# debug - n_true_negative: 610238
# debug - n_false_negative: 1562
#
# debug - n_true_positive: 43
# debug - n_false_positive: 21157
# debug - n_true_negative: 613137
# debug - n_false_negative: 1564
#
# debug - n_true_positive: 43
# debug - n_false_positive: 21257
# debug - n_true_negative: 616025
# debug - n_false_negative: 1575
#
# debug - n_true_positive: 43
# debug - n_false_positive: 21357
# debug - n_true_negative: 618917
# debug - n_false_negative: 1582
#
# debug - n_true_positive: 43
# debug - n_false_positive: 21457
# debug - n_true_negative: 621801
# debug - n_false_negative: 1597
#
# debug - n_true_positive: 43
# debug - n_false_positive: 21557
# debug - n_true_negative: 624700
# debug - n_false_negative: 1600
#
# debug - n_true_positive: 43
# debug - n_false_positive: 21657
# debug - n_true_negative: 627596
# debug - n_false_negative: 1603
#
# debug - n_true_positive: 43
# debug - n_false_positive: 21757
# debug - n_true_negative: 630490
# debug - n_false_negative: 1607
#
# debug - n_true_positive: 44
# debug - n_false_positive: 21856
# debug - n_true_negative: 633388
# debug - n_false_negative: 1609
#
# debug - n_true_positive: 46
# debug - n_false_positive: 21954
# debug - n_true_negative: 636281
# debug - n_false_negative: 1615
#
# debug - n_true_positive: 46
# debug - n_false_positive: 22054
# debug - n_true_negative: 639177
# debug - n_false_negative: 1619
#
# debug - n_true_positive: 48
# debug - n_false_positive: 22152
# debug - n_true_negative: 642052
# debug - n_false_negative: 1643
#
# debug - n_true_positive: 48
# debug - n_false_positive: 22252
# debug - n_true_negative: 644932
# debug - n_false_negative: 1663
#
# debug - n_true_positive: 48
# debug - n_false_positive: 22352
# debug - n_true_negative: 647813
# debug - n_false_negative: 1681
#
# debug - n_true_positive: 52
# debug - n_false_positive: 22448
# debug - n_true_negative: 650677
# debug - n_false_negative: 1718
#
# debug - n_true_positive: 52
# debug - n_false_positive: 22548
# debug - n_true_negative: 653562
# debug - n_false_negative: 1733
#
# debug - n_true_positive: 53
# debug - n_false_positive: 22647
# debug - n_true_negative: 656456
# debug - n_false_negative: 1740
#
# debug - n_true_positive: 53
# debug - n_false_positive: 22747
# debug - n_true_negative: 659332
# debug - n_false_negative: 1761
#
# debug - n_true_positive: 53
# debug - n_false_positive: 22847
# debug - n_true_negative: 662224
# debug - n_false_negative: 1768
#
# debug - n_true_positive: 54
# debug - n_false_positive: 22946
# debug - n_true_negative: 665108
# debug - n_false_negative: 1784
#
# debug - n_true_positive: 54
# debug - n_false_positive: 23046
# debug - n_true_negative: 668001
# debug - n_false_negative: 1792
#
# debug - n_true_positive: 54
# debug - n_false_positive: 23146
# debug - n_true_negative: 670896
# debug - n_false_negative: 1795
#
# debug - n_true_positive: 54
# debug - n_false_positive: 23246
# debug - n_true_negative: 673769
# debug - n_false_negative: 1822
#
# debug - n_true_positive: 55
# debug - n_false_positive: 23345
# debug - n_true_negative: 676647
# debug - n_false_negative: 1842
#
# debug - n_true_positive: 58
# debug - n_false_positive: 23442
# debug - n_true_negative: 679509
# debug - n_false_negative: 1879
#
# debug - n_true_positive: 59
# debug - n_false_positive: 23541
# debug - n_true_negative: 682383
# debug - n_false_negative: 1904
#
# debug - n_true_positive: 59
# debug - n_false_positive: 23641
# debug - n_true_negative: 685276
# debug - n_false_negative: 1910
#
# debug - n_true_positive: 60
# debug - n_false_positive: 23740
# debug - n_true_negative: 688165
# debug - n_false_negative: 1921
#
# debug - n_true_positive: 60
# debug - n_false_positive: 23840
# debug - n_true_negative: 691063
# debug - n_false_negative: 1924
#
# debug - n_true_positive: 63
# debug - n_false_positive: 23937
# debug - n_true_negative: 693932
# debug - n_false_negative: 1958
#
# debug - n_true_positive: 64
# debug - n_false_positive: 24036
# debug - n_true_negative: 696807
# debug - n_false_negative: 1982
#
# debug - n_true_positive: 64
# debug - n_false_positive: 24136
# debug - n_true_negative: 699700
# debug - n_false_negative: 1989
#
# debug - n_true_positive: 65
# debug - n_false_positive: 24235
# debug - n_true_negative: 702589
# debug - n_false_negative: 1998
#
# debug - n_true_positive: 66
# debug - n_false_positive: 24334
# debug - n_true_negative: 705461
# debug - n_false_negative: 2026
#
# debug - n_true_positive: 67
# debug - n_false_positive: 24433
# debug - n_true_negative: 708340
# debug - n_false_negative: 2047
#
# debug - n_true_positive: 67
# debug - n_false_positive: 24533
# debug - n_true_negative: 711237
# debug - n_false_negative: 2050
#
# debug - n_true_positive: 68
# debug - n_false_positive: 24632
# debug - n_true_negative: 714111
# debug - n_false_negative: 2076
#
# debug - n_true_positive: 68
# debug - n_false_positive: 24732
# debug - n_true_negative: 716994
# debug - n_false_negative: 2092
#
# debug - n_true_positive: 69
# debug - n_false_positive: 24831
# debug - n_true_negative: 719883
# debug - n_false_negative: 2102
#
# debug - n_true_positive: 71
# debug - n_false_positive: 24929
# debug - n_true_negative: 722763
# debug - n_false_negative: 2122
#
# debug - n_true_positive: 71
# debug - n_false_positive: 25029
# debug - n_true_negative: 725648
# debug - n_false_negative: 2135
#
# debug - n_true_positive: 71
# debug - n_false_positive: 25129
# debug - n_true_negative: 728523
# debug - n_false_negative: 2159
#
# debug - n_true_positive: 71
# debug - n_false_positive: 25229
# debug - n_true_negative: 731395
# debug - n_false_negative: 2184
#
# debug - n_true_positive: 71
# debug - n_false_positive: 25329
# debug - n_true_negative: 734271
# debug - n_false_negative: 2206
#
# debug - n_true_positive: 71
# debug - n_false_positive: 25429
# debug - n_true_negative: 737150
# debug - n_false_negative: 2228
#
# debug - n_true_positive: 71
# debug - n_false_positive: 25529
# debug - n_true_negative: 740035
# debug - n_false_negative: 2240
#
# debug - n_true_positive: 72
# debug - n_false_positive: 25628
# debug - n_true_negative: 742912
# debug - n_false_negative: 2262
#
# debug - n_true_positive: 72
# debug - n_false_positive: 25728
# debug - n_true_negative: 745804
# debug - n_false_negative: 2271
#
# debug - n_true_positive: 72
# debug - n_false_positive: 25828
# debug - n_true_negative: 748688
# debug - n_false_negative: 2285
#
# debug - n_true_positive: 73
# debug - n_false_positive: 25927
# debug - n_true_negative: 751559
# debug - n_false_negative: 2315
#
# debug - n_true_positive: 73
# debug - n_false_positive: 26027
# debug - n_true_negative: 754438
# debug - n_false_negative: 2335
#
# debug - n_true_positive: 73
# debug - n_false_positive: 26127
# debug - n_true_negative: 757325
# debug - n_false_negative: 2347
#
# debug - n_true_positive: 73
# debug - n_false_positive: 26227
# debug - n_true_negative: 760205
# debug - n_false_negative: 2366
#
# debug - n_true_positive: 76
# debug - n_false_positive: 26324
# debug - n_true_negative: 763066
# debug - n_false_negative: 2402
#
# debug - n_true_positive: 76
# debug - n_false_positive: 26424
# debug - n_true_negative: 765941
# debug - n_false_negative: 2424
#
# debug - n_true_positive: 76
# debug - n_false_positive: 26524
# debug - n_true_negative: 768839
# debug - n_false_negative: 2427
#
# debug - n_true_positive: 76
# debug - n_false_positive: 26624
# debug - n_true_negative: 771731
# debug - n_false_negative: 2436
#
# debug - n_true_positive: 76
# debug - n_false_positive: 26724
# debug - n_true_negative: 774623
# debug - n_false_negative: 2443
#
# debug - n_true_positive: 78
# debug - n_false_positive: 26822
# debug - n_true_negative: 777516
# debug - n_false_negative: 2451
#
# debug - n_true_positive: 78
# debug - n_false_positive: 26922
# debug - n_true_negative: 780400
# debug - n_false_negative: 2467
#
# debug - n_true_positive: 79
# debug - n_false_positive: 27021
# debug - n_true_negative: 783291
# debug - n_false_negative: 2478
#
# debug - n_true_positive: 80
# debug - n_false_positive: 27120
# debug - n_true_negative: 786188
# debug - n_false_negative: 2479
#
# debug - n_true_positive: 81
# debug - n_false_positive: 27219
# debug - n_true_negative: 789063
# debug - n_false_negative: 2504
#
# debug - n_true_positive: 81
# debug - n_false_positive: 27319
# debug - n_true_negative: 791955
# debug - n_false_negative: 2510
#
# debug - n_true_positive: 82
# debug - n_false_positive: 27418
# debug - n_true_negative: 794852
# debug - n_false_negative: 2513
#
# debug - n_true_positive: 82
# debug - n_false_positive: 27518
# debug - n_true_negative: 797739
# debug - n_false_negative: 2526
#
# debug - n_true_positive: 83
# debug - n_false_positive: 27617
# debug - n_true_negative: 800622
# debug - n_false_negative: 2541
#
# debug - n_true_positive: 83
# debug - n_false_positive: 27717
# debug - n_true_negative: 803516
# debug - n_false_negative: 2548
#
# debug - n_true_positive: 83
# debug - n_false_positive: 27817
# debug - n_true_negative: 806409
# debug - n_false_negative: 2554
#
# debug - n_true_positive: 83
# debug - n_false_positive: 27917
# debug - n_true_negative: 809299
# debug - n_false_negative: 2565
#
# debug - n_true_positive: 83
# debug - n_false_positive: 28017
# debug - n_true_negative: 812190
# debug - n_false_negative: 2573
#
# debug - n_true_positive: 83
# debug - n_false_positive: 28117
# debug - n_true_negative: 815085
# debug - n_false_negative: 2575
#
# debug - n_true_positive: 83
# debug - n_false_positive: 28217
# debug - n_true_negative: 817980
# debug - n_false_negative: 2580
#
# debug - n_true_positive: 83
# debug - n_false_positive: 28317
# debug - n_true_negative: 820871
# debug - n_false_negative: 2590
#
# debug - n_true_positive: 83
# debug - n_false_positive: 28417
# debug - n_true_negative: 823764
# debug - n_false_negative: 2597
#
# debug - n_true_positive: 83
# debug - n_false_positive: 28517
# debug - n_true_negative: 826660
# debug - n_false_negative: 2600
#
# debug - n_true_positive: 85
# debug - n_false_positive: 28615
# debug - n_true_negative: 829538
# debug - n_false_negative: 2622
#
# debug - n_true_positive: 85
# debug - n_false_positive: 28715
# debug - n_true_negative: 832431
# debug - n_false_negative: 2628
#
# debug - n_true_positive: 85
# debug - n_false_positive: 28815
# debug - n_true_negative: 835323
# debug - n_false_negative: 2638
#
# debug - n_true_positive: 85
# debug - n_false_positive: 28915
# debug - n_true_negative: 838213
# debug - n_false_negative: 2647
#
# debug - n_true_positive: 85
# debug - n_false_positive: 29015
# debug - n_true_negative: 841105
# debug - n_false_negative: 2655
#
# debug - n_true_positive: 85
# debug - n_false_positive: 29115
# debug - n_true_negative: 843994
# debug - n_false_negative: 2665
#
# debug - n_true_positive: 85
# debug - n_false_positive: 29215
# debug - n_true_negative: 846888
# debug - n_false_negative: 2669
#
# debug - n_true_positive: 85
# debug - n_false_positive: 29315
# debug - n_true_negative: 849775
# debug - n_false_negative: 2680
#
# debug - n_true_positive: 86
# debug - n_false_positive: 29414
# debug - n_true_negative: 852658
# debug - n_false_negative: 2694
#
# debug - n_true_positive: 86
# debug - n_false_positive: 29514
# debug - n_true_negative: 855527
# debug - n_false_negative: 2729
#
# debug - n_true_positive: 86
# debug - n_false_positive: 29614
# debug - n_true_negative: 858420
# debug - n_false_negative: 2736
#
# debug - n_true_positive: 86
# debug - n_false_positive: 29714
# debug - n_true_negative: 861314
# debug - n_false_negative: 2739
#
# debug - n_true_positive: 87
# debug - n_false_positive: 29813
# debug - n_true_negative: 864200
# debug - n_false_negative: 2750
#
# debug - n_true_positive: 87
# debug - n_false_positive: 29913
# debug - n_true_negative: 867099
# debug - n_false_negative: 2751
#
# debug - n_true_positive: 87
# debug - n_false_positive: 30013
# debug - n_true_negative: 869992
# debug - n_false_negative: 2757
#
# debug - n_true_positive: 89
# debug - n_false_positive: 30111
# debug - n_true_negative: 872875
# debug - n_false_negative: 2773
#
# debug - n_true_positive: 89
# debug - n_false_positive: 30211
# debug - n_true_negative: 875769
# debug - n_false_negative: 2777
#
# debug - n_true_positive: 89
# debug - n_false_positive: 30311
# debug - n_true_negative: 878648
# debug - n_false_negative: 2796
#
# debug - n_true_positive: 89
# debug - n_false_positive: 30411
# debug - n_true_negative: 881543
# debug - n_false_negative: 2801
#
# debug - n_true_positive: 90
# debug - n_false_positive: 30510
# debug - n_true_negative: 884430
# debug - n_false_negative: 2812
#
# debug - n_true_positive: 90
# debug - n_false_positive: 30610
# debug - n_true_negative: 887313
# debug - n_false_negative: 2829
#
# debug - n_true_positive: 90
# debug - n_false_positive: 30710
# debug - n_true_negative: 890206
# debug - n_false_negative: 2834
#
# debug - n_true_positive: 90
# debug - n_false_positive: 30810
# debug - n_true_negative: 893083
# debug - n_false_negative: 2856
#
# debug - n_true_positive: 90
# debug - n_false_positive: 30910
# debug - n_true_negative: 895974
# debug - n_false_negative: 2864
#
# debug - n_true_positive: 91
# debug - n_false_positive: 31009
# debug - n_true_negative: 898864
# debug - n_false_negative: 2874
#
# debug - n_true_positive: 91
# debug - n_false_positive: 31109
# debug - n_true_negative: 901758
# debug - n_false_negative: 2879
#
# debug - n_true_positive: 91
# debug - n_false_positive: 31209
# debug - n_true_negative: 904653
# debug - n_false_negative: 2884
#
# debug - n_true_positive: 91
# debug - n_false_positive: 31309
# debug - n_true_negative: 907530
# debug - n_false_negative: 2907
#
# debug - n_true_positive: 91
# debug - n_false_positive: 31409
# debug - n_true_negative: 910424
# debug - n_false_negative: 2911
#
# debug - n_true_positive: 91
# debug - n_false_positive: 31509
# debug - n_true_negative: 913321
# debug - n_false_negative: 2912
#
# debug - n_true_positive: 91
# debug - n_false_positive: 31609
# debug - n_true_negative: 916212
# debug - n_false_negative: 2921
#
# debug - n_true_positive: 92
# debug - n_false_positive: 31708
# debug - n_true_negative: 919099
# debug - n_false_negative: 2931
#
# debug - n_true_positive: 92
# debug - n_false_positive: 31808
# debug - n_true_negative: 921972
# debug - n_false_negative: 2957
#
# debug - n_true_positive: 92
# debug - n_false_positive: 31908
# debug - n_true_negative: 924855
# debug - n_false_negative: 2972
#
# debug - n_true_positive: 94
# debug - n_false_positive: 32006
# debug - n_true_negative: 927717
# debug - n_false_negative: 3009
#
# debug - n_true_positive: 94
# debug - n_false_positive: 32106
# debug - n_true_negative: 930606
# debug - n_false_negative: 3022
#
# debug - n_true_positive: 94
# debug - n_false_positive: 32206
# debug - n_true_negative: 933501
# debug - n_false_negative: 3026
#
# debug - n_true_positive: 95
# debug - n_false_positive: 32305
# debug - n_true_negative: 936397
# debug - n_false_negative: 3029
#
# debug - n_true_positive: 95
# debug - n_false_positive: 32405
# debug - n_true_negative: 939292
# debug - n_false_negative: 3034
#
# debug - n_true_positive: 95
# debug - n_false_positive: 32505
# debug - n_true_negative: 942183
# debug - n_false_negative: 3042
#
# debug - n_true_positive: 95
# debug - n_false_positive: 32605
# debug - n_true_negative: 945069
# debug - n_false_negative: 3057
#
# debug - n_true_positive: 95
# debug - n_false_positive: 32705
# debug - n_true_negative: 947961
# debug - n_false_negative: 3064
#
# debug - n_true_positive: 96
# debug - n_false_positive: 32804
# debug - n_true_negative: 950856
# debug - n_false_negative: 3071
#
# debug - n_true_positive: 96
# debug - n_false_positive: 32904
# debug - n_true_negative: 953742
# debug - n_false_negative: 3082
#
# debug - n_true_positive: 96
# debug - n_false_positive: 33004
# debug - n_true_negative: 956623
# debug - n_false_negative: 3099
#
# debug - n_true_positive: 98
# debug - n_false_positive: 33102
# debug - n_true_negative: 959520
# debug - n_false_negative: 3101
#
# debug - n_true_positive: 98
# debug - n_false_positive: 33202
# debug - n_true_negative: 962417
# debug - n_false_negative: 3104
#
# debug - n_true_positive: 99
# debug - n_false_positive: 33301
# debug - n_true_negative: 965314
# debug - n_false_negative: 3105
#
# debug - n_true_positive: 99
# debug - n_false_positive: 33401
# debug - n_true_negative: 968209
# debug - n_false_negative: 3110
#
# debug - n_true_positive: 101
# debug - n_false_positive: 33499
# debug - n_true_negative: 971095
# debug - n_false_negative: 3122
#
# debug - n_true_positive: 102
# debug - n_false_positive: 33598
# debug - n_true_negative: 973987
# debug - n_false_negative: 3128
#
# debug - n_true_positive: 102
# debug - n_false_positive: 33698
# debug - n_true_negative: 976883
# debug - n_false_negative: 3130
#
# debug - n_true_positive: 102
# debug - n_false_positive: 33798
# debug - n_true_negative: 979767
# debug - n_false_negative: 3145
#
# debug - n_true_positive: 102
# debug - n_false_positive: 33898
# debug - n_true_negative: 982667
# debug - n_false_negative: 3147
#
# debug - n_true_positive: 102
# debug - n_false_positive: 33998
# debug - n_true_negative: 985562
# debug - n_false_negative: 3151
#
# debug - n_true_positive: 103
# debug - n_false_positive: 34097
# debug - n_true_negative: 988461
# debug - n_false_negative: 3152
#
# debug - n_true_positive: 103
# debug - n_false_positive: 34197
# debug - n_true_negative: 991359
# debug - n_false_negative: 3155
#
# debug - n_true_positive: 103
# debug - n_false_positive: 34297
# debug - n_true_negative: 994256
# debug - n_false_negative: 3159
#
# debug - n_true_positive: 103
# debug - n_false_positive: 34397
# debug - n_true_negative: 997151
# debug - n_false_negative: 3163
#
# debug - n_true_positive: 103
# debug - n_false_positive: 34497
# debug - n_true_negative: 1000036
# debug - n_false_negative: 3178
#
# debug - n_true_positive: 103
# debug - n_false_positive: 34597
# debug - n_true_negative: 1002914
# debug - n_false_negative: 3197
#
# debug - n_true_positive: 103
# debug - n_false_positive: 34697
# debug - n_true_negative: 1005810
# debug - n_false_negative: 3200
#
# debug - n_true_positive: 103
# debug - n_false_positive: 34797
# debug - n_true_negative: 1008703
# debug - n_false_negative: 3207
#
# debug - n_true_positive: 103
# debug - n_false_positive: 34897
# debug - n_true_negative: 1011598
# debug - n_false_negative: 3211
#
# debug - n_true_positive: 103
# debug - n_false_positive: 34997
# debug - n_true_negative: 1014492
# debug - n_false_negative: 3215
#
# debug - n_true_positive: 103
# debug - n_false_positive: 35097
# debug - n_true_negative: 1017378
# debug - n_false_negative: 3229
#
# debug - n_true_positive: 103
# debug - n_false_positive: 35197
# debug - n_true_negative: 1020265
# debug - n_false_negative: 3241
#
# debug - n_true_positive: 103
# debug - n_false_positive: 35297
# debug - n_true_negative: 1023149
# debug - n_false_negative: 3255
#
# debug - n_true_positive: 103
# debug - n_false_positive: 35397
# debug - n_true_negative: 1026048
# debug - n_false_negative: 3257
#
# debug - n_true_positive: 103
# debug - n_false_positive: 35497
# debug - n_true_negative: 1028943
# debug - n_false_negative: 3261
#
# debug - n_true_positive: 103
# debug - n_false_positive: 35597
# debug - n_true_negative: 1031842
# debug - n_false_negative: 3262
#
# debug - n_true_positive: 103
# debug - n_false_positive: 35697
# debug - n_true_negative: 1034737
# debug - n_false_negative: 3264
#
# debug - n_true_positive: 104
# debug - n_false_positive: 35796
# debug - n_true_negative: 1037630
# debug - n_false_negative: 3268
#
# debug - n_true_positive: 105
# debug - n_false_positive: 35895
# debug - n_true_negative: 1040517
# debug - n_false_negative: 3280
#
# debug - n_true_positive: 105
# debug - n_false_positive: 35995
# debug - n_true_negative: 1043413
# debug - n_false_negative: 3283
#
# debug - n_true_positive: 106
# debug - n_false_positive: 36094
# debug - n_true_negative: 1046311
# debug - n_false_negative: 3285
#
# debug - n_true_positive: 106
# debug - n_false_positive: 36194
# debug - n_true_negative: 1049200
# debug - n_false_negative: 3294
#
# debug - n_true_positive: 106
# debug - n_false_positive: 36294
# debug - n_true_negative: 1052098
# debug - n_false_negative: 3295
#
# debug - n_true_positive: 107
# debug - n_false_positive: 36393
# debug - n_true_negative: 1054987
# debug - n_false_negative: 3304
#
# debug - n_true_positive: 107
# debug - n_false_positive: 36493
# debug - n_true_negative: 1057881
# debug - n_false_negative: 3312
#
# debug - n_true_positive: 107
# debug - n_false_positive: 36593
# debug - n_true_negative: 1060774
# debug - n_false_negative: 3317
#
# debug - n_true_positive: 107
# debug - n_false_positive: 36693
# debug - n_true_negative: 1063661
# debug - n_false_negative: 3330
#
# debug - n_true_positive: 107
# debug - n_false_positive: 36793
# debug - n_true_negative: 1066549
# debug - n_false_negative: 3339
#
# debug - n_true_positive: 107
# debug - n_false_positive: 36893
# debug - n_true_negative: 1069449
# debug - n_false_negative: 3340
#
# debug - n_true_positive: 107
# debug - n_false_positive: 36993
# debug - n_true_negative: 1072343
# debug - n_false_negative: 3346
#
# debug - n_true_positive: 107
# debug - n_false_positive: 37093
# debug - n_true_negative: 1075242
# debug - n_false_negative: 3347
#
# debug - n_true_positive: 107
# debug - n_false_positive: 37193
# debug - n_true_negative: 1078136
# debug - n_false_negative: 3352
#
# debug - n_true_positive: 107
# debug - n_false_positive: 37293
# debug - n_true_negative: 1081032
# debug - n_false_negative: 3357
#
# debug - n_true_positive: 108
# debug - n_false_positive: 37392
# debug - n_true_negative: 1083923
# debug - n_false_negative: 3366
#
# debug - n_true_positive: 109
# debug - n_false_positive: 37491
# debug - n_true_negative: 1086821
# debug - n_false_negative: 3368
#
# debug - n_true_positive: 109
# debug - n_false_positive: 37591
# debug - n_true_negative: 1089714
# debug - n_false_negative: 3374
#
# debug - n_true_positive: 110
# debug - n_false_positive: 37690
# debug - n_true_negative: 1092608
# debug - n_false_negative: 3380
#
# debug - n_true_positive: 110
# debug - n_false_positive: 37790
# debug - n_true_negative: 1095500
# debug - n_false_negative: 3387
#
# debug - n_true_positive: 111
# debug - n_false_positive: 37889
# debug - n_true_negative: 1098384
# debug - n_false_negative: 3401
#
# debug - n_true_positive: 111
# debug - n_false_positive: 37989
# debug - n_true_negative: 1101284
# debug - n_false_negative: 3402
#
# debug - n_true_positive: 111
# debug - n_false_positive: 38089
# debug - n_true_negative: 1104174
# debug - n_false_negative: 3413
#
# debug - n_true_positive: 112
# debug - n_false_positive: 38188
# debug - n_true_negative: 1107068
# debug - n_false_negative: 3419
#
# debug - n_true_positive: 112
# debug - n_false_positive: 38288
# debug - n_true_negative: 1109964
# debug - n_false_negative: 3422
#
# debug - n_true_positive: 112
# debug - n_false_positive: 38388
# debug - n_true_negative: 1112861
# debug - n_false_negative: 3425
#
# debug - n_true_positive: 113
# debug - n_false_positive: 38487
# debug - n_true_negative: 1115751
# debug - n_false_negative: 3435
#
# debug - n_true_positive: 113
# debug - n_false_positive: 38587
# debug - n_true_negative: 1118647
# debug - n_false_negative: 3436
#
# debug - n_true_positive: 114
# debug - n_false_positive: 38686
# debug - n_true_negative: 1121531
# debug - n_false_negative: 3451
#
# ...
# debug - n_true_negative: 2353269
# debug - n_false_negative: 6868
#
# debug - n_true_positive: 206
# debug - n_false_positive: 81294
# debug - n_true_negative: 2356165
# debug - n_false_negative: 6872
#
# debug - n_true_positive: 206
# debug - n_false_positive: 81394
# debug - n_true_negative: 2359063
# debug - n_false_negative: 6874
#
# debug - n_true_positive: 206
# debug - n_false_positive: 81494
# debug - n_true_negative: 2361961
# debug - n_false_negative: 6876
#
# debug - n_true_positive: 206
# debug - n_false_positive: 81594
# debug - n_true_negative: 2364853
# debug - n_false_negative: 6883
#
# debug - n_true_positive: 206
# debug - n_false_positive: 81694
# debug - n_true_negative: 2367752
# debug - n_false_negative: 6886
#
# debug - n_true_positive: 207
# debug - n_false_positive: 81793
# debug - n_true_negative: 2370642
# debug - n_false_negative: 6894
#
# debug - n_true_positive: 207
# debug - n_false_positive: 81893
# debug - n_true_negative: 2373529
# debug - n_false_negative: 6907
#
# debug - n_true_positive: 207
# debug - n_false_positive: 81993
# debug - n_true_negative: 2376412
# debug - n_false_negative: 6924
#
# debug - n_true_positive: 207
# debug - n_false_positive: 82093
# debug - n_true_negative: 2379307
# debug - n_false_negative: 6928
#
# debug - n_true_positive: 207
# debug - n_false_positive: 82193
# debug - n_true_negative: 2382199
# debug - n_false_negative: 6936
#
# debug - n_true_positive: 207
# debug - n_false_positive: 82293
# debug - n_true_negative: 2385095
# debug - n_false_negative: 6940
#
# debug - n_true_positive: 209
# debug - n_false_positive: 82391
# debug - n_true_negative: 2387982
# debug - n_false_negative: 6954
#
# debug - n_true_positive: 209
# debug - n_false_positive: 82491
# debug - n_true_negative: 2390875
# debug - n_false_negative: 6960
#
# debug - n_true_positive: 209
# debug - n_false_positive: 82591
# debug - n_true_negative: 2393766
# debug - n_false_negative: 6967
#
# debug - n_true_positive: 210
# debug - n_false_positive: 82690
# debug - n_true_negative: 2396657
# debug - n_false_negative: 6977
#
# debug - n_true_positive: 211
# debug - n_false_positive: 82789
# debug - n_true_negative: 2399541
# debug - n_false_negative: 6993
#
# debug - n_true_positive: 211
# debug - n_false_positive: 82889
# debug - n_true_negative: 2402437
# debug - n_false_negative: 6996
#
# debug - n_true_positive: 211
# debug - n_false_positive: 82989
# debug - n_true_negative: 2405334
# debug - n_false_negative: 7000
#
# debug - n_true_positive: 211
# debug - n_false_positive: 83089
# debug - n_true_negative: 2408231
# debug - n_false_negative: 7003
#
# debug - n_true_positive: 211
# debug - n_false_positive: 83189
# debug - n_true_negative: 2411125
# debug - n_false_negative: 7009
#
# debug - n_true_positive: 211
# debug - n_false_positive: 83289
# debug - n_true_negative: 2414023
# debug - n_false_negative: 7012
#
# debug - n_true_positive: 211
# debug - n_false_positive: 83389
# debug - n_true_negative: 2416919
# debug - n_false_negative: 7016
#
# debug - n_true_positive: 212
# debug - n_false_positive: 83488
# debug - n_true_negative: 2419813
# debug - n_false_negative: 7021
#
# debug - n_true_positive: 213
# debug - n_false_positive: 83587
# debug - n_true_negative: 2422703
# debug - n_false_negative: 7031
#
# debug - n_true_positive: 213
# debug - n_false_positive: 83687
# debug - n_true_negative: 2425601
# debug - n_false_negative: 7032
#
# debug - n_true_positive: 213
# debug - n_false_positive: 83787
# debug - n_true_negative: 2428495
# debug - n_false_negative: 7037
#
# debug - n_true_positive: 213
# debug - n_false_positive: 83887
# debug - n_true_negative: 2431383
# debug - n_false_negative: 7048
#
# debug - n_true_positive: 214
# debug - n_false_positive: 83986
# debug - n_true_negative: 2434276
# debug - n_false_negative: 7054
#
# debug - n_true_positive: 214
# debug - n_false_positive: 84086
# debug - n_true_negative: 2437173
# debug - n_false_negative: 7056
#
# debug - n_true_positive: 214
# debug - n_false_positive: 84186
# debug - n_true_negative: 2440071
# debug - n_false_negative: 7057
#
# debug - n_true_positive: 214
# debug - n_false_positive: 84286
# debug - n_true_negative: 2442961
# debug - n_false_negative: 7066
#
# debug - n_true_positive: 215
# debug - n_false_positive: 84385
# debug - n_true_negative: 2445859
# debug - n_false_negative: 7068
#
# debug - n_true_positive: 216
# debug - n_false_positive: 84484
# debug - n_true_negative: 2448757
# debug - n_false_negative: 7070
#
# debug - n_true_positive: 216
# debug - n_false_positive: 84584
# debug - n_true_negative: 2451646
# debug - n_false_negative: 7080
#
# debug - n_true_positive: 216
# debug - n_false_positive: 84684
# debug - n_true_negative: 2454539
# debug - n_false_negative: 7084
#
# debug - n_true_positive: 216
# debug - n_false_positive: 84784
# debug - n_true_negative: 2457437
# debug - n_false_negative: 7086
#
# debug - n_true_positive: 216
# debug - n_false_positive: 84884
# debug - n_true_negative: 2460328
# debug - n_false_negative: 7096
#
# debug - n_true_positive: 216
# debug - n_false_positive: 84984
# debug - n_true_negative: 2463223
# debug - n_false_negative: 7101
#
# debug - n_true_positive: 217
# debug - n_false_positive: 85083
# debug - n_true_negative: 2466110
# debug - n_false_negative: 7113
#
# debug - n_true_positive: 217
# debug - n_false_positive: 85183
# debug - n_true_negative: 2468997
# debug - n_false_negative: 7125
#
# debug - n_true_positive: 217
# debug - n_false_positive: 85283
# debug - n_true_negative: 2471887
# debug - n_false_negative: 7135
#
# debug - n_true_positive: 217
# debug - n_false_positive: 85383
# debug - n_true_negative: 2474784
# debug - n_false_negative: 7141
#
# debug - n_true_positive: 218
# debug - n_false_positive: 85482
# debug - n_true_negative: 2477654
# debug - n_false_negative: 7170
#
# debug - n_true_positive: 218
# debug - n_false_positive: 85582
# debug - n_true_negative: 2480551
# debug - n_false_negative: 7175
#
# debug - n_true_positive: 218
# debug - n_false_positive: 85682
# debug - n_true_negative: 2483449
# debug - n_false_negative: 7177
#
# debug - n_true_positive: 219
# debug - n_false_positive: 85781
# debug - n_true_negative: 2486338
# debug - n_false_negative: 7187
#
# debug - n_true_positive: 219
# debug - n_false_positive: 85881
# debug - n_true_negative: 2489231
# debug - n_false_negative: 7193
#
# debug - n_true_positive: 221
# debug - n_false_positive: 85979
# debug - n_true_negative: 2492109
# debug - n_false_negative: 7213
#
# debug - n_true_positive: 222
# debug - n_false_positive: 86078
# debug - n_true_negative: 2494999
# debug - n_false_negative: 7224
#
# debug - n_true_positive: 223
# debug - n_false_positive: 86177
# debug - n_true_negative: 2497887
# debug - n_false_negative: 7237
#
# debug - n_true_positive: 223
# debug - n_false_positive: 86277
# debug - n_true_negative: 2500774
# debug - n_false_negative: 7247
#
# debug - n_true_positive: 224
# debug - n_false_positive: 86376
# debug - n_true_negative: 2503665
# debug - n_false_negative: 7256
#
# debug - n_true_positive: 225
# debug - n_false_positive: 86475
# debug - n_true_negative: 2506541
# debug - n_false_negative: 7278
#
# debug - n_true_positive: 225
# debug - n_false_positive: 86575
# debug - n_true_negative: 2509436
# debug - n_false_negative: 7280
#
# debug - n_true_positive: 226
# debug - n_false_positive: 86674
# debug - n_true_negative: 2512329
# debug - n_false_negative: 7288
#
# debug - n_true_positive: 226
# debug - n_false_positive: 86774
# debug - n_true_negative: 2515211
# debug - n_false_negative: 7305
#
# debug - n_true_positive: 226
# debug - n_false_positive: 86874
# debug - n_true_negative: 2518103
# debug - n_false_negative: 7316
#
# debug - n_true_positive: 226
# debug - n_false_positive: 86974
# debug - n_true_negative: 2520995
# debug - n_false_negative: 7327
#
# debug - n_true_positive: 226
# debug - n_false_positive: 87074
# debug - n_true_negative: 2523892
# debug - n_false_negative: 7330
#
# debug - n_true_positive: 226
# debug - n_false_positive: 87174
# debug - n_true_negative: 2526779
# debug - n_false_negative: 7341
#
# debug - n_true_positive: 226
# debug - n_false_positive: 87274
# debug - n_true_negative: 2529671
# debug - n_false_negative: 7351
#
# debug - n_true_positive: 226
# debug - n_false_positive: 87374
# debug - n_true_negative: 2532567
# debug - n_false_negative: 7353
#
# debug - n_true_positive: 226
# debug - n_false_positive: 87474
# debug - n_true_negative: 2535465
# debug - n_false_negative: 7356
#
# debug - n_true_positive: 226
# debug - n_false_positive: 87574
# debug - n_true_negative: 2538348
# debug - n_false_negative: 7371
#
# debug - n_true_positive: 226
# debug - n_false_positive: 87674
# debug - n_true_negative: 2541234
# debug - n_false_negative: 7385
#
# debug - n_true_positive: 227
# debug - n_false_positive: 87773
# debug - n_true_negative: 2544133
# debug - n_false_negative: 7388
#
# debug - n_true_positive: 227
# debug - n_false_positive: 87873
# debug - n_true_negative: 2547019
# debug - n_false_negative: 7403
#
# debug - n_true_positive: 227
# debug - n_false_positive: 87973
# debug - n_true_negative: 2549903
# debug - n_false_negative: 7420
#
# debug - n_true_positive: 227
# debug - n_false_positive: 88073
# debug - n_true_negative: 2552797
# debug - n_false_negative: 7426
#
# debug - n_true_positive: 227
# debug - n_false_positive: 88173
# debug - n_true_negative: 2555692
# debug - n_false_negative: 7430
#
# debug - n_true_positive: 227
# debug - n_false_positive: 88273
# debug - n_true_negative: 2558588
# debug - n_false_negative: 7433
#
# debug - n_true_positive: 227
# debug - n_false_positive: 88373
# debug - n_true_negative: 2561475
# debug - n_false_negative: 7445
#
# debug - n_true_positive: 227
# debug - n_false_positive: 88473
# debug - n_true_negative: 2564372
# debug - n_false_negative: 7448
#
# debug - n_true_positive: 229
# debug - n_false_positive: 88571
# debug - n_true_negative: 2567246
# debug - n_false_negative: 7473
#
# debug - n_true_positive: 229
# debug - n_false_positive: 88671
# debug - n_true_negative: 2570142
# debug - n_false_negative: 7475
#
# debug - n_true_positive: 230
# debug - n_false_positive: 88770
# debug - n_true_negative: 2573020
# debug - n_false_negative: 7495
#
# debug - n_true_positive: 230
# debug - n_false_positive: 88870
# debug - n_true_negative: 2575916
# debug - n_false_negative: 7497
#
# debug - n_true_positive: 230
# debug - n_false_positive: 88970
# debug - n_true_negative: 2578808
# debug - n_false_negative: 7503
#
# debug - n_true_positive: 230
# debug - n_false_positive: 89070
# debug - n_true_negative: 2581706
# debug - n_false_negative: 7506
#
# debug - n_true_positive: 230
# debug - n_false_positive: 89170
# debug - n_true_negative: 2584602
# debug - n_false_negative: 7509
#
# debug - n_true_positive: 230
# debug - n_false_positive: 89270
# debug - n_true_negative: 2587497
# debug - n_false_negative: 7513
#
# debug - n_true_positive: 230
# debug - n_false_positive: 89370
# debug - n_true_negative: 2590387
# debug - n_false_negative: 7522
#
# debug - n_true_positive: 230
# debug - n_false_positive: 89470
# debug - n_true_negative: 2593280
# debug - n_false_negative: 7526
#
# debug - n_true_positive: 230
# debug - n_false_positive: 89570
# debug - n_true_negative: 2596169
# debug - n_false_negative: 7536
#
# debug - n_true_positive: 230
# debug - n_false_positive: 89670
# debug - n_true_negative: 2599065
# debug - n_false_negative: 7538
#
# debug - n_true_positive: 230
# debug - n_false_positive: 89770
# debug - n_true_negative: 2601950
# debug - n_false_negative: 7552
#
# debug - n_true_positive: 231
# debug - n_false_positive: 89869
# debug - n_true_negative: 2604841
# debug - n_false_negative: 7561
#
# debug - n_true_positive: 232
# debug - n_false_positive: 89968
# debug - n_true_negative: 2607730
# debug - n_false_negative: 7570
#
# debug - n_true_positive: 232
# debug - n_false_positive: 90068
# debug - n_true_negative: 2610625
# debug - n_false_negative: 7573
#
# debug - n_true_positive: 232
# debug - n_false_positive: 90168
# debug - n_true_negative: 2613503
# debug - n_false_negative: 7596
#
# debug - n_true_positive: 233
# debug - n_false_positive: 90267
# debug - n_true_negative: 2616398
# debug - n_false_negative: 7600
#
# debug - n_true_positive: 233
# debug - n_false_positive: 90367
# debug - n_true_negative: 2619289
# debug - n_false_negative: 7610
#
# debug - n_true_positive: 233
# debug - n_false_positive: 90467
# debug - n_true_negative: 2622184
# debug - n_false_negative: 7614
#
# debug - n_true_positive: 233
# debug - n_false_positive: 90567
# debug - n_true_negative: 2625077
# debug - n_false_negative: 7620
#
# debug - n_true_positive: 233
# debug - n_false_positive: 90667
# debug - n_true_negative: 2627966
# debug - n_false_negative: 7630
#
# debug - n_true_positive: 233
# debug - n_false_positive: 90767
# debug - n_true_negative: 2630864
# debug - n_false_negative: 7636
#
# debug - n_true_positive: 233
# debug - n_false_positive: 90867
# debug - n_true_negative: 2633760
# debug - n_false_negative: 7640
#
# debug - n_true_positive: 233
# debug - n_false_positive: 90967
# debug - n_true_negative: 2636655
# debug - n_false_negative: 7645
#
# debug - n_true_positive: 233
# debug - n_false_positive: 91067
# debug - n_true_negative: 2639551
# debug - n_false_negative: 7647
#
# debug - n_true_positive: 233
# debug - n_false_positive: 91167
# debug - n_true_negative: 2642440
# debug - n_false_negative: 7658
#
# debug - n_true_positive: 233
# debug - n_false_positive: 91267
# debug - n_true_negative: 2645337
# debug - n_false_negative: 7661
#
# debug - n_true_positive: 233
# debug - n_false_positive: 91367
# debug - n_true_negative: 2648229
# debug - n_false_negative: 7667
#
# debug - n_true_positive: 233
# debug - n_false_positive: 91467
# debug - n_true_negative: 2651123
# debug - n_false_negative: 7671
#
# debug - n_true_positive: 233
# debug - n_false_positive: 91567
# debug - n_true_negative: 2654001
# debug - n_false_negative: 7693
#
# debug - n_true_positive: 233
# debug - n_false_positive: 91667
# debug - n_true_negative: 2656892
# debug - n_false_negative: 7702
#
# debug - n_true_positive: 233
# debug - n_false_positive: 91767
# debug - n_true_negative: 2659786
# debug - n_false_negative: 7707
#
# debug - n_true_positive: 233
# debug - n_false_positive: 91867
# debug - n_true_negative: 2662680
# debug - n_false_negative: 7711
#
# debug - n_true_positive: 235
# debug - n_false_positive: 91965
# debug - n_true_negative: 2665571
# debug - n_false_negative: 7718
#
# debug - n_true_positive: 235
# debug - n_false_positive: 92065
# debug - n_true_negative: 2668455
# debug - n_false_negative: 7735
#
# debug - n_true_positive: 236
# debug - n_false_positive: 92164
# debug - n_true_negative: 2671345
# debug - n_false_negative: 7744
#
# debug - n_true_positive: 236
# debug - n_false_positive: 92264
# debug - n_true_negative: 2674244
# debug - n_false_negative: 7747
#
# debug - n_true_positive: 236
# debug - n_false_positive: 92364
# debug - n_true_negative: 2677123
# debug - n_false_negative: 7766
#
# debug - n_true_positive: 236
# debug - n_false_positive: 92464
# debug - n_true_negative: 2680008
# debug - n_false_negative: 7778
#
# debug - n_true_positive: 236
# debug - n_false_positive: 92564
# debug - n_true_negative: 2682897
# debug - n_false_negative: 7788
#
# debug - n_true_positive: 236
# debug - n_false_positive: 92664
# debug - n_true_negative: 2685784
# debug - n_false_negative: 7801
#
# debug - n_true_positive: 236
# debug - n_false_positive: 92764
# debug - n_true_negative: 2688673
# debug - n_false_negative: 7811
#
# debug - n_true_positive: 236
# debug - n_false_positive: 92864
# debug - n_true_negative: 2691568
# debug - n_false_negative: 7814
#
# debug - n_true_positive: 236
# debug - n_false_positive: 92964
# debug - n_true_negative: 2694464
# debug - n_false_negative: 7816
#
# debug - n_true_positive: 236
# debug - n_false_positive: 93064
# debug - n_true_negative: 2697356
# debug - n_false_negative: 7823
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-a98a9da7acac> in <module>
#       1 model_analyzer_helper = ModelAnalyzerHelper()
# ----> 2 model_analyzer_helper.evaluate(vali_data_dictionary, recommendation_data_dictionary)
#
# <ipython-input-42-ab129418b1a5> in evaluate(self, testing_data_dictionary, recommendation_data_dictionary)
#      51                 if positive_predition_item_id not in positive_testing_item_ids: n_false_positive = n_false_positive + 1
#      52
# ---> 53             for negative_predition_item_id in negative_predition_item_ids:
#      54                 if negative_predition_item_id in negative_testing_item_ids: n_true_negative = n_true_negative + 1
#      55                 if negative_predition_item_id not in negative_testing_item_ids: n_false_negative = n_false_negative + 1
#
# KeyboardInterrupt:
