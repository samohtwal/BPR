# %% [markdown]
# <a href="https://colab.research.google.com/github/samohtwal/BPR/blob/20221027/BPR_20221029.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import torch
import copy
from itertools import islice
from google.colab import files
import os
import matplotlib.pyplot as plt

# %%
global data_user_column_name
data_user_column_name = 'user_id'

global data_item_column_name
data_item_column_name = 'item_id'

global data_group_by_user_id_dictionary_key
data_group_by_user_id_dictionary_key = 'data_group_by_user_id'

global data_group_by_item_id_dictionary_key
data_group_by_item_id_dictionary_key = 'data_group_by_item_id'

global user_latent_factor_matrix_dictionary_key
user_latent_factor_matrix_dictionary_key = 'user_latent_factor_matrix'

global item_latent_factor_matrix_dictionary_key
item_latent_factor_matrix_dictionary_key = 'item_latent_factor_matrix'

global working_file_path
working_file_path = '/content/working/'

global user_latent_factor_matrix_file_name
user_latent_factor_matrix_file_name = 'user_latent_factor_matrix.csv'

global item_latent_factor_matrix_file_name
item_latent_factor_matrix_file_name = 'item_latent_factor_matrix.csv'

global root_mean_square_error_file_name
root_mean_square_error_file_name = 'root_mean_square_error.csv'

# %%
class DataHelper:

    def load_raw_data_dictionary(self, data_url):

        column_names = [data_user_column_name, data_item_column_name]
        raw_data = pd.read_csv(data_url, names = column_names, header=0)

        data_group_by_user_id = raw_data.groupby(data_user_column_name)[data_item_column_name].apply(list).reset_index(name=data_item_column_name).sort_values(by=[data_user_column_name])
        data_group_by_item_id = raw_data.groupby(data_item_column_name)[data_user_column_name].apply(list).reset_index(name=data_user_column_name).sort_values(by=[data_item_column_name])

        data_dictionary = {
            data_group_by_user_id_dictionary_key: data_group_by_user_id, 
            data_group_by_item_id_dictionary_key: data_group_by_item_id
        }

        return data_dictionary

    def save_latent_factor_matrix_dictionary(self, latent_factor_matrix_dictionary):

        user_latent_factor_matrix = latent_factor_matrix_dictionary[user_latent_factor_matrix_dictionary_key]
        item_latent_factor_matrix = latent_factor_matrix_dictionary[item_latent_factor_matrix_dictionary_key]
        
        if os.path.exists(working_file_path) == False:
            os.mkdir(working_file_path)

        pd.DataFrame(user_latent_factor_matrix).to_csv(working_file_path + user_latent_factor_matrix_file_name, index=False, header=False)
        pd.DataFrame(item_latent_factor_matrix).to_csv(working_file_path + item_latent_factor_matrix_file_name, index=False, header=False)

        return None

    def load_latent_factor_matrix_dictionary(self):

        user_latent_factor_matrix = pd.read_csv(working_file_path + user_latent_factor_matrix_file_name, header=None).values
        item_latent_factor_matrix = pd.read_csv(working_file_path + item_latent_factor_matrix_file_name, header=None).values

        latent_factor_matrix_dictionary = {
            user_latent_factor_matrix_dictionary_key: user_latent_factor_matrix, 
            item_latent_factor_matrix_dictionary_key: item_latent_factor_matrix
        }

        return latent_factor_matrix_dictionary
    
    def save_root_mean_square_error(self, errors):
        if os.path.exists(working_file_path) == False:
            os.mkdir(working_file_path)
        pd.DataFrame(errors).to_csv(working_file_path + root_mean_square_error_file_name, index=False, header=False)

        return None

# %%
class BayseianPersonalizedRankingModel:

    def __init__(self, random_seed = 1234, n_latent_factor = 15, n_batch = 10, learning_rate = 0.01, regularization_constant = 0.01):
        self.random_seed = random_seed
        self.n_latent_factor = n_latent_factor
        self.n_batch = n_batch
        self.learning_rate = learning_rate
        self.regularization_constant = regularization_constant

    def fit(self, training_data_dictionary):

        training_data_group_by_user_id = training_data_dictionary[data_group_by_user_id_dictionary_key]
        training_data_group_by_item_id = training_data_dictionary[data_group_by_item_id_dictionary_key]

        n_user = len(training_data_group_by_user_id[data_user_column_name])
        n_item = len(training_data_group_by_item_id[data_item_column_name])

        rstate = np.random.RandomState(self.random_seed)

        user_latent_factor_matrix = rstate.normal(size = (n_user, self.n_latent_factor))
        item_latent_factor_matrix = rstate.normal(size = (n_item, self.n_latent_factor))

        user_item_rating_matrix = self._create_user_item_rating_matrix(training_data_group_by_user_id, training_data_group_by_item_id)

        user_latent_factor_matrixes = []
        item_latent_factor_matrixes = []
        root_mean_square_errors = []

        is_converge = True
        index = 0
        while is_converge:

            # self.learning_rate = self.learning_rate * np.exp(-5*index)
            # self.learning_rate = self.learning_rate / (1 + 2 * index)
            
            sample_latent_factor_matrix_row_indexes = self._create_sample_latent_factor_matrix_row_indexes(training_data_group_by_user_id, training_data_group_by_item_id)
            sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes = sample_latent_factor_matrix_row_indexes
            user_latent_factor_matrix, item_latent_factor_matrix = self._update_sample_latent_factor_matrix_rows(user_latent_factor_matrix, item_latent_factor_matrix, sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes)
            
            sum_of_square_error = np.sum((user_item_rating_matrix - self._predict(user_latent_factor_matrix, item_latent_factor_matrix))**2)
            root_mean_square_error = np.sqrt((sum_of_square_error / n_user * n_item))

            user_latent_factor_matrixes.append(user_latent_factor_matrix)
            item_latent_factor_matrixes.append(item_latent_factor_matrix)
            root_mean_square_errors.append(root_mean_square_error)
            
            print('debug - iteration:', index+1, end='\n')
            print('debug - root_mean_square_error:', root_mean_square_error, end='\n')
            print('', end='\n')
            
            if (root_mean_square_errors[index] > root_mean_square_errors[index-1] 
                and root_mean_square_errors[index-1] > root_mean_square_errors[index-2]
                and root_mean_square_errors[index-2] > root_mean_square_errors[index-3]):
            # if index == 10:
                is_converge = False

            index = index + 1

        latent_factor_matrix_dictionary = {
            user_latent_factor_matrix_dictionary_key: user_latent_factor_matrixes[index-4], 
            item_latent_factor_matrix_dictionary_key: item_latent_factor_matrixes[index-4]
        }

        return latent_factor_matrix_dictionary, root_mean_square_errors[0:index-4]

    def _create_user_item_rating_matrix(self, training_data_group_by_user_id, training_data_group_by_item_id):

        n_user = len(training_data_group_by_user_id[data_user_column_name])
        n_item = len(training_data_group_by_item_id[data_item_column_name])

        user_ids = training_data_group_by_user_id[data_user_column_name].tolist()
        item_ids = training_data_group_by_item_id[data_item_column_name].tolist()

        user_item_rating_matrix = np.zeros((n_user, n_item), dtype = np.int64)
        for user_id_index, user_id in enumerate(user_ids):
            item_id_indexes = np.where(np.isin(training_data_group_by_user_id.iloc[user_id_index][data_item_column_name],item_ids))[0]
            for item_id_index in item_id_indexes:
                user_item_rating_matrix[user_id_index, item_id_index] = 1

        return user_item_rating_matrix

    def _create_sample_latent_factor_matrix_row_indexes(self, training_data_group_by_user_id, training_data_group_by_item_id):

        n_user = len(training_data_group_by_user_id[data_user_column_name])
        n_item = len(training_data_group_by_item_id[data_item_column_name])

        item_ids = training_data_group_by_item_id[data_item_column_name].tolist()

        sample_user_id_indexes = np.random.choice(n_user, size = self.n_batch, replace = False)
        sample_positive_item_id_indexes = np.zeros(self.n_batch, dtype = np.int64)
        sample_negative_item_id_indexes = np.zeros(self.n_batch, dtype = np.int64)

        for index, sampled_user_id_index in enumerate(sample_user_id_indexes):
            possible_positive_item_ids = training_data_group_by_user_id.iloc[sampled_user_id_index][data_item_column_name]
            possible_negative_item_ids = list(set(item_ids).difference(possible_positive_item_ids))
            sample_positive_item_id = np.random.choice(possible_positive_item_ids)
            sample_negative_item_id = np.random.choice(possible_negative_item_ids)
            sample_positive_item_id_indexes[index] = item_ids.index(sample_positive_item_id)
            sample_negative_item_id_indexes[index] = item_ids.index(sample_negative_item_id)

        return sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes

    def _update_sample_latent_factor_matrix_rows(self, user_latent_factor_matrix, item_latent_factor_matrix, sample_user_id_indexes, sample_positive_item_id_indexes, sample_negative_item_id_indexes):

        sample_user_latent_factor_matrix_tuple = user_latent_factor_matrix[sample_user_id_indexes]
        sample_item_latent_factor_matrix_positive_item_tuple = item_latent_factor_matrix[sample_positive_item_id_indexes]
        sample_item_latent_factor_matrix_negative_item_tuple = item_latent_factor_matrix[sample_negative_item_id_indexes]

        r_uij = np.sum(sample_user_latent_factor_matrix_tuple * (sample_item_latent_factor_matrix_positive_item_tuple - sample_item_latent_factor_matrix_negative_item_tuple), axis = 1)
        sigmoid = np.exp(-r_uij) / (1.0 + np.exp(-r_uij))
        sigmoid_tiled = np.tile(sigmoid, (self.n_latent_factor, 1)).T

        gradient_user = sigmoid_tiled * (sample_item_latent_factor_matrix_negative_item_tuple - sample_item_latent_factor_matrix_positive_item_tuple) + self.regularization_constant * sample_user_latent_factor_matrix_tuple
        gradient_positive_item = sigmoid_tiled * -sample_user_latent_factor_matrix_tuple + self.regularization_constant * sample_item_latent_factor_matrix_positive_item_tuple
        gradient_negative_item = sigmoid_tiled * sample_user_latent_factor_matrix_tuple + self.regularization_constant * sample_item_latent_factor_matrix_negative_item_tuple

        user_latent_factor_matrix[sample_user_id_indexes] -= self.learning_rate * gradient_user
        item_latent_factor_matrix[sample_positive_item_id_indexes] -= self.learning_rate * gradient_positive_item
        item_latent_factor_matrix[sample_negative_item_id_indexes] -= self.learning_rate * gradient_negative_item

        return user_latent_factor_matrix, item_latent_factor_matrix

    def recommend(self, testing_data_dictionary, training_data_dictionary, latent_factor_matrix_dictionary, lower_bound_score, upper_bound_score):

        testing_data_group_by_user_id = testing_data_dictionary[data_group_by_user_id_dictionary_key]

        n_user = len(testing_data_group_by_user_id[data_user_column_name])
        user_ids = user_ids = testing_data_group_by_user_id[data_user_column_name].tolist()

        recommendation_user_ids = []
        recommendation_item_ids = []
        for user_id in user_ids:
            best_recommendition_item_ids = self.recommend_user(training_data_dictionary, latent_factor_matrix_dictionary, user_id, lower_bound_score, upper_bound_score)
            for item_id in best_recommendition_item_ids:
                recommendation_user_ids.append(user_id)
                recommendation_item_ids.append(item_id)

        data = {'user_id': recommendation_user_ids, 'item_id': recommendation_item_ids}
        recommendation_data = pd.DataFrame.from_dict(data)

        recommendation_data_group_by_user_id = recommendation_data.groupby(data_user_column_name)[data_item_column_name].apply(list).reset_index(name=data_item_column_name).sort_values(by=[data_user_column_name])
        recommendation_data_group_by_item_id = recommendation_data.groupby(data_item_column_name)[data_user_column_name].apply(list).reset_index(name=data_user_column_name).sort_values(by=[data_item_column_name])

        recommendation_data_dictionary = {
            data_group_by_user_id_dictionary_key: recommendation_data_group_by_user_id, 
            data_group_by_item_id_dictionary_key: recommendation_data_group_by_item_id
        }

        return recommendation_data_dictionary

    def recommend_user(self, training_data_dictionary, latent_factor_matrix_dictionary, user_id, lower_bound_score, upper_bound_score):

        training_data_group_by_user_id = training_data_dictionary[data_group_by_user_id_dictionary_key]
        training_data_group_by_item_id = training_data_dictionary[data_group_by_item_id_dictionary_key]

        user_latent_factor_matrix = latent_factor_matrix_dictionary[user_latent_factor_matrix_dictionary_key]
        item_latent_factor_matrix = latent_factor_matrix_dictionary[item_latent_factor_matrix_dictionary_key]

        user_ids = training_data_group_by_user_id[data_user_column_name].tolist()
        item_ids = training_data_group_by_item_id[data_item_column_name].tolist()

        n_item = len(training_data_group_by_item_id[data_item_column_name])

        user_index = user_ids.index(user_id)

        scores = self._predict_user(user_latent_factor_matrix, item_latent_factor_matrix, user_index)

        item_score_dictionary = {item_ids[i]: scores[i] for i in range(len(item_ids))}
        positive_item_ids = training_data_group_by_user_id.iloc[user_index][data_item_column_name]

        item_score_dictionary = {item_ids[i]: scores[i] for i in range(len(item_ids))}

        # remove positive item
        # item_score_dictionary = {key: item_score_dictionary[key] for key in item_ids if key not in positive_item_ids}

        # item_score_dictionary = dict(sorted(item_score_dictionary.items(), key=lambda item: item[1], reverse=True))

        # best_recommendition_item_dictionary = dict(islice(item_score_dictionary.items(), n_best_recommendation))
        # best_recommendition_item_ids = list(best_recommendition_item_dictionary.keys())[0:n_best_recommendation]

        # item_score_dictionary = dict((key, value) for key, value in item_score_dictionary.items() if value >= 0.8)

        item_score_dictionary = dict((key, value) for key, value in item_score_dictionary.items() if value >= lower_bound_score and value <= upper_bound_score)
        best_recommendition_item_ids = list(item_score_dictionary.keys())

        '''
        print('debug - user_id:', user_id, end='\n')
        print('debug - best_recommendation:', best_recommendition_item_ids, end='\n')
        print('', end='\n')
        '''

        return best_recommendition_item_ids

    def _predict(self, user_latent_factor_matrix, item_latent_factor_matrix):
        return user_latent_factor_matrix.dot(item_latent_factor_matrix.T)

    def _predict_user(self, user_latent_factor_matrix, item_latent_factor_matrix, user_index):
        return user_latent_factor_matrix[user_index].dot(item_latent_factor_matrix.T)

# %%
class ModelAnalyzerHelper:

    def plot_error_chart(self, root_mean_square_errors, bayseian_personalized_ranking_parameters):

        x  = range(len(root_mean_square_errors))
        y = root_mean_square_errors
        plt.plot(x, y, label='Learning Rate = ' + str(bayseian_personalized_ranking_parameters['learning_rate']))
        plt.plot()

        plt.xlabel("Iteration")
        plt.ylabel("Root Mean Square Error")
        plt.title("Root Mean Square Error / Iteration")
        plt.legend()
        plt.show()

        return None
    
    def evaluate(self, testing_data_dictionary, recommendation_data_dictionary):

        testing_data_group_by_user_id = testing_data_dictionary[data_group_by_user_id_dictionary_key]
        testing_user_ids = testing_data_group_by_user_id[data_user_column_name].tolist()

        testing_data_group_by_item_id = testing_data_dictionary[data_group_by_item_id_dictionary_key]
        testing_item_ids = testing_data_group_by_item_id[data_item_column_name].tolist()

        recommendation_data_group_by_user_id = recommendation_data_dictionary[data_group_by_user_id_dictionary_key]
        recommendation_user_ids = recommendation_data_group_by_user_id[data_user_column_name].tolist()

        print('debug - testing_data_group_by_user_id.shpape:', end='\n')
        print(testing_data_group_by_user_id.shape, end='\n')
        print('', end='\n')

        print('debug - recommendation_data_group_by_user_id.shpape:', end='\n')
        print(recommendation_data_group_by_user_id.shape, end='\n')
        print('', end='\n')

        n_true_positive = 0
        n_false_positive = 0
        n_true_negative = 0
        n_false_negative = 0

        for index, recommendation_user_id in enumerate(recommendation_user_ids):
            
            positive_testing_item_ids = testing_data_group_by_user_id.iloc[index][data_item_column_name]
            negative_testing_item_ids = list(set(testing_item_ids).difference(positive_testing_item_ids))
            positive_predition_item_ids = recommendation_data_group_by_user_id.iloc[index][data_item_column_name]
            negative_predition_item_ids = list(set(testing_item_ids).difference(positive_predition_item_ids))

            for positive_predition_item_id in positive_predition_item_ids:
                if positive_predition_item_id in positive_testing_item_ids: n_true_positive = n_true_positive + 1
                if positive_predition_item_id not in positive_testing_item_ids: n_false_positive = n_false_positive + 1

            for negative_predition_item_id in negative_predition_item_ids:
                if negative_predition_item_id in negative_testing_item_ids: n_true_negative = n_true_negative + 1
                if negative_predition_item_id not in negative_testing_item_ids: n_false_negative = n_false_negative + 1

            print('debug - n_true_positive:', n_true_positive, end='\n')
            print('debug - n_false_positive:', n_false_positive, end='\n')
            print('debug - n_true_negative:', n_true_negative, end='\n')
            print('debug - n_false_negative:', n_false_negative, end='\n')
            print('', end='\n')

        true_positive_rate = n_true_positive / (n_true_positive + n_false_negative)
        false_positive_rate = n_false_positive / (n_false_positive + n_true_negative)

        return true_positive_rate, false_positive_rate

# %%
data_helper = DataHelper()
bayseian_personalized_ranking_parameters = {
    'random_seed' : 1234, 
    'n_latent_factor' : 15, 
    'n_batch' : 1000, 
    'learning_rate' : 0.1, 
    'regularization_constant' : 0.1
}
bayseian_personalized_ranking_model = BayseianPersonalizedRankingModel(**bayseian_personalized_ranking_parameters)
model_analyzer_helper = ModelAnalyzerHelper()

# %%
training_data_url = 'https://raw.githubusercontent.com/samohtwal/BPR/20221027/data/train-20221026.csv'
training_data_dictionary = data_helper.load_raw_data_dictionary(training_data_url)

# %%
latent_factor_matrix_dictionary, root_mean_square_errors = bayseian_personalized_ranking_model.fit(training_data_dictionary)
data_helper.save_latent_factor_matrix_dictionary(latent_factor_matrix_dictionary)
data_helper.save_root_mean_square_error(root_mean_square_errors)
# Out:
# debug - iteration: 1
# debug - root_mean_square_error: 11719.496144172559
#
# debug - iteration: 2
# debug - root_mean_square_error: 11575.915357061467
#
# debug - iteration: 3
# debug - root_mean_square_error: 11436.804826524092
#
# debug - iteration: 4
# debug - root_mean_square_error: 11294.229722511518
#
# debug - iteration: 5
# debug - root_mean_square_error: 11159.723576269203
#
# debug - iteration: 6
# debug - root_mean_square_error: 11022.87841129593
#
# debug - iteration: 7
# debug - root_mean_square_error: 10894.628490691044
#
# debug - iteration: 8
# debug - root_mean_square_error: 10764.461951676867
#
# debug - iteration: 9
# debug - root_mean_square_error: 10630.506029447353
#
# debug - iteration: 10
# debug - root_mean_square_error: 10498.845892870328
#
# debug - iteration: 11
# debug - root_mean_square_error: 10373.205142077957
#
# debug - iteration: 12
# debug - root_mean_square_error: 10248.777869156593
#
# debug - iteration: 13
# debug - root_mean_square_error: 10127.284237172618
#
# debug - iteration: 14
# debug - root_mean_square_error: 10009.17345722327
#
# debug - iteration: 15
# debug - root_mean_square_error: 9892.83772639906
#
# debug - iteration: 16
# debug - root_mean_square_error: 9784.135236088241
#
# debug - iteration: 17
# debug - root_mean_square_error: 9670.183907328828
#
# debug - iteration: 18
# debug - root_mean_square_error: 9559.561408443178
#
# debug - iteration: 19
# debug - root_mean_square_error: 9450.211261168603
#
# debug - iteration: 20
# debug - root_mean_square_error: 9339.770032469954
#
# debug - iteration: 21
# debug - root_mean_square_error: 9232.050962658092
#
# debug - iteration: 22
# debug - root_mean_square_error: 9124.79902644193
#
# debug - iteration: 23
# debug - root_mean_square_error: 9019.307202736865
#
# debug - iteration: 24
# debug - root_mean_square_error: 8920.099168132507
#
# debug - iteration: 25
# debug - root_mean_square_error: 8821.031341315062
#
# debug - iteration: 26
# debug - root_mean_square_error: 8722.827130177844
#
# debug - iteration: 27
# debug - root_mean_square_error: 8629.170233581563
#
# debug - iteration: 28
# debug - root_mean_square_error: 8535.618410840987
#
# debug - iteration: 29
# debug - root_mean_square_error: 8438.678394207434
#
# debug - iteration: 30
# debug - root_mean_square_error: 8347.387082530184
#
# debug - iteration: 31
# debug - root_mean_square_error: 8256.69350860662
#
# debug - iteration: 32
# debug - root_mean_square_error: 8164.179083626457
#
# debug - iteration: 33
# debug - root_mean_square_error: 8075.693783081513
#
# debug - iteration: 34
# debug - root_mean_square_error: 7988.400783518918
#
# debug - iteration: 35
# debug - root_mean_square_error: 7898.409625391642
#
# debug - iteration: 36
# debug - root_mean_square_error: 7810.687279726998
#
# debug - iteration: 37
# debug - root_mean_square_error: 7729.461665352137
#
# debug - iteration: 38
# debug - root_mean_square_error: 7646.9037257023265
#
# debug - iteration: 39
# debug - root_mean_square_error: 7566.103596511455
#
# debug - iteration: 40
# debug - root_mean_square_error: 7484.984369111707
#
# debug - iteration: 41
# debug - root_mean_square_error: 7406.471372943923
#
# debug - iteration: 42
# debug - root_mean_square_error: 7328.423884710917
#
# debug - iteration: 43
# debug - root_mean_square_error: 7250.924948565263
#
# debug - iteration: 44
# debug - root_mean_square_error: 7175.487979678334
#
# debug - iteration: 45
# debug - root_mean_square_error: 7100.23320503184
#
# debug - iteration: 46
# debug - root_mean_square_error: 7025.0992334444245
#
# debug - iteration: 47
# debug - root_mean_square_error: 6953.136367605908
#
# debug - iteration: 48
# debug - root_mean_square_error: 6880.038514313526
#
# debug - iteration: 49
# debug - root_mean_square_error: 6806.868161572492
#
# debug - iteration: 50
# debug - root_mean_square_error: 6737.9254485933025
#
# debug - iteration: 51
# debug - root_mean_square_error: 6668.598599384091
#
# debug - iteration: 52
# debug - root_mean_square_error: 6602.979158476212
#
# debug - iteration: 53
# debug - root_mean_square_error: 6535.63900746315
#
# debug - iteration: 54
# debug - root_mean_square_error: 6469.447896566625
#
# debug - iteration: 55
# debug - root_mean_square_error: 6404.676963040968
#
# debug - iteration: 56
# debug - root_mean_square_error: 6341.583994893194
#
# debug - iteration: 57
# debug - root_mean_square_error: 6277.664096786366
#
# debug - iteration: 58
# debug - root_mean_square_error: 6216.945617088478
#
# debug - iteration: 59
# debug - root_mean_square_error: 6153.936794693483
#
# debug - iteration: 60
# debug - root_mean_square_error: 6091.503151606084
#
# debug - iteration: 61
# debug - root_mean_square_error: 6030.776354555476
#
# debug - iteration: 62
# debug - root_mean_square_error: 5967.751552180013
#
# debug - iteration: 63
# debug - root_mean_square_error: 5911.518288068639
#
# debug - iteration: 64
# debug - root_mean_square_error: 5854.160012253666
#
# debug - iteration: 65
# debug - root_mean_square_error: 5798.449672531409
#
# debug - iteration: 66
# debug - root_mean_square_error: 5744.275741881539
#
# debug - iteration: 67
# debug - root_mean_square_error: 5689.943748480627
#
# debug - iteration: 68
# debug - root_mean_square_error: 5635.768283400932
#
# debug - iteration: 69
# debug - root_mean_square_error: 5582.840232054865
#
# debug - iteration: 70
# debug - root_mean_square_error: 5530.506022693662
#
# debug - iteration: 71
# debug - root_mean_square_error: 5478.176312006007
#
# debug - iteration: 72
# debug - root_mean_square_error: 5425.6125688384145
#
# debug - iteration: 73
# debug - root_mean_square_error: 5375.798791437662
#
# debug - iteration: 74
# debug - root_mean_square_error: 5323.684205988776
#
# debug - iteration: 75
# debug - root_mean_square_error: 5274.796313740242
#
# debug - iteration: 76
# debug - root_mean_square_error: 5225.655879946564
#
# debug - iteration: 77
# debug - root_mean_square_error: 5178.17105323291
#
# debug - iteration: 78
# debug - root_mean_square_error: 5131.427135540944
#
# debug - iteration: 79
# debug - root_mean_square_error: 5083.8241446825305
#
# debug - iteration: 80
# debug - root_mean_square_error: 5033.351607155959
#
# debug - iteration: 81
# debug - root_mean_square_error: 4988.486761429774
#
# debug - iteration: 82
# debug - root_mean_square_error: 4944.322411903055
#
# debug - iteration: 83
# debug - root_mean_square_error: 4900.80001614785
#
# debug - iteration: 84
# debug - root_mean_square_error: 4857.206230669365
#
# debug - iteration: 85
# debug - root_mean_square_error: 4810.858112512652
#
# debug - iteration: 86
# debug - root_mean_square_error: 4767.003968696623
#
# debug - iteration: 87
# debug - root_mean_square_error: 4723.125388192043
#
# debug - iteration: 88
# debug - root_mean_square_error: 4681.380211748443
#
# debug - iteration: 89
# debug - root_mean_square_error: 4639.60791811413
#
# debug - iteration: 90
# debug - root_mean_square_error: 4596.992327477088
#
# debug - iteration: 91
# debug - root_mean_square_error: 4554.465262171914
#
# debug - iteration: 92
# debug - root_mean_square_error: 4513.570463790133
#
# debug - iteration: 93
# debug - root_mean_square_error: 4474.804119932022
#
# debug - iteration: 94
# debug - root_mean_square_error: 4436.611916046078
#
# debug - iteration: 95
# debug - root_mean_square_error: 4396.893487905388
#
# debug - iteration: 96
# debug - root_mean_square_error: 4358.81417353609
#
# debug - iteration: 97
# debug - root_mean_square_error: 4323.165338001523
#
# debug - iteration: 98
# debug - root_mean_square_error: 4284.942304785104
#
# debug - iteration: 99
# debug - root_mean_square_error: 4249.017484461459
#
# debug - iteration: 100
# debug - root_mean_square_error: 4212.891548472674
#
# debug - iteration: 101
# debug - root_mean_square_error: 4175.770402071475
#
# debug - iteration: 102
# debug - root_mean_square_error: 4140.654577939404
#
# debug - iteration: 103
# debug - root_mean_square_error: 4105.470996744681
#
# debug - iteration: 104
# debug - root_mean_square_error: 4070.4794221966927
#
# debug - iteration: 105
# debug - root_mean_square_error: 4035.6032716792765
#
# debug - iteration: 106
# debug - root_mean_square_error: 4000.4153764321964
#
# debug - iteration: 107
# debug - root_mean_square_error: 3967.279938770719
#
# debug - iteration: 108
# debug - root_mean_square_error: 3932.957495452842
#
# debug - iteration: 109
# debug - root_mean_square_error: 3901.3639339467454
#
# debug - iteration: 110
# debug - root_mean_square_error: 3869.7608195887906
#
# debug - iteration: 111
# debug - root_mean_square_error: 3837.2073820002415
#
# debug - iteration: 112
# debug - root_mean_square_error: 3806.3833759244303
#
# debug - iteration: 113
# debug - root_mean_square_error: 3775.822446547144
#
# debug - iteration: 114
# debug - root_mean_square_error: 3746.3046359969003
#
# debug - iteration: 115
# debug - root_mean_square_error: 3715.461132966729
#
# debug - iteration: 116
# debug - root_mean_square_error: 3686.0917346180995
#
# debug - iteration: 117
# debug - root_mean_square_error: 3657.272794159668
#
# debug - iteration: 118
# debug - root_mean_square_error: 3628.809017759078
#
# debug - iteration: 119
# debug - root_mean_square_error: 3600.553166408867
#
# debug - iteration: 120
# debug - root_mean_square_error: 3572.303913522598
#
# debug - iteration: 121
# debug - root_mean_square_error: 3543.4941497847863
#
# debug - iteration: 122
# debug - root_mean_square_error: 3515.2036740292892
#
# debug - iteration: 123
# debug - root_mean_square_error: 3489.0199483111887
#
# debug - iteration: 124
# debug - root_mean_square_error: 3462.6802226603395
#
# debug - iteration: 125
# debug - root_mean_square_error: 3434.8223079712757
#
# debug - iteration: 126
# debug - root_mean_square_error: 3407.3238186752683
#
# debug - iteration: 127
# debug - root_mean_square_error: 3380.8120194003727
#
# debug - iteration: 128
# debug - root_mean_square_error: 3355.53234823848
#
# debug - iteration: 129
# debug - root_mean_square_error: 3329.4840418580684
#
# debug - iteration: 130
# debug - root_mean_square_error: 3305.453627849771
#
# debug - iteration: 131
# debug - root_mean_square_error: 3280.460560508704
#
# debug - iteration: 132
# debug - root_mean_square_error: 3255.0435630016655
#
# debug - iteration: 133
# debug - root_mean_square_error: 3229.997469956522
#
# debug - iteration: 134
# debug - root_mean_square_error: 3206.173620173784
#
# debug - iteration: 135
# debug - root_mean_square_error: 3181.9653488639256
#
# debug - iteration: 136
# debug - root_mean_square_error: 3157.3234802638344
#
# debug - iteration: 137
# debug - root_mean_square_error: 3133.900164941618
#
# debug - iteration: 138
# debug - root_mean_square_error: 3111.431379205034
#
# debug - iteration: 139
# debug - root_mean_square_error: 3087.846675649396
#
# debug - iteration: 140
# debug - root_mean_square_error: 3065.6972712242996
#
# debug - iteration: 141
# debug - root_mean_square_error: 3043.145020102095
#
# debug - iteration: 142
# debug - root_mean_square_error: 3020.5911230520646
#
# debug - iteration: 143
# debug - root_mean_square_error: 2999.229317599476
#
# debug - iteration: 144
# debug - root_mean_square_error: 2977.101288303091
#
# debug - iteration: 145
# debug - root_mean_square_error: 2956.1135673929007
#
# debug - iteration: 146
# debug - root_mean_square_error: 2934.4143769216216
#
# debug - iteration: 147
# debug - root_mean_square_error: 2912.964236412771
#
# debug - iteration: 148
# debug - root_mean_square_error: 2891.322698008845
#
# debug - iteration: 149
# debug - root_mean_square_error: 2871.2656866500724
#
# debug - iteration: 150
# debug - root_mean_square_error: 2851.5919915074883
#
# debug - iteration: 151
# debug - root_mean_square_error: 2832.5795621305665
#
# debug - iteration: 152
# debug - root_mean_square_error: 2813.150678035169
#
# debug - iteration: 153
# debug - root_mean_square_error: 2794.168874346941
#
# debug - iteration: 154
# debug - root_mean_square_error: 2774.36425822967
#
# debug - iteration: 155
# debug - root_mean_square_error: 2756.3726760143377
#
# debug - iteration: 156
# debug - root_mean_square_error: 2736.8476451352717
#
# debug - iteration: 157
# debug - root_mean_square_error: 2717.944697151397
#
# debug - iteration: 158
# debug - root_mean_square_error: 2698.8920526423
#
# debug - iteration: 159
# debug - root_mean_square_error: 2679.986536072202
#
# debug - iteration: 160
# debug - root_mean_square_error: 2662.4553878052234
#
# debug - iteration: 161
# debug - root_mean_square_error: 2644.868359161028
#
# debug - iteration: 162
# debug - root_mean_square_error: 2626.848769417559
#
# debug - iteration: 163
# debug - root_mean_square_error: 2609.912404031624
#
# debug - iteration: 164
# debug - root_mean_square_error: 2592.5428227348098
#
# debug - iteration: 165
# debug - root_mean_square_error: 2574.7736325542796
#
# debug - iteration: 166
# debug - root_mean_square_error: 2558.129648923884
#
# debug - iteration: 167
# debug - root_mean_square_error: 2542.364711543308
#
# debug - iteration: 168
# debug - root_mean_square_error: 2526.3910946143724
#
# debug - iteration: 169
# debug - root_mean_square_error: 2510.088558455166
#
# debug - iteration: 170
# debug - root_mean_square_error: 2494.180004960558
#
# debug - iteration: 171
# debug - root_mean_square_error: 2478.0647517101465
#
# debug - iteration: 172
# debug - root_mean_square_error: 2462.875596615871
#
# debug - iteration: 173
# debug - root_mean_square_error: 2447.3196021890103
#
# debug - iteration: 174
# debug - root_mean_square_error: 2432.2103814008424
#
# debug - iteration: 175
# debug - root_mean_square_error: 2417.8713475084564
#
# debug - iteration: 176
# debug - root_mean_square_error: 2403.0357740838595
#
# debug - iteration: 177
# debug - root_mean_square_error: 2387.803390143588
#
# debug - iteration: 178
# debug - root_mean_square_error: 2372.5435735442957
#
# debug - iteration: 179
# debug - root_mean_square_error: 2358.0341983135368
#
# debug - iteration: 180
# debug - root_mean_square_error: 2343.9754181047156
#
# debug - iteration: 181
# debug - root_mean_square_error: 2329.4979627216526
#
# debug - iteration: 182
# debug - root_mean_square_error: 2314.8933656548393
#
# debug - iteration: 183
# debug - root_mean_square_error: 2300.873489051601
#
# debug - iteration: 184
# debug - root_mean_square_error: 2287.6136134084736
#
# debug - iteration: 185
# debug - root_mean_square_error: 2273.696822520661
#
# debug - iteration: 186
# debug - root_mean_square_error: 2260.4957653051915
#
# debug - iteration: 187
# debug - root_mean_square_error: 2246.567556095223
#
# debug - iteration: 188
# debug - root_mean_square_error: 2233.4717867323607
#
# debug - iteration: 189
# debug - root_mean_square_error: 2220.4292862635853
#
# debug - iteration: 190
# debug - root_mean_square_error: 2207.368387312247
#
# debug - iteration: 191
# debug - root_mean_square_error: 2195.278459357026
#
# debug - iteration: 192
# debug - root_mean_square_error: 2183.1187617312394
#
# debug - iteration: 193
# debug - root_mean_square_error: 2169.392144948439
#
# debug - iteration: 194
# debug - root_mean_square_error: 2156.7688956850056
#
# debug - iteration: 195
# debug - root_mean_square_error: 2144.7161311523814
#
# debug - iteration: 196
# debug - root_mean_square_error: 2132.495679472998
#
# debug - iteration: 197
# debug - root_mean_square_error: 2120.079700676033
#
# debug - iteration: 198
# debug - root_mean_square_error: 2107.4396857762836
#
# debug - iteration: 199
# debug - root_mean_square_error: 2095.0058939722603
#
# debug - iteration: 200
# debug - root_mean_square_error: 2083.502579917178
#
# debug - iteration: 201
# debug - root_mean_square_error: 2071.971937017586
#
# debug - iteration: 202
# debug - root_mean_square_error: 2060.5936432736953
#
# debug - iteration: 203
# debug - root_mean_square_error: 2049.0393760643697
#
# debug - iteration: 204
# debug - root_mean_square_error: 2037.5111461316992
#
# debug - iteration: 205
# debug - root_mean_square_error: 2026.9321171029735
#
# debug - iteration: 206
# debug - root_mean_square_error: 2015.0296516741148
#
# debug - iteration: 207
# debug - root_mean_square_error: 2004.3113247370652
#
# debug - iteration: 208
# debug - root_mean_square_error: 1993.6082150290183
#
# debug - iteration: 209
# debug - root_mean_square_error: 1983.0242643401755
#
# debug - iteration: 210
# debug - root_mean_square_error: 1971.3678444612522
#
# debug - iteration: 211
# debug - root_mean_square_error: 1960.5782351333446
#
# debug - iteration: 212
# debug - root_mean_square_error: 1950.8134455775794
#
# debug - iteration: 213
# debug - root_mean_square_error: 1940.1383166270618
#
# debug - iteration: 214
# debug - root_mean_square_error: 1930.7771057086472
#
# debug - iteration: 215
# debug - root_mean_square_error: 1920.582876270245
#
# debug - iteration: 216
# debug - root_mean_square_error: 1910.1925699029937
#
# debug - iteration: 217
# debug - root_mean_square_error: 1900.3730560076267
#
# debug - iteration: 218
# debug - root_mean_square_error: 1890.2920374038758
#
# debug - iteration: 219
# debug - root_mean_square_error: 1880.68244677843
#
# debug - iteration: 220
# debug - root_mean_square_error: 1870.746251016476
#
# debug - iteration: 221
# debug - root_mean_square_error: 1861.9745144710969
#
# debug - iteration: 222
# debug - root_mean_square_error: 1852.6432812663622
#
# debug - iteration: 223
# debug - root_mean_square_error: 1843.490058003108
#
# debug - iteration: 224
# debug - root_mean_square_error: 1834.4701707537665
#
# debug - iteration: 225
# debug - root_mean_square_error: 1825.0764599850202
#
# debug - iteration: 226
# debug - root_mean_square_error: 1816.6345677361105
#
# debug - iteration: 227
# debug - root_mean_square_error: 1808.4934097342323
#
# debug - iteration: 228
# debug - root_mean_square_error: 1799.9336384915366
#
# debug - iteration: 229
# debug - root_mean_square_error: 1790.202221104589
#
# debug - iteration: 230
# debug - root_mean_square_error: 1781.1697270096063
#
# debug - iteration: 231
# debug - root_mean_square_error: 1772.2578668383571
#
# debug - iteration: 232
# debug - root_mean_square_error: 1763.771793200524
#
# debug - iteration: 233
# debug - root_mean_square_error: 1754.8176820998751
#
# debug - iteration: 234
# debug - root_mean_square_error: 1746.094996716991
#
# debug - iteration: 235
# debug - root_mean_square_error: 1738.2074339992398
#
# debug - iteration: 236
# debug - root_mean_square_error: 1730.3854775897557
#
# debug - iteration: 237
# debug - root_mean_square_error: 1722.7625496997803
#
# debug - iteration: 238
# debug - root_mean_square_error: 1714.9632096881364
#
# debug - iteration: 239
# debug - root_mean_square_error: 1706.9309824790282
#
# debug - iteration: 240
# debug - root_mean_square_error: 1700.2747068303504
#
# debug - iteration: 241
# debug - root_mean_square_error: 1693.2888233426559
#
# debug - iteration: 242
# debug - root_mean_square_error: 1685.4654071996222
#
# debug - iteration: 243
# debug - root_mean_square_error: 1678.0474311465898
#
# debug - iteration: 244
# debug - root_mean_square_error: 1670.2123124656036
#
# debug - iteration: 245
# debug - root_mean_square_error: 1663.0142181394847
#
# debug - iteration: 246
# debug - root_mean_square_error: 1656.0755447218405
#
# debug - iteration: 247
# debug - root_mean_square_error: 1649.708376652139
#
# debug - iteration: 248
# debug - root_mean_square_error: 1642.604757398291
#
# debug - iteration: 249
# debug - root_mean_square_error: 1635.6314824772376
#
# debug - iteration: 250
# debug - root_mean_square_error: 1628.499552067308
#
# debug - iteration: 251
# debug - root_mean_square_error: 1621.2556608043462
#
# debug - iteration: 252
# debug - root_mean_square_error: 1614.0748306734938
#
# debug - iteration: 253
# debug - root_mean_square_error: 1607.5860886741593
#
# debug - iteration: 254
# debug - root_mean_square_error: 1600.4806079939776
#
# debug - iteration: 255
# debug - root_mean_square_error: 1594.0679888884843
#
# debug - iteration: 256
# debug - root_mean_square_error: 1587.0687034379307
#
# debug - iteration: 257
# debug - root_mean_square_error: 1580.2685344206989
#
# debug - iteration: 258
# debug - root_mean_square_error: 1573.9005946477519
#
# debug - iteration: 259
# debug - root_mean_square_error: 1567.0909700809516
#
# debug - iteration: 260
# debug - root_mean_square_error: 1560.6493120741097
#
# debug - iteration: 261
# debug - root_mean_square_error: 1554.3558942552631
#
# debug - iteration: 262
# debug - root_mean_square_error: 1548.185027456382
#
# debug - iteration: 263
# debug - root_mean_square_error: 1542.5392792647785
#
# debug - iteration: 264
# debug - root_mean_square_error: 1536.0068173267168
#
# debug - iteration: 265
# debug - root_mean_square_error: 1529.4577689548728
#
# debug - iteration: 266
# debug - root_mean_square_error: 1523.672261903977
#
# debug - iteration: 267
# debug - root_mean_square_error: 1517.443543502203
#
# debug - iteration: 268
# debug - root_mean_square_error: 1511.0409849197652
#
# debug - iteration: 269
# debug - root_mean_square_error: 1505.2391131822676
#
# debug - iteration: 270
# debug - root_mean_square_error: 1499.2829556915685
#
# debug - iteration: 271
# debug - root_mean_square_error: 1493.6982038573644
#
# debug - iteration: 272
# debug - root_mean_square_error: 1487.8950616851628
#
# debug - iteration: 273
# debug - root_mean_square_error: 1482.4114342555906
#
# debug - iteration: 274
# debug - root_mean_square_error: 1476.6134394457463
#
# debug - iteration: 275
# debug - root_mean_square_error: 1471.26159441152
#
# debug - iteration: 276
# debug - root_mean_square_error: 1465.7203039648414
#
# debug - iteration: 277
# debug - root_mean_square_error: 1460.5848307612396
#
# debug - iteration: 278
# debug - root_mean_square_error: 1454.1596538300548
#
# debug - iteration: 279
# debug - root_mean_square_error: 1449.2749945056207
#
# debug - iteration: 280
# debug - root_mean_square_error: 1443.859571879026
#
# debug - iteration: 281
# debug - root_mean_square_error: 1439.0719756322771
#
# debug - iteration: 282
# debug - root_mean_square_error: 1433.8372300715705
#
# debug - iteration: 283
# debug - root_mean_square_error: 1429.1727571593044
#
# debug - iteration: 284
# debug - root_mean_square_error: 1424.6411571767624
#
# debug - iteration: 285
# debug - root_mean_square_error: 1419.348842813169
#
# debug - iteration: 286
# debug - root_mean_square_error: 1414.4649917603276
#
# debug - iteration: 287
# debug - root_mean_square_error: 1409.0201942183407
#
# debug - iteration: 288
# debug - root_mean_square_error: 1404.3279592073081
#
# debug - iteration: 289
# debug - root_mean_square_error: 1399.5359746639838
#
# debug - iteration: 290
# debug - root_mean_square_error: 1394.4009463207426
#
# debug - iteration: 291
# debug - root_mean_square_error: 1389.728223212841
#
# debug - iteration: 292
# debug - root_mean_square_error: 1385.075561325216
#
# debug - iteration: 293
# debug - root_mean_square_error: 1380.3545299922168
#
# debug - iteration: 294
# debug - root_mean_square_error: 1375.2291846934247
#
# debug - iteration: 295
# debug - root_mean_square_error: 1370.6095515975246
#
# debug - iteration: 296
# debug - root_mean_square_error: 1365.781481867285
#
# debug - iteration: 297
# debug - root_mean_square_error: 1361.5727455337706
#
# debug - iteration: 298
# debug - root_mean_square_error: 1357.311040852762
#
# debug - iteration: 299
# debug - root_mean_square_error: 1352.5569762840366
#
# debug - iteration: 300
# debug - root_mean_square_error: 1348.4273113931663
#
# debug - iteration: 301
# debug - root_mean_square_error: 1343.9792144504697
#
# debug - iteration: 302
# debug - root_mean_square_error: 1339.3553525947152
#
# debug - iteration: 303
# debug - root_mean_square_error: 1334.8343888147654
#
# debug - iteration: 304
# debug - root_mean_square_error: 1330.3651961244204
#
# debug - iteration: 305
# debug - root_mean_square_error: 1325.8923633513914
#
# debug - iteration: 306
# debug - root_mean_square_error: 1321.4945921070469
#
# debug - iteration: 307
# debug - root_mean_square_error: 1317.72698681643
#
# debug - iteration: 308
# debug - root_mean_square_error: 1313.7391945254592
#
# debug - iteration: 309
# debug - root_mean_square_error: 1309.5018269201603
#
# debug - iteration: 310
# debug - root_mean_square_error: 1305.3018661636916
#
# debug - iteration: 311
# debug - root_mean_square_error: 1301.389168650006
#
# debug - iteration: 312
# debug - root_mean_square_error: 1297.4235111618068
#
# debug - iteration: 313
# debug - root_mean_square_error: 1293.7430398202066
#
# debug - iteration: 314
# debug - root_mean_square_error: 1290.2441058379911
#
# debug - iteration: 315
# debug - root_mean_square_error: 1286.7853032511746
#
# debug - iteration: 316
# debug - root_mean_square_error: 1283.424066926499
#
# debug - iteration: 317
# debug - root_mean_square_error: 1279.6743922312944
#
# debug - iteration: 318
# debug - root_mean_square_error: 1275.581543415611
#
# debug - iteration: 319
# debug - root_mean_square_error: 1271.1305752996218
#
# debug - iteration: 320
# debug - root_mean_square_error: 1267.4353376737008
#
# debug - iteration: 321
# debug - root_mean_square_error: 1263.9107720218167
#
# debug - iteration: 322
# debug - root_mean_square_error: 1260.9012373254695
#
# debug - iteration: 323
# debug - root_mean_square_error: 1257.7508749987476
#
# debug - iteration: 324
# debug - root_mean_square_error: 1254.1326667093874
#
# debug - iteration: 325
# debug - root_mean_square_error: 1250.2115166419305
#
# debug - iteration: 326
# debug - root_mean_square_error: 1247.186572759962
#
# debug - iteration: 327
# debug - root_mean_square_error: 1243.698612599179
#
# debug - iteration: 328
# debug - root_mean_square_error: 1240.5378123653898
#
# debug - iteration: 329
# debug - root_mean_square_error: 1237.423951237386
#
# debug - iteration: 330
# debug - root_mean_square_error: 1233.7296096552052
#
# debug - iteration: 331
# debug - root_mean_square_error: 1230.7508321616654
#
# debug - iteration: 332
# debug - root_mean_square_error: 1227.8996173057938
#
# debug - iteration: 333
# debug - root_mean_square_error: 1225.0010568853354
#
# debug - iteration: 334
# debug - root_mean_square_error: 1221.8278713713048
#
# debug - iteration: 335
# debug - root_mean_square_error: 1218.6501059418495
#
# debug - iteration: 336
# debug - root_mean_square_error: 1215.9226416116533
#
# debug - iteration: 337
# debug - root_mean_square_error: 1212.9905932578645
#
# debug - iteration: 338
# debug - root_mean_square_error: 1209.4286948768222
#
# debug - iteration: 339
# debug - root_mean_square_error: 1206.576684132515
#
# debug - iteration: 340
# debug - root_mean_square_error: 1203.477757209673
#
# debug - iteration: 341
# debug - root_mean_square_error: 1200.5387582334201
#
# debug - iteration: 342
# debug - root_mean_square_error: 1197.2992756612102
#
# debug - iteration: 343
# debug - root_mean_square_error: 1194.019061254794
#
# debug - iteration: 344
# debug - root_mean_square_error: 1191.0099140125883
#
# debug - iteration: 345
# debug - root_mean_square_error: 1188.226387228121
#
# debug - iteration: 346
# debug - root_mean_square_error: 1185.4771043515725
#
# debug - iteration: 347
# debug - root_mean_square_error: 1182.5922348135764
#
# debug - iteration: 348
# debug - root_mean_square_error: 1179.7524553487597
#
# debug - iteration: 349
# debug - root_mean_square_error: 1176.9251057593267
#
# debug - iteration: 350
# debug - root_mean_square_error: 1174.1116676028307
#
# debug - iteration: 351
# debug - root_mean_square_error: 1171.8117020909149
#
# debug - iteration: 352
# debug - root_mean_square_error: 1169.2278334060359
#
# debug - iteration: 353
# debug - root_mean_square_error: 1165.95955775223
#
# debug - iteration: 354
# debug - root_mean_square_error: 1163.7199333989154
#
# debug - iteration: 355
# debug - root_mean_square_error: 1161.3158448942886
#
# debug - iteration: 356
# debug - root_mean_square_error: 1158.658042185932
#
# debug - iteration: 357
# debug - root_mean_square_error: 1156.5136843992038
#
# debug - iteration: 358
# debug - root_mean_square_error: 1153.4677990626692
#
# debug - iteration: 359
# debug - root_mean_square_error: 1151.257614688402
#
# debug - iteration: 360
# debug - root_mean_square_error: 1148.8949999214246
#
# debug - iteration: 361
# debug - root_mean_square_error: 1146.5608958521577
#
# debug - iteration: 362
# debug - root_mean_square_error: 1144.0154430055056
#
# debug - iteration: 363
# debug - root_mean_square_error: 1142.0243370599612
#
# debug - iteration: 364
# debug - root_mean_square_error: 1140.3182591715904
#
# debug - iteration: 365
# debug - root_mean_square_error: 1138.4370556788
#
# debug - iteration: 366
# debug - root_mean_square_error: 1135.9640640146254
#
# debug - iteration: 367
# debug - root_mean_square_error: 1134.1348662500372
#
# debug - iteration: 368
# debug - root_mean_square_error: 1132.0550939913282
#
# debug - iteration: 369
# debug - root_mean_square_error: 1129.9284096338745
#
# debug - iteration: 370
# debug - root_mean_square_error: 1127.8762049649745
#
# debug - iteration: 371
# debug - root_mean_square_error: 1126.2151435682845
#
# debug - iteration: 372
# debug - root_mean_square_error: 1124.2991705364282
#
# debug - iteration: 373
# debug - root_mean_square_error: 1122.0813781388076
#
# debug - iteration: 374
# debug - root_mean_square_error: 1120.3701060949065
#
# debug - iteration: 375
# debug - root_mean_square_error: 1118.1504795452543
#
# debug - iteration: 376
# debug - root_mean_square_error: 1116.1590096796388
#
# debug - iteration: 377
# debug - root_mean_square_error: 1114.400309701408
#
# debug - iteration: 378
# debug - root_mean_square_error: 1112.6542426172698
#
# debug - iteration: 379
# debug - root_mean_square_error: 1110.5450253044455
#
# debug - iteration: 380
# debug - root_mean_square_error: 1108.9189636973226
#
# debug - iteration: 381
# debug - root_mean_square_error: 1107.2761276168853
#
# debug - iteration: 382
# debug - root_mean_square_error: 1104.9334011806934
#
# debug - iteration: 383
# debug - root_mean_square_error: 1103.5613016078416
#
# debug - iteration: 384
# debug - root_mean_square_error: 1102.0065680352855
#
# debug - iteration: 385
# debug - root_mean_square_error: 1100.409318231188
#
# debug - iteration: 386
# debug - root_mean_square_error: 1099.1822036476092
#
# debug - iteration: 387
# debug - root_mean_square_error: 1097.484939532126
#
# debug - iteration: 388
# debug - root_mean_square_error: 1095.869695577765
#
# debug - iteration: 389
# debug - root_mean_square_error: 1094.5174899024585
#
# debug - iteration: 390
# debug - root_mean_square_error: 1092.8779996759024
#
# debug - iteration: 391
# debug - root_mean_square_error: 1091.4168215823047
#
# debug - iteration: 392
# debug - root_mean_square_error: 1090.2538162813046
#
# debug - iteration: 393
# debug - root_mean_square_error: 1088.6863228492086
#
# debug - iteration: 394
# debug - root_mean_square_error: 1086.835357046281
#
# debug - iteration: 395
# debug - root_mean_square_error: 1085.549761228097
#
# debug - iteration: 396
# debug - root_mean_square_error: 1084.3581280318629
#
# debug - iteration: 397
# debug - root_mean_square_error: 1082.898768894579
#
# debug - iteration: 398
# debug - root_mean_square_error: 1081.4656689227504
#
# debug - iteration: 399
# debug - root_mean_square_error: 1080.205554855765
#
# debug - iteration: 400
# debug - root_mean_square_error: 1078.8446449215733
#
# debug - iteration: 401
# debug - root_mean_square_error: 1077.7331174627425
#
# debug - iteration: 402
# debug - root_mean_square_error: 1076.5577257798468
#
# debug - iteration: 403
# debug - root_mean_square_error: 1074.9021973835295
#
# debug - iteration: 404
# debug - root_mean_square_error: 1073.6230024717522
#
# debug - iteration: 405
# debug - root_mean_square_error: 1072.2121536807729
#
# debug - iteration: 406
# debug - root_mean_square_error: 1071.1421772631845
#
# debug - iteration: 407
# debug - root_mean_square_error: 1070.096779108949
#
# debug - iteration: 408
# debug - root_mean_square_error: 1068.5495996204647
#
# debug - iteration: 409
# debug - root_mean_square_error: 1067.322843701076
#
# debug - iteration: 410
# debug - root_mean_square_error: 1066.8167685420615
#
# debug - iteration: 411
# debug - root_mean_square_error: 1065.773220996441
#
# debug - iteration: 412
# debug - root_mean_square_error: 1064.7052141191004
#
# debug - iteration: 413
# debug - root_mean_square_error: 1063.660259954658
#
# debug - iteration: 414
# debug - root_mean_square_error: 1062.9741729459045
#
# debug - iteration: 415
# debug - root_mean_square_error: 1061.4182070821544
#
# debug - iteration: 416
# debug - root_mean_square_error: 1060.3995053451724
#
# debug - iteration: 417
# debug - root_mean_square_error: 1059.6736906205838
#
# debug - iteration: 418
# debug - root_mean_square_error: 1058.9071217693786
#
# debug - iteration: 419
# debug - root_mean_square_error: 1057.995537188625
#
# debug - iteration: 420
# debug - root_mean_square_error: 1057.3540175405954
#
# debug - iteration: 421
# debug - root_mean_square_error: 1056.684667002036
#
# debug - iteration: 422
# debug - root_mean_square_error: 1056.1362501967253
#
# debug - iteration: 423
# debug - root_mean_square_error: 1055.3659207191129
#
# debug - iteration: 424
# debug - root_mean_square_error: 1054.27630205585
#
# debug - iteration: 425
# debug - root_mean_square_error: 1053.8716036611995
#
# debug - iteration: 426
# debug - root_mean_square_error: 1053.15757065159
#
# debug - iteration: 427
# debug - root_mean_square_error: 1052.8178760189369
#
# debug - iteration: 428
# debug - root_mean_square_error: 1052.0253616507423
#
# debug - iteration: 429
# debug - root_mean_square_error: 1051.3089554844844
#
# debug - iteration: 430
# debug - root_mean_square_error: 1050.682798648666
#
# debug - iteration: 431
# debug - root_mean_square_error: 1049.8874685999133
#
# debug - iteration: 432
# debug - root_mean_square_error: 1049.4325273890265
#
# debug - iteration: 433
# debug - root_mean_square_error: 1048.8233363231363
#
# debug - iteration: 434
# debug - root_mean_square_error: 1048.0799249696279
#
# debug - iteration: 435
# debug - root_mean_square_error: 1048.265770024326
#
# debug - iteration: 436
# debug - root_mean_square_error: 1047.6430013065662
#
# debug - iteration: 437
# debug - root_mean_square_error: 1047.559231714362
#
# debug - iteration: 438
# debug - root_mean_square_error: 1046.906676821353
#
# debug - iteration: 439
# debug - root_mean_square_error: 1046.043030734141
#
# debug - iteration: 440
# debug - root_mean_square_error: 1045.5984304527717
#
# debug - iteration: 441
# debug - root_mean_square_error: 1044.8971368419718
#
# debug - iteration: 442
# debug - root_mean_square_error: 1044.243622338252
#
# debug - iteration: 443
# debug - root_mean_square_error: 1043.6385041712533
#
# debug - iteration: 444
# debug - root_mean_square_error: 1042.7517759171164
#
# debug - iteration: 445
# debug - root_mean_square_error: 1042.1960250326006
#
# debug - iteration: 446
# debug - root_mean_square_error: 1041.8197495029497
#
# debug - iteration: 447
# debug - root_mean_square_error: 1041.8156157739425
#
# debug - iteration: 448
# debug - root_mean_square_error: 1041.4363336563297
#
# debug - iteration: 449
# debug - root_mean_square_error: 1041.0973180676003
#
# debug - iteration: 450
# debug - root_mean_square_error: 1040.6806860593194
#
# debug - iteration: 451
# debug - root_mean_square_error: 1040.5408358559357
#
# debug - iteration: 452
# debug - root_mean_square_error: 1040.2462846735032
#
# debug - iteration: 453
# debug - root_mean_square_error: 1039.6089590439199
#
# debug - iteration: 454
# debug - root_mean_square_error: 1039.6029196144905
#
# debug - iteration: 455
# debug - root_mean_square_error: 1039.9463031966413
#
# debug - iteration: 456
# debug - root_mean_square_error: 1039.979569921069
#
# debug - iteration: 457
# debug - root_mean_square_error: 1040.194651213517

# %%
model_analyzer_helper.plot_error_chart(root_mean_square_errors, bayseian_personalized_ranking_parameters)

# %%
latent_factor_matrix_dictionary = data_helper.load_latent_factor_matrix_dictionary()

# %%
data_helper = DataHelper()
bayseian_personalized_ranking_parameters = {
    'random_seed' : 1234, 
    'n_latent_factor' : 15, 
    'n_batch' : 1000, 
    'learning_rate' : 0.1, 
    'regularization_constant' : 0.1
}
bayseian_personalized_ranking_model = BayseianPersonalizedRankingModel(**bayseian_personalized_ranking_parameters)
model_analyzer_helper = ModelAnalyzerHelper()

vali_data_url = 'https://raw.githubusercontent.com/samohtwal/BPR/20221027/data/vali-20221026.csv'
vali_data_dictionary = data_helper.load_raw_data_dictionary(vali_data_url)

user_ids = vali_data_dictionary[data_group_by_user_id_dictionary_key][data_user_column_name].tolist()
user_id = np.random.choice(user_ids)
# n_best_recommendation = 100
lower_bound_score = 0.5
upper_bound_score = 1.5
best_recommendation = bayseian_personalized_ranking_model.recommend_user(training_data_dictionary, latent_factor_matrix_dictionary, user_id, lower_bound_score, upper_bound_score)

recommendation_data_dictionary = bayseian_personalized_ranking_model.recommend(vali_data_dictionary, training_data_dictionary, latent_factor_matrix_dictionary, lower_bound_score, upper_bound_score)

# %%
model_analyzer_helper = ModelAnalyzerHelper()
model_analyzer_helper.evaluate(vali_data_dictionary, recommendation_data_dictionary)
# Out:
# Streaming output truncated to the last 5000 lines.
# debug - n_true_positive: 2239
# debug - n_false_positive: 409034
# debug - n_true_negative: 8131996
# debug - n_false_negative: 18360
#
# debug - n_true_positive: 2241
# debug - n_false_positive: 409109
# debug - n_true_negative: 8134914
# debug - n_false_negative: 18362
#
# debug - n_true_positive: 2242
# debug - n_false_positive: 409166
# debug - n_true_negative: 8137848
# debug - n_false_negative: 18367
#
# debug - n_true_positive: 2242
# debug - n_false_positive: 409218
# debug - n_true_negative: 8140788
# debug - n_false_negative: 18373
#
# debug - n_true_positive: 2242
# debug - n_false_positive: 409465
# debug - n_true_negative: 8143539
# debug - n_false_negative: 18378
#
# debug - n_true_positive: 2242
# debug - n_false_positive: 409568
# debug - n_true_negative: 8146433
# debug - n_false_negative: 18380
#
# debug - n_true_positive: 2242
# debug - n_false_positive: 410118
# debug - n_true_negative: 8148896
# debug - n_false_negative: 18382
#
# debug - n_true_positive: 2243
# debug - n_false_positive: 410385
# debug - n_true_negative: 8151628
# debug - n_false_negative: 18382
#
# debug - n_true_positive: 2244
# debug - n_false_positive: 410531
# debug - n_true_negative: 8154474
# debug - n_false_negative: 18388
#
# debug - n_true_positive: 2247
# debug - n_false_positive: 410756
# debug - n_true_negative: 8157240
# debug - n_false_negative: 18392
#
# debug - n_true_positive: 2248
# debug - n_false_positive: 410909
# debug - n_true_negative: 8160080
# debug - n_false_negative: 18397
#
# debug - n_true_positive: 2248
# debug - n_false_positive: 411197
# debug - n_true_negative: 8162788
# debug - n_false_negative: 18401
#
# debug - n_true_positive: 2248
# debug - n_false_positive: 411225
# debug - n_true_negative: 8165752
# debug - n_false_negative: 18406
#
# debug - n_true_positive: 2248
# debug - n_false_positive: 411352
# debug - n_true_negative: 8168619
# debug - n_false_negative: 18409
#
# debug - n_true_positive: 2248
# debug - n_false_positive: 411465
# debug - n_true_negative: 8171503
# debug - n_false_negative: 18411
#
# debug - n_true_positive: 2248
# debug - n_false_positive: 411583
# debug - n_true_negative: 8174385
# debug - n_false_negative: 18412
#
# debug - n_true_positive: 2248
# debug - n_false_positive: 411646
# debug - n_true_negative: 8177316
# debug - n_false_negative: 18415
#
# debug - n_true_positive: 2249
# debug - n_false_positive: 411850
# debug - n_true_negative: 8180109
# debug - n_false_negative: 18418
#
# debug - n_true_positive: 2249
# debug - n_false_positive: 411950
# debug - n_true_negative: 8183001
# debug - n_false_negative: 18423
#
# debug - n_true_positive: 2249
# debug - n_false_positive: 411963
# debug - n_true_negative: 8185983
# debug - n_false_negative: 18425
#
# debug - n_true_positive: 2251
# debug - n_false_positive: 412198
# debug - n_true_negative: 8188737
# debug - n_false_negative: 18431
#
# debug - n_true_positive: 2252
# debug - n_false_positive: 412292
# debug - n_true_negative: 8191638
# debug - n_false_negative: 18433
#
# debug - n_true_positive: 2252
# debug - n_false_positive: 412429
# debug - n_true_negative: 8194495
# debug - n_false_negative: 18438
#
# debug - n_true_positive: 2252
# debug - n_false_positive: 412639
# debug - n_true_negative: 8197275
# debug - n_false_negative: 18445
#
# debug - n_true_positive: 2256
# debug - n_false_positive: 412907
# debug - n_true_negative: 8199999
# debug - n_false_negative: 18447
#
# debug - n_true_positive: 2256
# debug - n_false_positive: 413135
# debug - n_true_negative: 8202762
# debug - n_false_negative: 18453
#
# debug - n_true_positive: 2257
# debug - n_false_positive: 413262
# debug - n_true_negative: 8205625
# debug - n_false_negative: 18460
#
# debug - n_true_positive: 2259
# debug - n_false_positive: 413466
# debug - n_true_negative: 8208414
# debug - n_false_negative: 18465
#
# debug - n_true_positive: 2261
# debug - n_false_positive: 413743
# debug - n_true_negative: 8211135
# debug - n_false_negative: 18466
#
# debug - n_true_positive: 2261
# debug - n_false_positive: 413919
# debug - n_true_negative: 8213951
# debug - n_false_negative: 18471
#
# debug - n_true_positive: 2262
# debug - n_false_positive: 414090
# debug - n_true_negative: 8216777
# debug - n_false_negative: 18472
#
# debug - n_true_positive: 2264
# debug - n_false_positive: 414213
# debug - n_true_negative: 8219647
# debug - n_false_negative: 18474
#
# debug - n_true_positive: 2264
# debug - n_false_positive: 414372
# debug - n_true_negative: 8222482
# debug - n_false_negative: 18477
#
# debug - n_true_positive: 2264
# debug - n_false_positive: 414489
# debug - n_true_negative: 8225359
# debug - n_false_negative: 18481
#
# debug - n_true_positive: 2264
# debug - n_false_positive: 414662
# debug - n_true_negative: 8228183
# debug - n_false_negative: 18484
#
# debug - n_true_positive: 2264
# debug - n_false_positive: 414723
# debug - n_true_negative: 8231110
# debug - n_false_negative: 18493
#
# debug - n_true_positive: 2264
# debug - n_false_positive: 414813
# debug - n_true_negative: 8234015
# debug - n_false_negative: 18495
#
# debug - n_true_positive: 2265
# debug - n_false_positive: 414892
# debug - n_true_negative: 8236929
# debug - n_false_negative: 18498
#
# debug - n_true_positive: 2265
# debug - n_false_positive: 414921
# debug - n_true_negative: 8239896
# debug - n_false_negative: 18500
#
# debug - n_true_positive: 2265
# debug - n_false_positive: 415082
# debug - n_true_negative: 8242722
# debug - n_false_negative: 18513
#
# debug - n_true_positive: 2267
# debug - n_false_positive: 415315
# debug - n_true_negative: 8245482
# debug - n_false_negative: 18515
#
# debug - n_true_positive: 2270
# debug - n_false_positive: 415551
# debug - n_true_negative: 8248239
# debug - n_false_negative: 18517
#
# debug - n_true_positive: 2270
# debug - n_false_positive: 415778
# debug - n_true_negative: 8251008
# debug - n_false_negative: 18519
#
# debug - n_true_positive: 2270
# debug - n_false_positive: 415980
# debug - n_true_negative: 8253802
# debug - n_false_negative: 18523
#
# debug - n_true_positive: 2270
# debug - n_false_positive: 416082
# debug - n_true_negative: 8256694
# debug - n_false_negative: 18527
#
# debug - n_true_positive: 2270
# debug - n_false_positive: 416332
# debug - n_true_negative: 8259442
# debug - n_false_negative: 18532
#
# debug - n_true_positive: 2271
# debug - n_false_positive: 416578
# debug - n_true_negative: 8262189
# debug - n_false_negative: 18537
#
# debug - n_true_positive: 2271
# debug - n_false_positive: 416786
# debug - n_true_negative: 8264977
# debug - n_false_negative: 18540
#
# debug - n_true_positive: 2271
# debug - n_false_positive: 416834
# debug - n_true_negative: 8267928
# debug - n_false_negative: 18541
#
# debug - n_true_positive: 2271
# debug - n_false_positive: 417108
# debug - n_true_negative: 8270653
# debug - n_false_negative: 18551
#
# debug - n_true_positive: 2272
# debug - n_false_positive: 417355
# debug - n_true_negative: 8273404
# debug - n_false_negative: 18552
#
# debug - n_true_positive: 2273
# debug - n_false_positive: 417408
# debug - n_true_negative: 8276345
# debug - n_false_negative: 18555
#
# debug - n_true_positive: 2273
# debug - n_false_positive: 417475
# debug - n_true_negative: 8279268
# debug - n_false_negative: 18562
#
# debug - n_true_positive: 2273
# debug - n_false_positive: 417629
# debug - n_true_negative: 8282110
# debug - n_false_negative: 18564
#
# debug - n_true_positive: 2273
# debug - n_false_positive: 417796
# debug - n_true_negative: 8284942
# debug - n_false_negative: 18566
#
# debug - n_true_positive: 2273
# debug - n_false_positive: 417887
# debug - n_true_negative: 8287848
# debug - n_false_negative: 18567
#
# debug - n_true_positive: 2274
# debug - n_false_positive: 418024
# debug - n_true_negative: 8290702
# debug - n_false_negative: 18574
#
# debug - n_true_positive: 2274
# debug - n_false_positive: 418167
# debug - n_true_negative: 8293553
# debug - n_false_negative: 18579
#
# debug - n_true_positive: 2274
# debug - n_false_positive: 418313
# debug - n_true_negative: 8296406
# debug - n_false_negative: 18581
#
# debug - n_true_positive: 2275
# debug - n_false_positive: 418583
# debug - n_true_negative: 8299129
# debug - n_false_negative: 18585
#
# debug - n_true_positive: 2276
# debug - n_false_positive: 418622
# debug - n_true_negative: 8302075
# debug - n_false_negative: 18596
#
# debug - n_true_positive: 2276
# debug - n_false_positive: 418767
# debug - n_true_negative: 8304924
# debug - n_false_negative: 18599
#
# debug - n_true_positive: 2277
# debug - n_false_positive: 419000
# debug - n_true_negative: 8307686
# debug - n_false_negative: 18601
#
# debug - n_true_positive: 2280
# debug - n_false_positive: 419098
# debug - n_true_negative: 8310580
# debug - n_false_negative: 18604
#
# debug - n_true_positive: 2280
# debug - n_false_positive: 419131
# debug - n_true_negative: 8313538
# debug - n_false_negative: 18610
#
# debug - n_true_positive: 2280
# debug - n_false_positive: 419279
# debug - n_true_negative: 8316385
# debug - n_false_negative: 18614
#
# debug - n_true_positive: 2280
# debug - n_false_positive: 419406
# debug - n_true_negative: 8319253
# debug - n_false_negative: 18616
#
# debug - n_true_positive: 2280
# debug - n_false_positive: 419482
# debug - n_true_negative: 8322173
# debug - n_false_negative: 18619
#
# debug - n_true_positive: 2281
# debug - n_false_positive: 419513
# debug - n_true_negative: 8325124
# debug - n_false_negative: 18633
#
# debug - n_true_positive: 2281
# debug - n_false_positive: 419546
# debug - n_true_negative: 8328088
# debug - n_false_negative: 18635
#
# debug - n_true_positive: 2283
# debug - n_false_positive: 419657
# debug - n_true_negative: 8330969
# debug - n_false_negative: 18640
#
# debug - n_true_positive: 2283
# debug - n_false_positive: 420075
# debug - n_true_negative: 8333556
# debug - n_false_negative: 18645
#
# debug - n_true_positive: 2287
# debug - n_false_positive: 420333
# debug - n_true_negative: 8336282
# debug - n_false_negative: 18656
#
# debug - n_true_positive: 2287
# debug - n_false_positive: 420343
# debug - n_true_negative: 8339263
# debug - n_false_negative: 18662
#
# debug - n_true_positive: 2288
# debug - n_false_positive: 420554
# debug - n_true_negative: 8342044
# debug - n_false_negative: 18667
#
# debug - n_true_positive: 2289
# debug - n_false_positive: 420820
# debug - n_true_negative: 8344771
# debug - n_false_negative: 18671
#
# debug - n_true_positive: 2289
# debug - n_false_positive: 420855
# debug - n_true_negative: 8347729
# debug - n_false_negative: 18675
#
# debug - n_true_positive: 2291
# debug - n_false_positive: 421089
# debug - n_true_negative: 8350486
# debug - n_false_negative: 18679
#
# debug - n_true_positive: 2293
# debug - n_false_positive: 421254
# debug - n_true_negative: 8353315
# debug - n_false_negative: 18683
#
# debug - n_true_positive: 2294
# debug - n_false_positive: 421348
# debug - n_true_negative: 8356216
# debug - n_false_negative: 18684
#
# debug - n_true_positive: 2294
# debug - n_false_positive: 421491
# debug - n_true_negative: 8359069
# debug - n_false_negative: 18687
#
# debug - n_true_positive: 2294
# debug - n_false_positive: 421525
# debug - n_true_negative: 8362023
# debug - n_false_negative: 18697
#
# debug - n_true_positive: 2294
# debug - n_false_positive: 421621
# debug - n_true_negative: 8364917
# debug - n_false_negative: 18704
#
# debug - n_true_positive: 2295
# debug - n_false_positive: 421659
# debug - n_true_negative: 8367874
# debug - n_false_negative: 18706
#
# debug - n_true_positive: 2295
# debug - n_false_positive: 421768
# debug - n_true_negative: 8370756
# debug - n_false_negative: 18714
#
# debug - n_true_positive: 2295
# debug - n_false_positive: 421898
# debug - n_true_negative: 8373619
# debug - n_false_negative: 18720
#
# debug - n_true_positive: 2295
# debug - n_false_positive: 421925
# debug - n_true_negative: 8376581
# debug - n_false_negative: 18728
#
# debug - n_true_positive: 2295
# debug - n_false_positive: 422142
# debug - n_true_negative: 8379360
# debug - n_false_negative: 18731
#
# debug - n_true_positive: 2295
# debug - n_false_positive: 422415
# debug - n_true_negative: 8382090
# debug - n_false_negative: 18733
#
# debug - n_true_positive: 2295
# debug - n_false_positive: 422702
# debug - n_true_negative: 8384798
# debug - n_false_negative: 18736
#
# debug - n_true_positive: 2296
# debug - n_false_positive: 422820
# debug - n_true_negative: 8387675
# debug - n_false_negative: 18738
#
# debug - n_true_positive: 2296
# debug - n_false_positive: 422974
# debug - n_true_negative: 8390515
# debug - n_false_negative: 18743
#
# debug - n_true_positive: 2296
# debug - n_false_positive: 423042
# debug - n_true_negative: 8393438
# debug - n_false_negative: 18750
#
# debug - n_true_positive: 2297
# debug - n_false_positive: 423168
# debug - n_true_negative: 8396309
# debug - n_false_negative: 18752
#
# debug - n_true_positive: 2297
# debug - n_false_positive: 423273
# debug - n_true_negative: 8399198
# debug - n_false_negative: 18756
#
# debug - n_true_positive: 2300
# debug - n_false_positive: 423424
# debug - n_true_negative: 8402039
# debug - n_false_negative: 18759
#
# debug - n_true_positive: 2300
# debug - n_false_positive: 423579
# debug - n_true_negative: 8404877
# debug - n_false_negative: 18763
#
# debug - n_true_positive: 2300
# debug - n_false_positive: 423598
# debug - n_true_negative: 8407854
# debug - n_false_negative: 18765
#
# debug - n_true_positive: 2300
# debug - n_false_positive: 423767
# debug - n_true_negative: 8410683
# debug - n_false_negative: 18768
#
# debug - n_true_positive: 2300
# debug - n_false_positive: 423789
# debug - n_true_negative: 8413655
# debug - n_false_negative: 18772
#
# debug - n_true_positive: 2300
# debug - n_false_positive: 423794
# debug - n_true_negative: 8416642
# debug - n_false_negative: 18777
#
# debug - n_true_positive: 2300
# debug - n_false_positive: 423928
# debug - n_true_negative: 8419500
# debug - n_false_negative: 18782
#
# debug - n_true_positive: 2300
# debug - n_false_positive: 424187
# debug - n_true_negative: 8422234
# debug - n_false_negative: 18787
#
# debug - n_true_positive: 2300
# debug - n_false_positive: 424346
# debug - n_true_negative: 8425069
# debug - n_false_negative: 18792
#
# debug - n_true_positive: 2302
# debug - n_false_positive: 424575
# debug - n_true_negative: 8427833
# debug - n_false_negative: 18794
#
# debug - n_true_positive: 2302
# debug - n_false_positive: 424637
# debug - n_true_negative: 8430762
# debug - n_false_negative: 18800
#
# debug - n_true_positive: 2302
# debug - n_false_positive: 424713
# debug - n_true_negative: 8433677
# debug - n_false_negative: 18806
#
# debug - n_true_positive: 2303
# debug - n_false_positive: 424871
# debug - n_true_negative: 8436513
# debug - n_false_negative: 18810
#
# debug - n_true_positive: 2309
# debug - n_false_positive: 425178
# debug - n_true_negative: 8439188
# debug - n_false_negative: 18819
#
# debug - n_true_positive: 2313
# debug - n_false_positive: 425383
# debug - n_true_negative: 8441966
# debug - n_false_negative: 18830
#
# debug - n_true_positive: 2313
# debug - n_false_positive: 425586
# debug - n_true_negative: 8444758
# debug - n_false_negative: 18835
#
# debug - n_true_positive: 2313
# debug - n_false_positive: 425599
# debug - n_true_negative: 8447738
# debug - n_false_negative: 18839
#
# debug - n_true_positive: 2313
# debug - n_false_positive: 425797
# debug - n_true_negative: 8450535
# debug - n_false_negative: 18842
#
# debug - n_true_positive: 2314
# debug - n_false_positive: 426008
# debug - n_true_negative: 8453324
# debug - n_false_negative: 18844
#
# debug - n_true_positive: 2316
# debug - n_false_positive: 426327
# debug - n_true_negative: 8456002
# debug - n_false_negative: 18845
#
# debug - n_true_positive: 2317
# debug - n_false_positive: 426457
# debug - n_true_negative: 8458861
# debug - n_false_negative: 18853
#
# debug - n_true_positive: 2317
# debug - n_false_positive: 426474
# debug - n_true_negative: 8461837
# debug - n_false_negative: 18857
#
# debug - n_true_positive: 2317
# debug - n_false_positive: 426695
# debug - n_true_negative: 8464611
# debug - n_false_negative: 18859
#
# debug - n_true_positive: 2317
# debug - n_false_positive: 426888
# debug - n_true_negative: 8467412
# debug - n_false_negative: 18862
#
# debug - n_true_positive: 2317
# debug - n_false_positive: 426978
# debug - n_true_negative: 8470311
# debug - n_false_negative: 18870
#
# debug - n_true_positive: 2319
# debug - n_false_positive: 427287
# debug - n_true_negative: 8472988
# debug - n_false_negative: 18880
#
# debug - n_true_positive: 2319
# debug - n_false_positive: 427336
# debug - n_true_negative: 8475933
# debug - n_false_negative: 18883
#
# debug - n_true_positive: 2319
# debug - n_false_positive: 427394
# debug - n_true_negative: 8478872
# debug - n_false_negative: 18885
#
# debug - n_true_positive: 2321
# debug - n_false_positive: 427582
# debug - n_true_negative: 8481661
# debug - n_false_negative: 18903
#
# debug - n_true_positive: 2321
# debug - n_false_positive: 427743
# debug - n_true_negative: 8484499
# debug - n_false_negative: 18906
#
# debug - n_true_positive: 2321
# debug - n_false_positive: 427836
# debug - n_true_negative: 8487403
# debug - n_false_negative: 18909
#
# debug - n_true_positive: 2326
# debug - n_false_positive: 428028
# debug - n_true_negative: 8490185
# debug - n_false_negative: 18929
#
# debug - n_true_positive: 2326
# debug - n_false_positive: 428103
# debug - n_true_negative: 8493105
# debug - n_false_negative: 18931
#
# debug - n_true_positive: 2328
# debug - n_false_positive: 428286
# debug - n_true_negative: 8495914
# debug - n_false_negative: 18936
#
# debug - n_true_positive: 2329
# debug - n_false_positive: 428425
# debug - n_true_negative: 8498766
# debug - n_false_negative: 18944
#
# debug - n_true_positive: 2329
# debug - n_false_positive: 428462
# debug - n_true_negative: 8501724
# debug - n_false_negative: 18946
#
# debug - n_true_positive: 2330
# debug - n_false_positive: 428582
# debug - n_true_negative: 8504599
# debug - n_false_negative: 18949
#
# debug - n_true_positive: 2330
# debug - n_false_positive: 428772
# debug - n_true_negative: 8507405
# debug - n_false_negative: 18953
#
# debug - n_true_positive: 2331
# debug - n_false_positive: 429035
# debug - n_true_negative: 8510142
# debug - n_false_negative: 18956
#
# debug - n_true_positive: 2332
# debug - n_false_positive: 429239
# debug - n_true_negative: 8512935
# debug - n_false_negative: 18958
#
# debug - n_true_positive: 2332
# debug - n_false_positive: 429327
# debug - n_true_negative: 8515843
# debug - n_false_negative: 18959
#
# debug - n_true_positive: 2332
# debug - n_false_positive: 429402
# debug - n_true_negative: 8518763
# debug - n_false_negative: 18961
#
# debug - n_true_positive: 2332
# debug - n_false_positive: 429410
# debug - n_true_negative: 8521737
# debug - n_false_negative: 18976
#
# debug - n_true_positive: 2332
# debug - n_false_positive: 429474
# debug - n_true_negative: 8524656
# debug - n_false_negative: 18991
#
# debug - n_true_positive: 2332
# debug - n_false_positive: 429528
# debug - n_true_negative: 8527593
# debug - n_false_negative: 18997
#
# debug - n_true_positive: 2335
# debug - n_false_positive: 429744
# debug - n_true_negative: 8530367
# debug - n_false_negative: 19003
#
# debug - n_true_positive: 2336
# debug - n_false_positive: 429934
# debug - n_true_negative: 8533172
# debug - n_false_negative: 19007
#
# debug - n_true_positive: 2336
# debug - n_false_positive: 430164
# debug - n_true_negative: 8535930
# debug - n_false_negative: 19016
#
# debug - n_true_positive: 2337
# debug - n_false_positive: 430357
# debug - n_true_negative: 8538733
# debug - n_false_negative: 19017
#
# debug - n_true_positive: 2337
# debug - n_false_positive: 430543
# debug - n_true_negative: 8541539
# debug - n_false_negative: 19025
#
# debug - n_true_positive: 2341
# debug - n_false_positive: 430820
# debug - n_true_negative: 8544249
# debug - n_false_negative: 19033
#
# debug - n_true_positive: 2341
# debug - n_false_positive: 430916
# debug - n_true_negative: 8547142
# debug - n_false_negative: 19041
#
# debug - n_true_positive: 2341
# debug - n_false_positive: 430949
# debug - n_true_negative: 8550098
# debug - n_false_negative: 19049
#
# debug - n_true_positive: 2341
# debug - n_false_positive: 431211
# debug - n_true_negative: 8552833
# debug - n_false_negative: 19052
#
# debug - n_true_positive: 2341
# debug - n_false_positive: 431291
# debug - n_true_negative: 8555745
# debug - n_false_negative: 19057
#
# debug - n_true_positive: 2341
# debug - n_false_positive: 431392
# debug - n_true_negative: 8558642
# debug - n_false_negative: 19059
#
# debug - n_true_positive: 2342
# debug - n_false_positive: 431499
# debug - n_true_negative: 8561516
# debug - n_false_negative: 19075
#
# debug - n_true_positive: 2342
# debug - n_false_positive: 431563
# debug - n_true_negative: 8564445
# debug - n_false_negative: 19080
#
# debug - n_true_positive: 2343
# debug - n_false_positive: 431756
# debug - n_true_negative: 8567244
# debug - n_false_negative: 19086
#
# debug - n_true_positive: 2343
# debug - n_false_positive: 431948
# debug - n_true_negative: 8570047
# debug - n_false_negative: 19089
#
# debug - n_true_positive: 2344
# debug - n_false_positive: 432127
# debug - n_true_negative: 8572862
# debug - n_false_negative: 19091
#
# debug - n_true_positive: 2345
# debug - n_false_positive: 432280
# debug - n_true_negative: 8575704
# debug - n_false_negative: 19093
#
# debug - n_true_positive: 2345
# debug - n_false_positive: 432486
# debug - n_true_negative: 8578490
# debug - n_false_negative: 19101
#
# debug - n_true_positive: 2345
# debug - n_false_positive: 432683
# debug - n_true_negative: 8581292
# debug - n_false_negative: 19102
#
# debug - n_true_positive: 2345
# debug - n_false_positive: 433210
# debug - n_true_negative: 8583778
# debug - n_false_negative: 19104
#
# debug - n_true_positive: 2347
# debug - n_false_positive: 433429
# debug - n_true_negative: 8586555
# debug - n_false_negative: 19107
#
# debug - n_true_positive: 2347
# debug - n_false_positive: 433662
# debug - n_true_negative: 8589317
# debug - n_false_negative: 19114
#
# debug - n_true_positive: 2347
# debug - n_false_positive: 433720
# debug - n_true_negative: 8592249
# debug - n_false_negative: 19125
#
# debug - n_true_positive: 2347
# debug - n_false_positive: 433777
# debug - n_true_negative: 8595184
# debug - n_false_negative: 19130
#
# debug - n_true_positive: 2347
# debug - n_false_positive: 433966
# debug - n_true_negative: 8597988
# debug - n_false_negative: 19135
#
# debug - n_true_positive: 2347
# debug - n_false_positive: 434172
# debug - n_true_negative: 8600777
# debug - n_false_negative: 19137
#
# debug - n_true_positive: 2347
# debug - n_false_positive: 434323
# debug - n_true_negative: 8603620
# debug - n_false_negative: 19141
#
# debug - n_true_positive: 2351
# debug - n_false_positive: 434598
# debug - n_true_negative: 8606335
# debug - n_false_negative: 19144
#
# debug - n_true_positive: 2351
# debug - n_false_positive: 434783
# debug - n_true_negative: 8609147
# debug - n_false_negative: 19148
#
# debug - n_true_positive: 2351
# debug - n_false_positive: 434991
# debug - n_true_negative: 8611935
# debug - n_false_negative: 19150
#
# debug - n_true_positive: 2351
# debug - n_false_positive: 435162
# debug - n_true_negative: 8614761
# debug - n_false_negative: 19152
#
# debug - n_true_positive: 2351
# debug - n_false_positive: 435375
# debug - n_true_negative: 8617548
# debug - n_false_negative: 19153
#
# debug - n_true_positive: 2354
# debug - n_false_positive: 435533
# debug - n_true_negative: 8620362
# debug - n_false_negative: 19175
#
# debug - n_true_positive: 2354
# debug - n_false_positive: 435761
# debug - n_true_negative: 8623134
# debug - n_false_negative: 19177
#
# debug - n_true_positive: 2354
# debug - n_false_positive: 435780
# debug - n_true_negative: 8626111
# debug - n_false_negative: 19178
#
# debug - n_true_positive: 2354
# debug - n_false_positive: 435816
# debug - n_true_negative: 8629067
# debug - n_false_negative: 19184
#
# debug - n_true_positive: 2354
# debug - n_false_positive: 435932
# debug - n_true_negative: 8631949
# debug - n_false_negative: 19187
#
# debug - n_true_positive: 2355
# debug - n_false_positive: 436086
# debug - n_true_negative: 8634789
# debug - n_false_negative: 19189
#
# debug - n_true_positive: 2357
# debug - n_false_positive: 436328
# debug - n_true_negative: 8637543
# debug - n_false_negative: 19190
#
# debug - n_true_positive: 2357
# debug - n_false_positive: 436384
# debug - n_true_negative: 8640483
# debug - n_false_negative: 19193
#
# debug - n_true_positive: 2357
# debug - n_false_positive: 436478
# debug - n_true_negative: 8643387
# debug - n_false_negative: 19196
#
# debug - n_true_positive: 2357
# debug - n_false_positive: 436553
# debug - n_true_negative: 8646305
# debug - n_false_negative: 19202
#
# debug - n_true_positive: 2357
# debug - n_false_positive: 436773
# debug - n_true_negative: 8649079
# debug - n_false_negative: 19205
#
# debug - n_true_positive: 2357
# debug - n_false_positive: 436915
# debug - n_true_negative: 8651936
# debug - n_false_negative: 19207
#
# debug - n_true_positive: 2358
# debug - n_false_positive: 437140
# debug - n_true_negative: 8654700
# debug - n_false_negative: 19214
#
# debug - n_true_positive: 2358
# debug - n_false_positive: 437213
# debug - n_true_negative: 8657621
# debug - n_false_negative: 19219
#
# debug - n_true_positive: 2358
# debug - n_false_positive: 437602
# debug - n_true_negative: 8660236
# debug - n_false_negative: 19221
#
# debug - n_true_positive: 2358
# debug - n_false_positive: 437893
# debug - n_true_negative: 8662940
# debug - n_false_negative: 19224
#
# debug - n_true_positive: 2358
# debug - n_false_positive: 438131
# debug - n_true_negative: 8665698
# debug - n_false_negative: 19227
#
# debug - n_true_positive: 2358
# debug - n_false_positive: 438329
# debug - n_true_negative: 8668499
# debug - n_false_negative: 19231
#
# debug - n_true_positive: 2359
# debug - n_false_positive: 438480
# debug - n_true_negative: 8671344
# debug - n_false_negative: 19233
#
# debug - n_true_positive: 2359
# debug - n_false_positive: 438643
# debug - n_true_negative: 8674171
# debug - n_false_negative: 19242
#
# debug - n_true_positive: 2359
# debug - n_false_positive: 438950
# debug - n_true_negative: 8676859
# debug - n_false_negative: 19247
#
# debug - n_true_positive: 2359
# debug - n_false_positive: 438994
# debug - n_true_negative: 8679810
# debug - n_false_negative: 19249
#
# debug - n_true_positive: 2359
# debug - n_false_positive: 439253
# debug - n_true_negative: 8682546
# debug - n_false_negative: 19253
#
# debug - n_true_positive: 2359
# debug - n_false_positive: 439350
# debug - n_true_negative: 8685442
# debug - n_false_negative: 19257
#
# debug - n_true_positive: 2359
# debug - n_false_positive: 439549
# debug - n_true_negative: 8688240
# debug - n_false_negative: 19259
#
# debug - n_true_positive: 2359
# debug - n_false_positive: 439698
# debug - n_true_negative: 8691088
# debug - n_false_negative: 19263
#
# debug - n_true_positive: 2359
# debug - n_false_positive: 439933
# debug - n_true_negative: 8693847
# debug - n_false_negative: 19266
#
# debug - n_true_positive: 2359
# debug - n_false_positive: 440079
# debug - n_true_negative: 8696696
# debug - n_false_negative: 19270
#
# debug - n_true_positive: 2359
# debug - n_false_positive: 440255
# debug - n_true_negative: 8699515
# debug - n_false_negative: 19272
#
# debug - n_true_positive: 2360
# debug - n_false_positive: 440373
# debug - n_true_negative: 8702386
# debug - n_false_negative: 19279
#
# debug - n_true_positive: 2360
# debug - n_false_positive: 440515
# debug - n_true_negative: 8705238
# debug - n_false_negative: 19282
#
# debug - n_true_positive: 2360
# debug - n_false_positive: 440627
# debug - n_true_negative: 8708119
# debug - n_false_negative: 19289
#
# debug - n_true_positive: 2360
# debug - n_false_positive: 440797
# debug - n_true_negative: 8710945
# debug - n_false_negative: 19293
#
# debug - n_true_positive: 2362
# debug - n_false_positive: 440965
# debug - n_true_negative: 8713763
# debug - n_false_negative: 19303
#
# debug - n_true_positive: 2362
# debug - n_false_positive: 441021
# debug - n_true_negative: 8716703
# debug - n_false_negative: 19304
#
# debug - n_true_positive: 2362
# debug - n_false_positive: 441175
# debug - n_true_negative: 8719550
# debug - n_false_negative: 19305
#
# debug - n_true_positive: 2363
# debug - n_false_positive: 441343
# debug - n_true_negative: 8722376
# debug - n_false_negative: 19307
#
# debug - n_true_positive: 2364
# debug - n_false_positive: 441648
# debug - n_true_negative: 8725066
# debug - n_false_negative: 19311
#
# debug - n_true_positive: 2364
# debug - n_false_positive: 441873
# debug - n_true_negative: 8727842
# debug - n_false_negative: 19314
#
# debug - n_true_positive: 2364
# debug - n_false_positive: 442083
# debug - n_true_negative: 8730631
# debug - n_false_negative: 19318
#
# debug - n_true_positive: 2365
# debug - n_false_positive: 442141
# debug - n_true_negative: 8733561
# debug - n_false_negative: 19326
#
# debug - n_true_positive: 2365
# debug - n_false_positive: 442322
# debug - n_true_negative: 8736372
# debug - n_false_negative: 19331
#
# debug - n_true_positive: 2365
# debug - n_false_positive: 442421
# debug - n_true_negative: 8739270
# debug - n_false_negative: 19333
#
# debug - n_true_positive: 2365
# debug - n_false_positive: 442521
# debug - n_true_negative: 8742166
# debug - n_false_negative: 19335
#
# debug - n_true_positive: 2365
# debug - n_false_positive: 442690
# debug - n_true_negative: 8744987
# debug - n_false_negative: 19342
#
# debug - n_true_positive: 2365
# debug - n_false_positive: 442814
# debug - n_true_negative: 8747859
# debug - n_false_negative: 19344
#
# debug - n_true_positive: 2365
# debug - n_false_positive: 443094
# debug - n_true_negative: 8750577
# debug - n_false_negative: 19349
#
# debug - n_true_positive: 2366
# debug - n_false_positive: 443196
# debug - n_true_negative: 8753472
# debug - n_false_negative: 19351
#
# debug - n_true_positive: 2366
# debug - n_false_positive: 443269
# debug - n_true_negative: 8756397
# debug - n_false_negative: 19353
#
# debug - n_true_positive: 2366
# debug - n_false_positive: 443296
# debug - n_true_negative: 8759363
# debug - n_false_negative: 19357
#
# debug - n_true_positive: 2367
# debug - n_false_positive: 443368
# debug - n_true_negative: 8762275
# debug - n_false_negative: 19370
#
# debug - n_true_positive: 2367
# debug - n_false_positive: 443461
# debug - n_true_negative: 8765178
# debug - n_false_negative: 19373
#
# debug - n_true_positive: 2367
# debug - n_false_positive: 443601
# debug - n_true_negative: 8768026
# debug - n_false_negative: 19382
#
# debug - n_true_positive: 2368
# debug - n_false_positive: 443882
# debug - n_true_negative: 8770736
# debug - n_false_negative: 19396
#
# debug - n_true_positive: 2368
# debug - n_false_positive: 444092
# debug - n_true_negative: 8773518
# debug - n_false_negative: 19404
#
# debug - n_true_positive: 2368
# debug - n_false_positive: 444103
# debug - n_true_negative: 8776498
# debug - n_false_negative: 19410
#
# debug - n_true_positive: 2368
# debug - n_false_positive: 444240
# debug - n_true_negative: 8779356
# debug - n_false_negative: 19412
#
# debug - n_true_positive: 2368
# debug - n_false_positive: 444320
# debug - n_true_negative: 8782263
# debug - n_false_negative: 19422
#
# debug - n_true_positive: 2368
# debug - n_false_positive: 444486
# debug - n_true_negative: 8785092
# debug - n_false_negative: 19426
#
# debug - n_true_positive: 2372
# debug - n_false_positive: 444732
# debug - n_true_negative: 8787834
# debug - n_false_negative: 19431
#
# debug - n_true_positive: 2372
# debug - n_false_positive: 444827
# debug - n_true_negative: 8790727
# debug - n_false_negative: 19440
#
# debug - n_true_positive: 2372
# debug - n_false_positive: 445490
# debug - n_true_negative: 8793079
# debug - n_false_negative: 19441
#
# debug - n_true_positive: 2374
# debug - n_false_positive: 445815
# debug - n_true_negative: 8795747
# debug - n_false_negative: 19445
#
# debug - n_true_positive: 2374
# debug - n_false_positive: 445908
# debug - n_true_negative: 8798646
# debug - n_false_negative: 19450
#
# debug - n_true_positive: 2374
# debug - n_false_positive: 446020
# debug - n_true_negative: 8801527
# debug - n_false_negative: 19456
#
# debug - n_true_positive: 2374
# debug - n_false_positive: 446178
# debug - n_true_negative: 8804366
# debug - n_false_negative: 19460
#
# debug - n_true_positive: 2374
# debug - n_false_positive: 446268
# debug - n_true_negative: 8807272
# debug - n_false_negative: 19464
#
# debug - n_true_positive: 2374
# debug - n_false_positive: 446482
# debug - n_true_negative: 8810050
# debug - n_false_negative: 19473
#
# debug - n_true_positive: 2375
# debug - n_false_positive: 446628
# debug - n_true_negative: 8812899
# debug - n_false_negative: 19474
#
# debug - n_true_positive: 2375
# debug - n_false_positive: 446654
# debug - n_true_negative: 8815867
# debug - n_false_negative: 19477
#
# debug - n_true_positive: 2375
# debug - n_false_positive: 446684
# debug - n_true_negative: 8818829
# debug - n_false_negative: 19482
#
# debug - n_true_positive: 2375
# debug - n_false_positive: 446719
# debug - n_true_negative: 8821789
# debug - n_false_negative: 19484
#
# debug - n_true_positive: 2375
# debug - n_false_positive: 446806
# debug - n_true_negative: 8824697
# debug - n_false_negative: 19487
#
# debug - n_true_positive: 2377
# debug - n_false_positive: 447009
# debug - n_true_negative: 8827483
# debug - n_false_negative: 19495
#
# debug - n_true_positive: 2378
# debug - n_false_positive: 447169
# debug - n_true_negative: 8830308
# debug - n_false_negative: 19510
#
# debug - n_true_positive: 2378
# debug - n_false_positive: 447246
# debug - n_true_negative: 8833226
# debug - n_false_negative: 19512
#
# debug - n_true_positive: 2379
# debug - n_false_positive: 447540
# debug - n_true_negative: 8835931
# debug - n_false_negative: 19516
#
# debug - n_true_positive: 2379
# debug - n_false_positive: 447715
# debug - n_true_negative: 8838753
# debug - n_false_negative: 19517
#
# debug - n_true_positive: 2379
# debug - n_false_positive: 447797
# debug - n_true_negative: 8841661
# debug - n_false_negative: 19525
#
# debug - n_true_positive: 2380
# debug - n_false_positive: 447969
# debug - n_true_negative: 8844473
# debug - n_false_negative: 19538
#
# debug - n_true_positive: 2380
# debug - n_false_positive: 448136
# debug - n_true_negative: 8847295
# debug - n_false_negative: 19546
#
# debug - n_true_positive: 2380
# debug - n_false_positive: 448200
# debug - n_true_negative: 8850224
# debug - n_false_negative: 19551
#
# debug - n_true_positive: 2380
# debug - n_false_positive: 448242
# debug - n_true_negative: 8853172
# debug - n_false_negative: 19558
#
# debug - n_true_positive: 2380
# debug - n_false_positive: 448349
# debug - n_true_negative: 8856060
# debug - n_false_negative: 19561
#
# debug - n_true_positive: 2380
# debug - n_false_positive: 448492
# debug - n_true_negative: 8858915
# debug - n_false_negative: 19563
#
# debug - n_true_positive: 2380
# debug - n_false_positive: 448528
# debug - n_true_negative: 8861872
# debug - n_false_negative: 19567
#
# debug - n_true_positive: 2380
# debug - n_false_positive: 448542
# debug - n_true_negative: 8864844
# debug - n_false_negative: 19578
#
# debug - n_true_positive: 2380
# debug - n_false_positive: 448635
# debug - n_true_negative: 8867748
# debug - n_false_negative: 19579
#
# debug - n_true_positive: 2380
# debug - n_false_positive: 448783
# debug - n_true_negative: 8870595
# debug - n_false_negative: 19581
#
# debug - n_true_positive: 2381
# debug - n_false_positive: 448868
# debug - n_true_negative: 8873505
# debug - n_false_negative: 19582
#
# debug - n_true_positive: 2382
# debug - n_false_positive: 448901
# debug - n_true_negative: 8876465
# debug - n_false_negative: 19585
#
# debug - n_true_positive: 2382
# debug - n_false_positive: 449107
# debug - n_true_negative: 8879246
# debug - n_false_negative: 19596
#
# debug - n_true_positive: 2382
# debug - n_false_positive: 449188
# debug - n_true_negative: 8882161
# debug - n_false_negative: 19600
#
# debug - n_true_positive: 2383
# debug - n_false_positive: 449265
# debug - n_true_negative: 8885074
# debug - n_false_negative: 19606
#
# debug - n_true_positive: 2384
# debug - n_false_positive: 449513
# debug - n_true_negative: 8887823
# debug - n_false_negative: 19611
#
# debug - n_true_positive: 2385
# debug - n_false_positive: 449930
# debug - n_true_negative: 8890410
# debug - n_false_negative: 19615
#
# debug - n_true_positive: 2386
# debug - n_false_positive: 450164
# debug - n_true_negative: 8893173
# debug - n_false_negative: 19620
#
# debug - n_true_positive: 2386
# debug - n_false_positive: 450237
# debug - n_true_negative: 8896097
# debug - n_false_negative: 19625
#
# debug - n_true_positive: 2386
# debug - n_false_positive: 450352
# debug - n_true_negative: 8898979
# debug - n_false_negative: 19626
#
# debug - n_true_positive: 2387
# debug - n_false_positive: 450561
# debug - n_true_negative: 8901763
# debug - n_false_negative: 19631
#
# debug - n_true_positive: 2387
# debug - n_false_positive: 450597
# debug - n_true_negative: 8904722
# debug - n_false_negative: 19633
#
# debug - n_true_positive: 2387
# debug - n_false_positive: 450673
# debug - n_true_negative: 8907642
# debug - n_false_negative: 19635
#
# debug - n_true_positive: 2388
# debug - n_false_positive: 450921
# debug - n_true_negative: 8910383
# debug - n_false_negative: 19643
#
# debug - n_true_positive: 2389
# debug - n_false_positive: 451164
# debug - n_true_negative: 8913135
# debug - n_false_negative: 19646
#
# debug - n_true_positive: 2390
# debug - n_false_positive: 451413
# debug - n_true_negative: 8915880
# debug - n_false_negative: 19650
#
# debug - n_true_positive: 2390
# debug - n_false_positive: 451687
# debug - n_true_negative: 8918609
# debug - n_false_negative: 19651
#
# debug - n_true_positive: 2390
# debug - n_false_positive: 451747
# debug - n_true_negative: 8921547
# debug - n_false_negative: 19653
#
# debug - n_true_positive: 2392
# debug - n_false_positive: 451945
# debug - n_true_negative: 8924336
# debug - n_false_negative: 19665
#
# debug - n_true_positive: 2392
# debug - n_false_positive: 452385
# debug - n_true_negative: 8926905
# debug - n_false_negative: 19667
#
# debug - n_true_positive: 2394
# debug - n_false_positive: 452511
# debug - n_true_negative: 8929775
# debug - n_false_negative: 19668
#
# debug - n_true_positive: 2394
# debug - n_false_positive: 452642
# debug - n_true_negative: 8932635
# debug - n_false_negative: 19677
#
# debug - n_true_positive: 2394
# debug - n_false_positive: 452912
# debug - n_true_negative: 8935367
# debug - n_false_negative: 19682
#
# debug - n_true_positive: 2394
# debug - n_false_positive: 453218
# debug - n_true_negative: 8938059
# debug - n_false_negative: 19683
#
# debug - n_true_positive: 2394
# debug - n_false_positive: 453490
# debug - n_true_negative: 8940793
# debug - n_false_negative: 19686
#
# debug - n_true_positive: 2394
# debug - n_false_positive: 453661
# debug - n_true_negative: 8943614
# debug - n_false_negative: 19692
#
# debug - n_true_positive: 2394
# debug - n_false_positive: 453850
# debug - n_true_negative: 8946419
# debug - n_false_negative: 19695
#
# debug - n_true_positive: 2394
# debug - n_false_positive: 454040
# debug - n_true_negative: 8949221
# debug - n_false_negative: 19700
#
# debug - n_true_positive: 2394
# debug - n_false_positive: 454161
# debug - n_true_negative: 8952095
# debug - n_false_negative: 19702
#
# debug - n_true_positive: 2394
# debug - n_false_positive: 454213
# debug - n_true_negative: 8955034
# debug - n_false_negative: 19709
#
# debug - n_true_positive: 2394
# debug - n_false_positive: 454223
# debug - n_true_negative: 8958012
# debug - n_false_negative: 19718
#
# debug - n_true_positive: 2394
# debug - n_false_positive: 454319
# debug - n_true_negative: 8960908
# debug - n_false_negative: 19724
#
# debug - n_true_positive: 2394
# debug - n_false_positive: 454383
# debug - n_true_negative: 8963839
# debug - n_false_negative: 19727
#
# debug - n_true_positive: 2394
# debug - n_false_positive: 454708
# debug - n_true_negative: 8966509
# debug - n_false_negative: 19729
#
# debug - n_true_positive: 2394
# debug - n_false_positive: 455005
# debug - n_true_negative: 8969216
# debug - n_false_negative: 19731
#
# debug - n_true_positive: 2395
# debug - n_false_positive: 455174
# debug - n_true_negative: 8972044
# debug - n_false_negative: 19732
#
# debug - n_true_positive: 2395
# debug - n_false_positive: 455420
# debug - n_true_negative: 8974798
# debug - n_false_negative: 19737
#
# debug - n_true_positive: 2395
# debug - n_false_positive: 455459
# debug - n_true_negative: 8977749
# debug - n_false_negative: 19745
#
# debug - n_true_positive: 2396
# debug - n_false_positive: 455682
# debug - n_true_negative: 8980524
# debug - n_false_negative: 19748
#
# debug - n_true_positive: 2396
# debug - n_false_positive: 455909
# debug - n_true_negative: 8983292
# debug - n_false_negative: 19751
#
# debug - n_true_positive: 2396
# debug - n_false_positive: 456073
# debug - n_true_negative: 8986117
# debug - n_false_negative: 19763
#
# debug - n_true_positive: 2396
# debug - n_false_positive: 456207
# debug - n_true_negative: 8988981
# debug - n_false_negative: 19764
#
# debug - n_true_positive: 2396
# debug - n_false_positive: 456255
# debug - n_true_negative: 8991920
# debug - n_false_negative: 19774
#
# debug - n_true_positive: 2397
# debug - n_false_positive: 456463
# debug - n_true_negative: 8994706
# debug - n_false_negative: 19777
#
# debug - n_true_positive: 2397
# debug - n_false_positive: 456587
# debug - n_true_negative: 8997578
# debug - n_false_negative: 19779
#
# debug - n_true_positive: 2399
# debug - n_false_positive: 456821
# debug - n_true_negative: 9000343
# debug - n_false_negative: 19779
#
# debug - n_true_positive: 2399
# debug - n_false_positive: 456823
# debug - n_true_negative: 9003333
# debug - n_false_negative: 19784
#
# debug - n_true_positive: 2400
# debug - n_false_positive: 457205
# debug - n_true_negative: 9005948
# debug - n_false_negative: 19792
#
# debug - n_true_positive: 2400
# debug - n_false_positive: 457294
# debug - n_true_negative: 9008856
# debug - n_false_negative: 19793
#
# debug - n_true_positive: 2401
# debug - n_false_positive: 457421
# debug - n_true_negative: 9011726
# debug - n_false_negative: 19796
#
# debug - n_true_positive: 2401
# debug - n_false_positive: 457425
# debug - n_true_negative: 9014717
# debug - n_false_negative: 19798
#
# debug - n_true_positive: 2401
# debug - n_false_positive: 457927
# debug - n_true_negative: 9017219
# debug - n_false_negative: 19801
#
# debug - n_true_positive: 2401
# debug - n_false_positive: 457953
# debug - n_true_negative: 9020186
# debug - n_false_negative: 19805
#
# debug - n_true_positive: 2401
# debug - n_false_positive: 458015
# debug - n_true_negative: 9023118
# debug - n_false_negative: 19808
#
# debug - n_true_positive: 2401
# debug - n_false_positive: 458041
# debug - n_true_negative: 9026086
# debug - n_false_negative: 19811
#
# debug - n_true_positive: 2401
# debug - n_false_positive: 458260
# debug - n_true_negative: 9028863
# debug - n_false_negative: 19814
#
# debug - n_true_positive: 2401
# debug - n_false_positive: 458328
# debug - n_true_negative: 9031775
# debug - n_false_negative: 19831
#
# debug - n_true_positive: 2401
# debug - n_false_positive: 458563
# debug - n_true_negative: 9034537
# debug - n_false_negative: 19835
#
# debug - n_true_positive: 2402
# debug - n_false_positive: 458761
# debug - n_true_negative: 9037327
# debug - n_false_negative: 19847
#
# debug - n_true_positive: 2402
# debug - n_false_positive: 458901
# debug - n_true_negative: 9040184
# debug - n_false_negative: 19852
#
# debug - n_true_positive: 2402
# debug - n_false_positive: 459095
# debug - n_true_negative: 9042977
# debug - n_false_negative: 19863
#
# debug - n_true_positive: 2402
# debug - n_false_positive: 459272
# debug - n_true_negative: 9045794
# debug - n_false_negative: 19866
#
# debug - n_true_positive: 2403
# debug - n_false_positive: 459599
# debug - n_true_negative: 9048466
# debug - n_false_negative: 19873
#
# debug - n_true_positive: 2404
# debug - n_false_positive: 459742
# debug - n_true_negative: 9051310
# debug - n_false_negative: 19883
#
# debug - n_true_positive: 2404
# debug - n_false_positive: 460013
# debug - n_true_negative: 9054043
# debug - n_false_negative: 19886
#
# debug - n_true_positive: 2404
# debug - n_false_positive: 460104
# debug - n_true_negative: 9056943
# debug - n_false_negative: 19892
#
# debug - n_true_positive: 2405
# debug - n_false_positive: 460318
# debug - n_true_negative: 9059724
# debug - n_false_negative: 19903
#
# debug - n_true_positive: 2406
# debug - n_false_positive: 460411
# debug - n_true_negative: 9062625
# debug - n_false_negative: 19905
#
# debug - n_true_positive: 2407
# debug - n_false_positive: 460581
# debug - n_true_negative: 9065455
# debug - n_false_negative: 19906
#
# debug - n_true_positive: 2407
# debug - n_false_positive: 460769
# debug - n_true_negative: 9068263
# debug - n_false_negative: 19909
#
# debug - n_true_positive: 2407
# debug - n_false_positive: 460811
# debug - n_true_negative: 9071215
# debug - n_false_negative: 19912
#
# debug - n_true_positive: 2408
# debug - n_false_positive: 461083
# debug - n_true_negative: 9073938
# debug - n_false_negative: 19918
#
# debug - n_true_positive: 2408
# debug - n_false_positive: 461345
# debug - n_true_negative: 9076668
# debug - n_false_negative: 19923
#
# debug - n_true_positive: 2408
# debug - n_false_positive: 461805
# debug - n_true_negative: 9079217
# debug - n_false_negative: 19925
#
# debug - n_true_positive: 2408
# debug - n_false_positive: 461864
# debug - n_true_negative: 9082151
# debug - n_false_negative: 19930
#
# debug - n_true_positive: 2408
# debug - n_false_positive: 461999
# debug - n_true_negative: 9085013
# debug - n_false_negative: 19935
#
# debug - n_true_positive: 2408
# debug - n_false_positive: 462026
# debug - n_true_negative: 9087978
# debug - n_false_negative: 19940
#
# debug - n_true_positive: 2408
# debug - n_false_positive: 462185
# debug - n_true_negative: 9090812
# debug - n_false_negative: 19945
#
# debug - n_true_positive: 2408
# debug - n_false_positive: 462212
# debug - n_true_negative: 9093779
# debug - n_false_negative: 19948
#
# debug - n_true_positive: 2408
# debug - n_false_positive: 462375
# debug - n_true_negative: 9096613
# debug - n_false_negative: 19950
#
# debug - n_true_positive: 2408
# debug - n_false_positive: 462587
# debug - n_true_negative: 9099397
# debug - n_false_negative: 19957
#
# debug - n_true_positive: 2411
# debug - n_false_positive: 462842
# debug - n_true_negative: 9102136
# debug - n_false_negative: 19958
#
# debug - n_true_positive: 2411
# debug - n_false_positive: 462892
# debug - n_true_negative: 9105080
# debug - n_false_negative: 19961
#
# debug - n_true_positive: 2411
# debug - n_false_positive: 463061
# debug - n_true_negative: 9107910
# debug - n_false_negative: 19964
#
# debug - n_true_positive: 2412
# debug - n_false_positive: 463115
# debug - n_true_negative: 9110845
# debug - n_false_negative: 19972
#
# debug - n_true_positive: 2412
# debug - n_false_positive: 463290
# debug - n_true_negative: 9113657
# debug - n_false_negative: 19984
#
# debug - n_true_positive: 2412
# debug - n_false_positive: 463547
# debug - n_true_negative: 9116405
# debug - n_false_negative: 19985
#
# debug - n_true_positive: 2413
# debug - n_false_positive: 463729
# debug - n_true_negative: 9119216
# debug - n_false_negative: 19989
#
# debug - n_true_positive: 2414
# debug - n_false_positive: 464100
# debug - n_true_negative: 9121835
# debug - n_false_negative: 19998
#
# debug - n_true_positive: 2414
# debug - n_false_positive: 464178
# debug - n_true_negative: 9124753
# debug - n_false_negative: 20001
#
# debug - n_true_positive: 2414
# debug - n_false_positive: 464238
# debug - n_true_negative: 9127687
# debug - n_false_negative: 20004
#
# debug - n_true_positive: 2414
# debug - n_false_positive: 464457
# debug - n_true_negative: 9130467
# debug - n_false_negative: 20006
#
# debug - n_true_positive: 2416
# debug - n_false_positive: 464583
# debug - n_true_negative: 9133332
# debug - n_false_negative: 20013
#
# debug - n_true_positive: 2417
# debug - n_false_positive: 464834
# debug - n_true_negative: 9136079
# debug - n_false_negative: 20018
#
# debug - n_true_positive: 2418
# debug - n_false_positive: 464955
# debug - n_true_negative: 9138945
# debug - n_false_negative: 20028
#
# debug - n_true_positive: 2419
# debug - n_false_positive: 465223
# debug - n_true_negative: 9141678
# debug - n_false_negative: 20032
#
# debug - n_true_positive: 2420
# debug - n_false_positive: 465437
# debug - n_true_negative: 9144462
# debug - n_false_negative: 20032
#
# debug - n_true_positive: 2420
# debug - n_false_positive: 465529
# debug - n_true_negative: 9147366
# debug - n_false_negative: 20034
#
# debug - n_true_positive: 2420
# debug - n_false_positive: 465682
# debug - n_true_negative: 9150212
# debug - n_false_negative: 20035
#
# debug - n_true_positive: 2420
# debug - n_false_positive: 465835
# debug - n_true_negative: 9153053
# debug - n_false_negative: 20038
#
# debug - n_true_positive: 2420
# debug - n_false_positive: 466017
# debug - n_true_negative: 9155865
# debug - n_false_negative: 20043
#
# debug - n_true_positive: 2420
# debug - n_false_positive: 466145
# debug - n_true_negative: 9158733
# debug - n_false_negative: 20046
#
# debug - n_true_positive: 2421
# debug - n_false_positive: 466308
# debug - n_true_negative: 9161568
# debug - n_false_negative: 20047
#
# debug - n_true_positive: 2421
# debug - n_false_positive: 466511
# debug - n_true_negative: 9164356
# debug - n_false_negative: 20056
#
# debug - n_true_positive: 2422
# debug - n_false_positive: 466591
# debug - n_true_negative: 9167268
# debug - n_false_negative: 20060
#
# debug - n_true_positive: 2422
# debug - n_false_positive: 466925
# debug - n_true_negative: 9169938
# debug - n_false_negative: 20062
#
# debug - n_true_positive: 2423
# debug - n_false_positive: 467057
# debug - n_true_negative: 9172801
# debug - n_false_negative: 20063
#
# debug - n_true_positive: 2424
# debug - n_false_positive: 467206
# debug - n_true_negative: 9175647
# debug - n_false_negative: 20066
#
# debug - n_true_positive: 2424
# debug - n_false_positive: 467442
# debug - n_true_negative: 9178409
# debug - n_false_negative: 20067
#
# debug - n_true_positive: 2427
# debug - n_false_positive: 467782
# debug - n_true_negative: 9181065
# debug - n_false_negative: 20069
#
# debug - n_true_positive: 2427
# debug - n_false_positive: 467819
# ...
# debug - n_true_negative: 10614000
# debug - n_false_negative: 22065
#
# debug - n_true_positive: 2593
# debug - n_false_positive: 553767
# debug - n_true_negative: 10616685
# debug - n_false_negative: 22066
#
# debug - n_true_positive: 2593
# debug - n_false_positive: 554052
# debug - n_true_negative: 10619401
# debug - n_false_negative: 22069
#
# debug - n_true_positive: 2594
# debug - n_false_positive: 554390
# debug - n_true_negative: 10622065
# debug - n_false_negative: 22072
#
# debug - n_true_positive: 2594
# debug - n_false_positive: 554640
# debug - n_true_negative: 10624814
# debug - n_false_negative: 22073
#
# debug - n_true_positive: 2594
# debug - n_false_positive: 555016
# debug - n_true_negative: 10627441
# debug - n_false_negative: 22076
#
# debug - n_true_positive: 2594
# debug - n_false_positive: 555145
# debug - n_true_negative: 10630309
# debug - n_false_negative: 22079
#
# debug - n_true_positive: 2595
# debug - n_false_positive: 555424
# debug - n_true_negative: 10633030
# debug - n_false_negative: 22081
#
# debug - n_true_positive: 2595
# debug - n_false_positive: 555694
# debug - n_true_negative: 10635763
# debug - n_false_negative: 22082
#
# debug - n_true_positive: 2595
# debug - n_false_positive: 556003
# debug - n_true_negative: 10638450
# debug - n_false_negative: 22086
#
# debug - n_true_positive: 2596
# debug - n_false_positive: 556238
# debug - n_true_negative: 10641214
# debug - n_false_negative: 22087
#
# debug - n_true_positive: 2596
# debug - n_false_positive: 556294
# debug - n_true_negative: 10644153
# debug - n_false_negative: 22089
#
# debug - n_true_positive: 2596
# debug - n_false_positive: 556558
# debug - n_true_negative: 10646892
# debug - n_false_negative: 22091
#
# debug - n_true_positive: 2596
# debug - n_false_positive: 556828
# debug - n_true_negative: 10649616
# debug - n_false_negative: 22097
#
# debug - n_true_positive: 2596
# debug - n_false_positive: 557089
# debug - n_true_negative: 10652354
# debug - n_false_negative: 22099
#
# debug - n_true_positive: 2597
# debug - n_false_positive: 557384
# debug - n_true_negative: 10655059
# debug - n_false_negative: 22100
#
# debug - n_true_positive: 2598
# debug - n_false_positive: 557800
# debug - n_true_negative: 10657648
# debug - n_false_negative: 22105
#
# debug - n_true_positive: 2598
# debug - n_false_positive: 557987
# debug - n_true_negative: 10660456
# debug - n_false_negative: 22108
#
# debug - n_true_positive: 2598
# debug - n_false_positive: 558053
# debug - n_true_negative: 10663387
# debug - n_false_negative: 22110
#
# debug - n_true_positive: 2599
# debug - n_false_positive: 558110
# debug - n_true_negative: 10666328
# debug - n_false_negative: 22110
#
# debug - n_true_positive: 2599
# debug - n_false_positive: 558338
# debug - n_true_negative: 10669098
# debug - n_false_negative: 22113
#
# debug - n_true_positive: 2599
# debug - n_false_positive: 558502
# debug - n_true_negative: 10671923
# debug - n_false_negative: 22122
#
# debug - n_true_positive: 2599
# debug - n_false_positive: 558707
# debug - n_true_negative: 10674717
# debug - n_false_negative: 22123
#
# debug - n_true_positive: 2599
# debug - n_false_positive: 558730
# debug - n_true_negative: 10677688
# debug - n_false_negative: 22127
#
# debug - n_true_positive: 2599
# debug - n_false_positive: 558882
# debug - n_true_negative: 10680535
# debug - n_false_negative: 22128
#
# debug - n_true_positive: 2599
# debug - n_false_positive: 559093
# debug - n_true_negative: 10683326
# debug - n_false_negative: 22130
#
# debug - n_true_positive: 2599
# debug - n_false_positive: 559314
# debug - n_true_negative: 10686100
# debug - n_false_negative: 22132
#
# debug - n_true_positive: 2599
# debug - n_false_positive: 559800
# debug - n_true_negative: 10688616
# debug - n_false_negative: 22139
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 560042
# debug - n_true_negative: 10691373
# debug - n_false_negative: 22143
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 560328
# debug - n_true_negative: 10694075
# debug - n_false_negative: 22157
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 560519
# debug - n_true_negative: 10696884
# debug - n_false_negative: 22160
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 560679
# debug - n_true_negative: 10699719
# debug - n_false_negative: 22162
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 560773
# debug - n_true_negative: 10702620
# debug - n_false_negative: 22164
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 561017
# debug - n_true_negative: 10705370
# debug - n_false_negative: 22174
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 561024
# debug - n_true_negative: 10708357
# debug - n_false_negative: 22178
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 561221
# debug - n_true_negative: 10711157
# debug - n_false_negative: 22181
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 561379
# debug - n_true_negative: 10713998
# debug - n_false_negative: 22183
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 561660
# debug - n_true_negative: 10716717
# debug - n_false_negative: 22184
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 561767
# debug - n_true_negative: 10719612
# debug - n_false_negative: 22186
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 561880
# debug - n_true_negative: 10722496
# debug - n_false_negative: 22189
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 562084
# debug - n_true_negative: 10725289
# debug - n_false_negative: 22191
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 562306
# debug - n_true_negative: 10728063
# debug - n_false_negative: 22194
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 562373
# debug - n_true_negative: 10730990
# debug - n_false_negative: 22197
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 562692
# debug - n_true_negative: 10733673
# debug - n_false_negative: 22200
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 562977
# debug - n_true_negative: 10736379
# debug - n_false_negative: 22212
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 563140
# debug - n_true_negative: 10739214
# debug - n_false_negative: 22214
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 563445
# debug - n_true_negative: 10741910
# debug - n_false_negative: 22218
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 563500
# debug - n_true_negative: 10744849
# debug - n_false_negative: 22221
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 563570
# debug - n_true_negative: 10747771
# debug - n_false_negative: 22226
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 563807
# debug - n_true_negative: 10750530
# debug - n_false_negative: 22229
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 564071
# debug - n_true_negative: 10753267
# debug - n_false_negative: 22232
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 564196
# debug - n_true_negative: 10756144
# debug - n_false_negative: 22236
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 564372
# debug - n_true_negative: 10758964
# debug - n_false_negative: 22239
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 564734
# debug - n_true_negative: 10761606
# debug - n_false_negative: 22242
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 564960
# debug - n_true_negative: 10764376
# debug - n_false_negative: 22245
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 565248
# debug - n_true_negative: 10767083
# debug - n_false_negative: 22250
#
# debug - n_true_positive: 2600
# debug - n_false_positive: 565563
# debug - n_true_negative: 10769773
# debug - n_false_negative: 22252
#
# debug - n_true_positive: 2601
# debug - n_false_positive: 565663
# debug - n_true_negative: 10772665
# debug - n_false_negative: 22257
#
# debug - n_true_positive: 2602
# debug - n_false_positive: 565917
# debug - n_true_negative: 10775413
# debug - n_false_negative: 22261
#
# debug - n_true_positive: 2602
# debug - n_false_positive: 565922
# debug - n_true_negative: 10778402
# debug - n_false_negative: 22264
#
# debug - n_true_positive: 2602
# debug - n_false_positive: 566226
# debug - n_true_negative: 10781096
# debug - n_false_negative: 22267
#
# debug - n_true_positive: 2602
# debug - n_false_positive: 566446
# debug - n_true_negative: 10783876
# debug - n_false_negative: 22269
#
# debug - n_true_positive: 2602
# debug - n_false_positive: 566696
# debug - n_true_negative: 10786625
# debug - n_false_negative: 22272
#
# debug - n_true_positive: 2602
# debug - n_false_positive: 566860
# debug - n_true_negative: 10789457
# debug - n_false_negative: 22275
#
# debug - n_true_positive: 2602
# debug - n_false_positive: 567124
# debug - n_true_negative: 10792191
# debug - n_false_negative: 22282
#
# debug - n_true_positive: 2602
# debug - n_false_positive: 567350
# debug - n_true_negative: 10794963
# debug - n_false_negative: 22285
#
# debug - n_true_positive: 2602
# debug - n_false_positive: 567835
# debug - n_true_negative: 10797483
# debug - n_false_negative: 22287
#
# debug - n_true_positive: 2602
# debug - n_false_positive: 568086
# debug - n_true_negative: 10800230
# debug - n_false_negative: 22289
#
# debug - n_true_positive: 2602
# debug - n_false_positive: 568464
# debug - n_true_negative: 10802857
# debug - n_false_negative: 22290
#
# debug - n_true_positive: 2602
# debug - n_false_positive: 568720
# debug - n_true_negative: 10805602
# debug - n_false_negative: 22295
#
# debug - n_true_positive: 2603
# debug - n_false_positive: 568932
# debug - n_true_negative: 10808388
# debug - n_false_negative: 22296
#
# debug - n_true_positive: 2603
# debug - n_false_positive: 569006
# debug - n_true_negative: 10811312
# debug - n_false_negative: 22298
#
# debug - n_true_positive: 2603
# debug - n_false_positive: 569222
# debug - n_true_negative: 10814096
# debug - n_false_negative: 22299
#
# debug - n_true_positive: 2603
# debug - n_false_positive: 569500
# debug - n_true_negative: 10816820
# debug - n_false_negative: 22301
#
# debug - n_true_positive: 2603
# debug - n_false_positive: 569605
# debug - n_true_negative: 10819710
# debug - n_false_negative: 22304
#
# debug - n_true_positive: 2604
# debug - n_false_positive: 569847
# debug - n_true_negative: 10822465
# debug - n_false_negative: 22305
#
# debug - n_true_positive: 2604
# debug - n_false_positive: 570138
# debug - n_true_negative: 10825172
# debug - n_false_negative: 22309
#
# debug - n_true_positive: 2605
# debug - n_false_positive: 570319
# debug - n_true_negative: 10827985
# debug - n_false_negative: 22313
#
# debug - n_true_positive: 2605
# debug - n_false_positive: 570405
# debug - n_true_negative: 10830896
# debug - n_false_negative: 22316
#
# debug - n_true_positive: 2605
# debug - n_false_positive: 570764
# debug - n_true_negative: 10833540
# debug - n_false_negative: 22320
#
# debug - n_true_positive: 2605
# debug - n_false_positive: 570886
# debug - n_true_negative: 10836416
# debug - n_false_negative: 22322
#
# debug - n_true_positive: 2605
# debug - n_false_positive: 571040
# debug - n_true_negative: 10839258
# debug - n_false_negative: 22324
#
# debug - n_true_positive: 2605
# debug - n_false_positive: 571200
# debug - n_true_negative: 10842095
# debug - n_false_negative: 22325
#
# debug - n_true_positive: 2607
# debug - n_false_positive: 571789
# debug - n_true_negative: 10844514
# debug - n_false_negative: 22325
#
# debug - n_true_positive: 2607
# debug - n_false_positive: 572010
# debug - n_true_negative: 10847294
# debug - n_false_negative: 22329
#
# debug - n_true_positive: 2607
# debug - n_false_positive: 572303
# debug - n_true_negative: 10850002
# debug - n_false_negative: 22332
#
# debug - n_true_positive: 2607
# debug - n_false_positive: 572540
# debug - n_true_negative: 10852763
# debug - n_false_negative: 22333
#
# debug - n_true_positive: 2607
# debug - n_false_positive: 572790
# debug - n_true_negative: 10855514
# debug - n_false_negative: 22335
#
# debug - n_true_positive: 2607
# debug - n_false_positive: 573055
# debug - n_true_negative: 10858244
# debug - n_false_negative: 22342
#
# debug - n_true_positive: 2607
# debug - n_false_positive: 573292
# debug - n_true_negative: 10861009
# debug - n_false_negative: 22343
#
# debug - n_true_positive: 2607
# debug - n_false_positive: 573560
# debug - n_true_negative: 10863739
# debug - n_false_negative: 22348
#
# debug - n_true_positive: 2607
# debug - n_false_positive: 573887
# debug - n_true_negative: 10866412
# debug - n_false_negative: 22349
#
# debug - n_true_positive: 2607
# debug - n_false_positive: 574064
# debug - n_true_negative: 10869229
# debug - n_false_negative: 22353
#
# debug - n_true_positive: 2607
# debug - n_false_positive: 574322
# debug - n_true_negative: 10871973
# debug - n_false_negative: 22355
#
# debug - n_true_positive: 2607
# debug - n_false_positive: 574497
# debug - n_true_negative: 10874797
# debug - n_false_negative: 22356
#
# debug - n_true_positive: 2607
# debug - n_false_positive: 574698
# debug - n_true_negative: 10877596
# debug - n_false_negative: 22357
#
# debug - n_true_positive: 2607
# debug - n_false_positive: 574907
# debug - n_true_negative: 10880383
# debug - n_false_negative: 22360
#
# debug - n_true_positive: 2607
# debug - n_false_positive: 575092
# debug - n_true_negative: 10883195
# debug - n_false_negative: 22361
#
# debug - n_true_positive: 2608
# debug - n_false_positive: 575425
# debug - n_true_negative: 10885864
# debug - n_false_negative: 22362
#
# debug - n_true_positive: 2608
# debug - n_false_positive: 575876
# debug - n_true_negative: 10888424
# debug - n_false_negative: 22364
#
# debug - n_true_positive: 2610
# debug - n_false_positive: 576176
# debug - n_true_negative: 10891124
# debug - n_false_negative: 22365
#
# debug - n_true_positive: 2610
# debug - n_false_positive: 576441
# debug - n_true_negative: 10893858
# debug - n_false_negative: 22368
#
# debug - n_true_positive: 2610
# debug - n_false_positive: 576596
# debug - n_true_negative: 10896701
# debug - n_false_negative: 22371
#
# debug - n_true_positive: 2611
# debug - n_false_positive: 576826
# debug - n_true_negative: 10899468
# debug - n_false_negative: 22373
#
# debug - n_true_positive: 2611
# debug - n_false_positive: 577361
# debug - n_true_negative: 10901942
# debug - n_false_negative: 22377
#
# debug - n_true_positive: 2611
# debug - n_false_positive: 577603
# debug - n_true_negative: 10904700
# debug - n_false_negative: 22379
#
# debug - n_true_positive: 2611
# debug - n_false_positive: 577907
# debug - n_true_negative: 10907399
# debug - n_false_negative: 22381
#
# debug - n_true_positive: 2612
# debug - n_false_positive: 578165
# debug - n_true_negative: 10910142
# debug - n_false_negative: 22382
#
# debug - n_true_positive: 2613
# debug - n_false_positive: 578352
# debug - n_true_negative: 10912954
# debug - n_false_negative: 22384
#
# debug - n_true_positive: 2614
# debug - n_false_positive: 578667
# debug - n_true_negative: 10915642
# debug - n_false_negative: 22385
#
# debug - n_true_positive: 2615
# debug - n_false_positive: 579004
# debug - n_true_negative: 10918306
# debug - n_false_negative: 22387
#
# debug - n_true_positive: 2615
# debug - n_false_positive: 579285
# debug - n_true_negative: 10921026
# debug - n_false_negative: 22388
#
# debug - n_true_positive: 2616
# debug - n_false_positive: 579730
# debug - n_true_negative: 10923589
# debug - n_false_negative: 22388
#
# debug - n_true_positive: 2616
# debug - n_false_positive: 580043
# debug - n_true_negative: 10926284
# debug - n_false_negative: 22390
#
# debug - n_true_positive: 2616
# debug - n_false_positive: 580275
# debug - n_true_negative: 10929051
# debug - n_false_negative: 22392
#
# debug - n_true_positive: 2616
# debug - n_false_positive: 580503
# debug - n_true_negative: 10931820
# debug - n_false_negative: 22398
#
# debug - n_true_positive: 2618
# debug - n_false_positive: 580707
# debug - n_true_negative: 10934613
# debug - n_false_negative: 22400
#
# debug - n_true_positive: 2618
# debug - n_false_positive: 580946
# debug - n_true_negative: 10937373
# debug - n_false_negative: 22402
#
# debug - n_true_positive: 2620
# debug - n_false_positive: 581225
# debug - n_true_negative: 10940093
# debug - n_false_negative: 22403
#
# debug - n_true_positive: 2621
# debug - n_false_positive: 581539
# debug - n_true_negative: 10942782
# debug - n_false_negative: 22404
#
# debug - n_true_positive: 2621
# debug - n_false_positive: 581762
# debug - n_true_negative: 10945556
# debug - n_false_negative: 22407
#
# debug - n_true_positive: 2622
# debug - n_false_positive: 582028
# debug - n_true_negative: 10948289
# debug - n_false_negative: 22408
#
# debug - n_true_positive: 2622
# debug - n_false_positive: 582239
# debug - n_true_negative: 10951074
# debug - n_false_negative: 22410
# (0.10474592521572387, 0.05048323929126002)
